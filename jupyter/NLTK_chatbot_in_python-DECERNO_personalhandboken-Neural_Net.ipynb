# %%
import numpy as np
import nltk
import string
import random
import pickle
import spacy
from spacy.lang.sv.examples import sentences

import PyPDF2
import re

# %%
def extract_text(text):
    
    # Create reader variable that will read the pdffileobj
    pdf_reader = PyPDF2.PdfReader(text)
    
    # This will store the number of pages of this pdf file
    x = len(pdf_reader.pages)
    
    # Create a variable that will select the selected number of pages
    page = pdf_reader.pages[0]
    text = page.extract_text()
    
    complete_text = ''
    for i in range(0, x):
        page = pdf_reader.pages[i]
        text = page.extract_text()
        complete_text = complete_text + text 
    
    # converting enitre text to lowercase
    raw_doc = complete_text.lower() 
    return raw_doc

# %%
# Create file object variable (opening method will be rb)
pdf_file_obj = open('personalhandboken.pdf','rb')
raw_text = extract_text(pdf_file_obj)

# %%
raw_text = raw_text.replace("�llsammans", "tillsammans")
raw_text = raw_text.replace("�ll", "till")
raw_text = raw_text.replace("�llgänglig", "tillgänglig")
raw_text = raw_text.replace("�ps", "tips")
raw_text = raw_text.replace("�psa", "tipsa")
raw_text = raw_text.replace("�digare", "tidigare")
raw_text = raw_text.replace("medlemsavgi�er", "medlemsavgiter")
raw_text = raw_text.replace("u�orska", "utforska")
raw_text = raw_text.replace("�ärran", "fjärran")
raw_text = raw_text.replace("�dredovisas", "tidredovisas")
raw_text = raw_text.replace("res�d", "restid")
raw_text = raw_text.replace("ini�a�v", "initiativ")
raw_text = raw_text.replace("kundlö�e", "kundlöfte")
raw_text = raw_text.replace("sam�digt", "samtidigt")
raw_text = raw_text.replace("sy�et", "syftet")
raw_text = raw_text.replace("personalpoli�k", "personalpolitik")
raw_text = raw_text.replace("mo�verade", "motiverade")
raw_text = raw_text.replace("kon�nuerlig", "kontinuerlig")
raw_text = raw_text.replace("all�d", "alltid")
raw_text = raw_text.replace("fram�den", "framtiden")
raw_text = raw_text.replace("kollek �vavtal", "kollektivavtal")
raw_text = raw_text.replace("kollek�vavtal", "kollektivavtal")
raw_text = raw_text.replace("e�er", "eller")
raw_text = raw_text.replace("vik�ga", "viktiga")
raw_text = raw_text.replace("ru�ner", "rutiner")
raw_text = raw_text.replace("s�mulera", "stimulera")
raw_text = raw_text.replace("resulta�nriktad", "resultatinriktad")
raw_text = raw_text.replace("lönepoli�k", "lönepolitik")
raw_text = raw_text.replace("posi�va", "positiva")
raw_text = raw_text.replace("sta�s�k", "statistik")
raw_text = raw_text.replace("arbetsuppgi�er", "arbetsuppgifter")
raw_text = raw_text.replace("arbets�d", "arbetstid")
raw_text = raw_text.replace("posi�on", "position")
raw_text = raw_text.replace("�mme", "timme")
raw_text = raw_text.replace("mo�on", "motion")
raw_text = raw_text.replace("sve�s", "svettis")
raw_text = raw_text.replace("häl�en", "hälften")
raw_text = raw_text.replace("utgi�er", "uppgifter")
raw_text = raw_text.replace("vik�gt", "viktigt")
raw_text = raw_text.replace("s tartavgi�er", "startavgifter")
raw_text = raw_text.replace("informa� on", "information")
raw_text = raw_text.replace("skateplik�ga", "skatepliktiga")
raw_text = raw_text.replace("uppgi�er", "uppgifter")
raw_text = raw_text.replace("vik�g", "viktig")
raw_text = raw_text.replace("rä�gheten", "rättgheten")
raw_text = raw_text.replace("mo�vera", "motivera")
raw_text = raw_text.replace("inkomstbor�allet", "inkomstbortfallet")
raw_text = raw_text.replace("�d", "tid")
raw_text = raw_text.replace("ha�", "haft")
raw_text = raw_text.replace("tre�odagarsperioder", "tretiodagarsperioder")
raw_text = raw_text.replace("tre�odagarsperiod", "tretiodagarsperiod")
raw_text = raw_text.replace("�ärdedels", "fjärdedels")
raw_text = raw_text.replace("�ärdedelar", "fjärdedelar")
raw_text = raw_text.replace("�ärdedel", "fjärdedel")
raw_text = raw_text.replace("respek�ve", "respektive")
raw_text = raw_text.replace("övers�ga", "överstiga")
raw_text = raw_text.replace("adop�on", "adoption")
raw_text = raw_text.replace("op�ker", "optiker")
raw_text = raw_text.replace("synop�k", "synoptik")
raw_text = raw_text.replace("op�kern", "optikern")
raw_text = raw_text.replace("rekvisi�on", "rekvisition")
raw_text = raw_text.replace("o�a", "ofta")
raw_text = raw_text.replace("alterna�v", "alternativ")
raw_text = raw_text.replace("informa�on", "information")
raw_text = raw_text.replace("repara�onen", "reparationen")
raw_text = raw_text.replace("�mmar", "timmar")
raw_text = raw_text.replace("produk�va", "produktiva")
raw_text = raw_text.replace("organisa�on", "organisation")
raw_text = raw_text.replace("� llse", "tillse")
raw_text = raw_text.replace("sy�ar", "syftar")
raw_text = raw_text.replace("framåtsy�ande", "framåtsyftande")
raw_text = raw_text.replace("ak�viteterna", "aktiviteterna")
raw_text = raw_text.replace("ak�viteter", "aktiviteter")
raw_text = raw_text.replace("ak�vitet", "aktivitet")
raw_text = raw_text.replace("ak� vitet", "aktivitet")
raw_text = raw_text.replace("arbetssitua�on", "arbetssituation")
raw_text = raw_text.replace("presta�on", "prestation")
raw_text = raw_text.replace("uppgi�", "uppgift")
raw_text = raw_text.replace("situa�on", "situation")
raw_text = raw_text.replace("u�från", "utifrån")
raw_text = raw_text.replace("uppg i�er", "uppgifter")
raw_text = raw_text.replace("kombina�on", "kombination")
raw_text = raw_text.replace("ak�viteter", "aktiviteter")
raw_text = raw_text.replace("ak�vitet", "aktivitet")
raw_text = raw_text.replace("tradi�on", "tradition")
raw_text = raw_text.replace("tradi�oner", "traditioner")
raw_text = raw_text.replace("all�från", "alltifrån")
raw_text = raw_text.replace("introduk�on", "introduktion")
raw_text = raw_text.replace("introduk�ons dagen", "introduktionsdagen")
raw_text = raw_text.replace("introduk�onsdagar", "introduktionsdagar")
raw_text = raw_text.replace("introduk�ons dagen", "introduktionsdagen")
raw_text = raw_text.replace("vik �gt", "viktigt")
raw_text = raw_text.replace("månadsski�e", "månadsskifte")
raw_text = raw_text.replace("a�on", "afton")
raw_text = raw_text.replace("an�ngen", "antingen")
raw_text = raw_text.replace("u�öras", "utföras")
raw_text = raw_text.replace("övers�ger", "överstiger")
raw_text = raw_text.replace("pr ognos�cera", "prognosticera")
raw_text = raw_text.replace("övers�ger", "överstiger")
raw_text = raw_text.replace("automa�skt", "automatiskt")
raw_text = raw_text.replace("u�öra", "utföra")
raw_text = raw_text.replace("pos i�va", "positiva")
raw_text = raw_text.replace("gil�ghet", "giltighet")
raw_text = raw_text.replace("u�ormat", "utformat")
raw_text = raw_text.replace("u�ormad", "utformad")
raw_text = raw_text.replace("informa�v", "informativ")
raw_text = raw_text.replace("u�örlig", "utförlig")
raw_text = raw_text.replace("u�all", "utfall")
raw_text = raw_text.replace("administrafton", "administration")
raw_text = raw_text.replace("augus�", "augusti")
raw_text = raw_text.replace("gil�g", "giltig")
raw_text = raw_text.replace(" �o", " tio")
raw_text = raw_text.replace("�sdagen", "onsdagen")
raw_text = raw_text.replace("kon struk�on", "konstruktion")
raw_text = raw_text.replace("edi�on", "edition")
raw_text = raw_text.replace("näs�öljande", "nästföljande")
raw_text = raw_text.replace("bekrä�as", "bekräknas")
raw_text = raw_text.replace("funk�on", "funktion")
raw_text = raw_text.replace("direk�ven", "direktiven")
raw_text = raw_text.replace("huvudsy�e", "huvudsyfte")
raw_text = raw_text.replace("avgi�", "avgit")
raw_text = raw_text.replace("kos�örmån", "kostförmån")
raw_text = raw_text.replace("sy�e", "syfte")
raw_text = raw_text.replace("kollek�va", "kollektiva")
raw_text = raw_text.replace("iden�ﬁera", "idenfiﬁera")
raw_text = raw_text.replace("skateplik�g ", "skatepliktig ")
raw_text = raw_text.replace("fak�sk", "faktisk")
raw_text = raw_text.replace("berä�gad", "berätigad")
raw_text = raw_text.replace("u�örs", "utförs")
raw_text = raw_text.replace("konﬁden�ell", "konﬁdentiell")
raw_text = raw_text.replace("kra�", "kraft")
raw_text = raw_text.replace("�manställda", "timanställda")
raw_text = raw_text.replace("skri�ligen", "skriftligen")
raw_text = raw_text.replace("inkoms�örlust", "inkomstförlust")
raw_text = raw_text.replace("livss�lsrelaterade", "livsstilsrelaterade")
raw_text = raw_text.replace("legi�merad", "legitimerad")
raw_text = raw_text.replace("ini�alt", "initialt")
raw_text = raw_text.replace("ak�er", "aktier")
raw_text = raw_text.replace("recep�örskrivningar", "receptförskrivningar")
raw_text = raw_text.replace("förberedelse �g -möte/aktivitet", "förberedelse ftg -möte/aktivitet")
raw_text = raw_text.replace("må�ulla", "måttfulla")
raw_text = raw_text.replace("skatelags��ningen", "skatelagsstiftningen")
raw_text
# Out:
# ' \n \n  \nvi skapar värde tillsammans  \nutforska och våga pröva  \ntydlig med omtanke  \ngör dig själv och andra stolta  personalhandbok   personalhandbok  2 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n  \nvision:  \ndecerno är bäst i \nsverige på att leverera \npålitliga system-\nlösningar för kunder \nmed höga krav   personalhandbok  3 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ninnehåll   \natt arbeta på decerno  5 \n1. personalhandboken  6 \n2. koll ektivavtal  7 \n3. lön och förmåner  8 \n3.1 lönepolicy  8 \n3.2 lön, ersättningar  8 \n3.3 rekryteringsbonus  8 \n3.4 företagsh älsovård  9 \n3.5 motion och friskvård  9 \n3.6 fika och frukt på kontoret  10 \n3.7 föräldraförmån  10 \n3.8 bildskärmglasögon  11 \n3.9 blodgivning på arbetstid  12 \n4. mobiltelefonpolicy  13 \n5. kompetensutveckling och personlig  utveckling  14 \n5.1 kompetensutvecklingspolicy  14 \n5.2 konferenser  16 \n5.3 tidredovisning kurs och extern konferens  16 \n6. introduktion av nyanställda  17 \n6.1 introduktion  17 \n6.2 fadder  17 \n7. arbetstider och tidredovisning  18 \n7.1 riktlinjer för arbetstid  18 \n7.2 distansarbete  fel! bokmärket är inte definierat . \n8. decernomöten & sociala aktiviteter  21 \n8.1 obligatoriska decernomöten  21 \n8.2 regionala sociala aktiviteter  21 \n8.3 övriga sociala aktiviteter  21 \n9. frånvaro  23 \n9.1 planerad frånvaro  23 \n9.2 föräldraledighet  23 \n9.3 semester  23 \n9.4 läkarbesök  25 \n9.5 sjukfrånvaro  25 \n9.6 permission  27 \n10. utlägg och representation  28 \n10.1 utlägg  27 \n10.2 extern representation  28 \n10.3 intern representation  29 \n10.4 utköp av dator  30 \n11. resor i tjänsten  30 \n11.1 resepolicy  30 \n11.2 ersättning för reskostnad vid långvarigt arbete hos kund  32  personalhandbok  4 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n11.3 traktamente  32 \n11.4 semester i samband med tjänsteresa  33 \n11.5 restid  33 \n12. säkerhet och sekretess  34 \n12.1 sekretess  34 \n12.2 media 34 \n12.3 finansiell information  33 \n12.4 skyddsombud  34 \n12.5 säkerhetsrutiner it & programvarupolicy  34 \n13. arbetsmiljö och jämställdhet  35 \n13.1 arbetsmiljöpolicy  35 \n13.2 jämställdhetspolicy  35 \n14. försäkringspolicy  36 \n14.1 allmänt  36 \n14.2 omfattning  36 \n14.3 tjänstegrupplivförsäkring (tgl)  36 \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  37 \n14.5 kollektiv olycksfallsförsäkring hos if 37 \n14.6 sjukförsäkring  38 \n14.7 tjänstereseförsäkring  39 \n14.8 tjänstepension  39 \n14.9 sjukvårdsförsäkring  40  personalhandbok  5 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \natt arbeta på decerno  \ndet ska vara roligt at arbeta på decerno!  \npå decerno förenas vi kring et stort \nteknikintresse. vi gillar tekniska utmaningar och at lösa svåra problem tillsammans.  \nföretagskulturen är omhändertagande utan at \nhämma  egna initiativ och idéer.  \ndecerno arbetar  med hela uppdrag. at jobba \ntillsammans i tuﬀa projekt skapar en unik företagskultur. det du inte redan kan får du lära dig av erfa rna kollegor.  \nvi bygger skräddarsydda verksamhetssystem och vårt kundlöfte \när pålitliga systemlösningar. pålitlighet innebär at ta ansvar för \nhelheten. at ha överblick och samtidigt kontroll på alla detaljer.   \nhos decerno har du stora möjlighet at ständ igt vidareutveckla din \nkompetens. dels genom arbetskamraternas erfarenhet och dels \ngenom vår satsning på vidareutbildning.  \npå våra  konferensresor diskuterar vi lärdomar från våra projekt. \nbåde vad gäller teknik, ledarskap och aﬀärsmannaskap. \nresorna går till när och fjärran platser där vi kan \nkrydda vistelsen med berikande upplevelser.  \nalla anställdas insatser är avgörande för at \nföretag ets mål och visio ...

# %%
count = 0
start_index = []
end_index = []
# \w matches any alphanumeric character
# \b indicate word boundary
# {5} indicate five-letter word
for match in re.finditer(r'�', raw_text):
    count += 1
    #print("match", count, match.group(), "start index", match.start(), "End index", match.end())
    print(raw_text[match.start():match.start()+20])

# %%
# Download tokenizer packages for swedish
nlp = spacy.load('sv_core_news_sm')

# %%
# Go trough the text. make it to lower case and remove punctuation like new lines, commas etc.
our_token_string = '  \n \n  \n \n \n  \n\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_{|}~\t\n�u '
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in our_token_string]

# %%
word_tokens = separate_punc(raw_text)
word_tokens
# Out:
# ['vi',
#  'skapar',
#  'värde',
#  'tillsammans',
#  'utforska',
#  'och',
#  'våga',
#  'pröva',
#  'tydlig',
#  'med',
#  'omtanke',
#  'gör',
#  'dig',
#  'själv',
#  'och',
#  'andra',
#  'stolta',
#  'personalhandbok',
#  'personalhandbok',
#  '2',
#  '40',
#  'dokument',
#  'författare',
#  'senast',
#  'sparat',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'vision',
#  'decerno',
#  'är',
#  'bäst',
#  'i',
#  'sverige',
#  'på',
#  'att',
#  'leverera',
#  'pålitliga',
#  'system-',
#  'lösningar',
#  'för',
#  'kunder',
#  'med',
#  'höga',
#  'krav',
#  'personalhandbok',
#  '3',
#  '40',
#  'dokument',
#  'författare',
#  'senast',
#  'sparat',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'innehåll',
#  'att',
#  'arbeta',
#  'på',
#  'decerno',
#  '5',
#  '1',
#  'personalhandboken',
#  '6',
#  '2',
#  'koll',
#  'ektivavtal',
#  '7',
#  '3',
#  'lön',
#  'och',
#  'förmåner',
#  '8',
#  '3.1',
#  'lönepolicy',
#  '8',
#  '3.2',
#  'lön',
#  'ersättningar',
#  '8',
#  '3.3',
#  'rekryteringsbonus',
#  '8',
#  '3.4',
#  'företagsh',
#  'älsovård',
#  '9',
#  '3.5',
#  'motion',
#  'och',
#  'friskvård',
#  '9',
#  '3.6',
#  'fika',
#  'och',
#  'frukt',
#  'på',
#  'kontoret',
#  '10',
#  '3.7',
#  'föräldraförmån',
#  '10',
#  '3.8',
#  'bildskärmglasögon',
#  '11',
#  '3.9',
#  'blodgivning',
#  'på',
#  'arbetstid',
#  '12',
#  '4',
#  'mobiltelefonpolicy',
#  '13',
#  '5',
#  'kompetensutveckling',
#  'och',
#  'personlig',
#  'utveckling',
#  '14',
#  '5.1',
#  'kompetensutvecklingspolicy',
#  '14',
#  '5.2',
#  'konferenser',
#  '16',
#  '5.3',
#  'tidredovisning',
#  'kurs',
#  'och',
#  'extern',
#  'konferens',
#  '16',
#  '6',
#  'introduktion',
#  'av',
#  'nyanställda',
#  '17',
#  '6.1',
#  'introduktion',
#  '17',
#  '6.2',
#  'fadder',
#  '17',
#  '7',
#  'arbetstider',
#  'och',
#  'tidredovisning',
#  '18',
#  '7.1',
#  'riktlinjer',
#  'för',
#  'arbetstid',
#  '18',
#  '7.2',
#  'distansarbete',
#  'fel',
#  'bokmärket',
#  'är',
#  'inte',
#  'definierat',
#  '8',
#  'decernomöten',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '8.1',
#  'obligatoriska',
#  'decernomöten',
#  '21',
#  '8.2',
#  'regionala',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '8.3',
#  'övriga',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '9',
#  'frånvaro',
#  '23',
#  '9.1',
#  'planerad',
#  'frånvaro',
#  '23',
#  '9.2',
#  'föräldraledighet',
#  '23',
#  '9.3',
#  'semester',
#  '23',
#  '9.4',
#  'läkarbesök',
#  '25',
#  '9.5',
#  'sjukfrånvaro',
#  '25',
#  '9.6',
#  'permission',
#  '27',
#  '10',
#  'utlägg',
#  'och',
#  'representation',
#  '28',
#  '10.1',
#  'utlägg',
#  '27',
#  '10.2',
#  'extern',
#  'representation',
#  '28',
#  '10.3',
#  'intern',
#  'representation',
#  '29',
#  '10.4',
#  'utköp',
#  'av',
#  'dator',
#  '30',
#  '11',
#  'resor',
#  'i',
#  'tjänsten',
#  '30',
#  '11.1',
#  'resepolicy',
#  '30',
#  '11.2',
#  'ersättning',
#  'för',
#  'reskostnad',
#  'vid',
#  'långvarigt',
#  'arbete',
#  'hos',
#  'kund',
#  '32',
#  'personalhandbok',
#  '4',
#  '40',
#  'dokument',
#  'författare',
#  'senast',
#  'sparat',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  '11.3',
#  'traktamente',
#  '32',
#  '11.4',
#  'semester',
#  'i',
#  'samband',
#  'med',
#  'tjänsteresa',
#  '33',
#  '11.5',
#  'restid',
#  '33',
#  '12',
#  'säkerhet',
#  'och',
#  'sekretess',
#  '34',
#  '12.1',
#  'sekretess',
#  '34',
#  '12.2',
#  'media',
#  '34',
#  '12.3',
#  'finansiell',
#  'information',
#  '33',
#  '12.4',
#  'skyddsombud',
#  '34',
#  '12.5',
#  'säkerhetsrutiner',
#  'it',
#  'programvarupolicy',
#  '34',
#  '13',
#  'arbetsmiljö',
#  'och',
#  'jämställdhet',
#  '35',
#  '13.1',
#  'arbetsmiljöpolicy',
#  '35',
#  '13.2',
#  'jämställdhetspolicy',
#  '35',
#  '14',
#  'försäkringspolicy',
#  '36',
#  '14.1',
#  'allmänt',
#  '36',
#  '14.2',
#  'omfattning',
#  '36',
#  '14.3',
#  'tjänstegrupplivförsäkring',
#  'tgl',
#  '36',
#  '14.4',
#  'trygghetsförsäkring',
#  'vid',
#  'arbetsskada',
#  'tfa',
#  '37',
#  '14.5',
#  'kollektiv',
#  'olycksfallsförsäkring',
#  'hos',
#  'if',
#  '37',
#  '14.6',
#  'sjukförsäkring',
#  '38',
#  '14.7',
#  'tjänstereseförsäkring',
#  '39',
#  '14.8',
#  'tjänstepension',
#  '39',
#  '14.9',
#  'sjukvårdsförsäkring',
#  '40',
#  'personalhandbok',
#  '5',
#  '40',
#  'dokument',
#  'författare',
#  'senast',
#  'sparat',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'att',
#  'arbeta',
#  'på',
#  'decerno',
#  'det',
#  'ska',
#  'vara',
#  'roligt',
#  'at',
#  'arbeta',
#  'på',
#  'decerno',
#  'på',
#  'decerno',
#  'förenas',
#  'vi',
#  'kring',
#  'et',
#  'stort',
#  'teknikintresse',
#  'vi',
#  'gillar',
#  'tekniska',
#  'utmaningar',
#  'och',
#  'at',
#  'lösa',
#  'svåra',
#  'problem',
#  'tillsammans',
#  'företagskulturen',
#  'är',
#  'omhändertagande',
#  'utan',
#  'at',
#  'hämma',
#  'egna',
#  'initiativ',
#  'och',
#  'idéer',
#  'decerno',
#  'arbetar',
#  'med',
#  'hela',
#  'uppdrag',
#  'at',
#  'jobba',
#  'tillsammans',
#  'i',
#  'tuﬀa',
#  'projekt',
#  'skapar',
#  'en',
#  'unik',
#  'företagskultur',
#  'det',
#  'du',
#  'inte',
#  'redan',
#  'kan',
#  'får',
#  'du',
#  'lära',
#  'dig',
#  'av',
#  'erfa',
#  'rna',
#  'kollegor',
#  'vi',
#  'bygger',
#  'skräddarsydda',
#  'verksamhetssystem',
#  'och',
#  'vårt',
#  'kundlöfte',
#  'är',
#  'pålitliga',
#  'systemlösningar',
#  'pålitlighet',
#  'innebär',
#  'at',
#  'ta',
#  'ansvar',
#  'för',
#  'helheten',
#  'at',
#  'ha',
#  'överblick',
#  'och',
#  'samtidigt',
#  'kontroll',
#  'på',
#  'alla',
#  'detaljer',
#  'hos',
#  'decerno',
#  'har',
#  'du',
#  'stora',
#  'möjlighet',
#  'at',
#  'ständ',
#  'igt',
#  'vidareutveckla',
#  'din',
#  'kompetens',
#  'dels',
#  'genom',
#  'arbetskamraternas',
#  'erfarenhet',
#  'och',
#  'dels',
#  'genom',
#  'vår',
#  'satsning',
#  'på',
#  'vidareutbildning',
#  'på',
#  'våra',
#  'konferensresor',
#  'diskuterar',
#  'vi',
#  'lärdomar',
#  'från',
#  'våra',
#  'projekt',
#  'både',
#  'vad',
#  'gäller',
#  'teknik',
#  'ledarskap',
#  'och',
#  'aﬀärsmannaskap',
#  'resorna',
#  'går',
#  'till',
#  'när',
#  'och',
#  'fjärran',
#  'platser',
#  'där',
#  'vi',
#  'kan',
#  'krydda',
#  'vistelsen',
#  'med',
#  'berikande',
#  'upplevelser',
#  'alla',
#  'anställdas',
#  'insatser',
#  'är',
#  'avgörande',
#  'för',
#  'at',
#  'företag',
#  'ets',
#  'mål',
#  'och',
#  'vision',
#  'ska',
#  'uppnås',
#  'syftet',
#  'med',
#  'företagets',
#  'personalpolitik',
#  'är',
#  'at',
#  'utveckla',
#  'kunniga',
#  'motiverade',
#  'och',
#  'enga',
#  'gerade',
#  'medarbetare',
#  'decerno',
#  'uppmuntrar',
#  'initiativ',
#  'från',
#  'medarbetarna',
#  'som',
#  'bidrar',
#  'till',
#  'utveckling',
#  'av',
#  'företaget',
#  'en',
#  'kontinuerlig',
#  'kompetensutveckling',
#  'är',
#  'en',
#  'förutsätning',
#  'för',
#  'at',
#  'företagets',
#  'mål',
#  'och',
#  'visioner',
#  'ska',
#  'uppnås',
#  'företaget',
#  'står',
#  'och',
#  'faller',
#  'med',
#  'engagerade',
#  'medarbet',
#  'are',
#  'som',
#  'anstränger',
#  'sig',
#  'för',
#  'at',
#  'leva',
#  'upp',
#  'till',
#  'vår',
#  'gemensamma',
#  'värdegrund',
#  'och',
#  'arbeta',
#  'med',
#  'decernos',
#  'kundlöfte',
#  '”',
#  'pålitliga',
#  'systemlösningar',
#  '”',
#  'som',
#  'mål',
#  'tydlig',
#  'med',
#  'omtanke',
#  'med',
#  'omtanke',
#  'är',
#  'vi',
#  'är',
#  'tydliga',
#  'transparenta',
#  'och',
#  'öppna',
#  'med',
#  'varandra',
#  'vi',
#  'känner',
#  'ansvar',
#  'för',
#  'att',
#  'både',
#  'dela',
#  'och',
#  'söka',
#  'information',
#  'prestigelösheten',
#  'är',
#  'tydlig',
#  'när',
#  'vi',
#  'delar',
#  'med',
#  'oss',
#  'av',
#  'vår',
#  'kunskap',
#  'och',
#  'våra',
#  'lärdomar',
#  'gör',
#  'dig',
#  'själv',
#  'och',
#  'andra',
#  'stolta',
#  'med',
#  'en',
#  'hög',
#  'yrkesheder',
#  'gör',
#  'vi',
#  'vårt',
#  'bästa',
#  'och',
#  'känner',
#  'en',
#  'stolthet',
#  'i',
#  'det',
#  'vi',
#  'levererar',
#  'vi',
#  'står',
#  'för',
#  'våra',
#  'handlingar',
#  'och',
#  'det',
#  'vi',
#  'säger',
#  'utforska',
#  'och',
#  'våga',
#  'pröva',
#  'med',
#  'nyfikenhet',
#  'och',
#  'e',
#  'n',
#  'vilja',
#  'att',
#  'ständigt',
#  'utvecklas',
#  'vågar',
#  'vi',
#  'tänka',
#  'nytt',
#  'och',
#  'testa',
#  'nya',
#  'vägar',
#  'framåt',
#  'vi',
#  'är',
#  'i',
#  'en',
#  'miljö',
#  'där',
#  'vi',
#  'vågar',
#  'spänna',
#  'bågen',
#  'och',
#  'lära',
#  'oss',
#  'av',
#  'våra',
#  'misstag',
#  'vi',
#  'skapar',
#  'värde',
#  'tillsammans',
#  'vi',
#  'agerar',
#  'alltid',
#  'affärsmässigt',
#  'och',
#  'brinner',
#  'för',
#  'att',
#  'göra',
#  'skillnad',
#  'och',
#  'skapa',
#  'värde',
#  'med',
#  'en',
#  'stark',
#  'laganda',
#  'inkluderar',
#  'vi',
#  'respekterar',
#  'och',
#  'uppskattar',
#  'varandras',
#  'olikheter',
#  'personalhandbok',
#  '6',
#  '40',
#  'dokument',
#  'författare',
#  'senast',
#  'sparat',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  '1',
#  'personalhandboken',
#  'denna',
#  'personalhandbok',
#  'gäller',
#  'för',
#  'alla',
#  'bolag',
#  'inom',
#  'dec',
#  'erno',
#  'dvs',
#  'både',
#  'för',
#  'decerno',
#  'ab',
#  'och',
#  'decerno',
#  'väst',
#  'ab',
#  'personalhandboken',
#  'är',
#  'din',
#  'uppslagsbok',
#  'för',
#  'alla',
#  'personalrelaterade',
#  'frågor',
#  'hitar',
#  'du',
#  'inte',
#  'svaret',
#  'på',
#  'din',
#  'fråga',
#  'så',
#  'ställ',
#  'den',
#  'till',
#  'din',
#  'närmsta',
#  'chef',
#  'flertalet',
#  'av',
#  'våra',
#  'anställda',
#  'arbetar',
#  'som',
#  'konsulter',
#  'de',
#  'får',
#  'därför',
#  'störst',
#  'utrymme',
#  'i',
#  'personalhandboken',
#  'de',
#  'som',
#  'arbetar',
#  'i',
#  'andra',
#  'roller',
#  'såsom',
#  'hr',
#  'sälj',
#  'med',
#  'ﬂera',
#  'är',
#  'självklart',
#  'lika',
#  'viktiga',
#  'men',
#  'kan',
#  'i',
#  'något',
#  'högre',
#  'grad',
#  'behöva',
#  'söka',
#  'svar',
#  'från',
#  'närmsta',
#  'chef',
#  'för',
#  'frågor',
#  'som',
#  'är',
#  'speciﬁka',
#  'för',
#  'rollen',
#  'senaste',
#  'versionen',
#  'ﬁnns',
#  'alltid',
#  'tillgänglig',
#  'på',
#  'intr',
#  'anätet',
#  'de',
#  'regler',
#  'och',
#  'f',
#  'örmåner',
#  'som',
#  'ﬁnns',
#  'beskrivna',
#  'i',
#  'handboken',
#  'är',
#  'de',
#  'nu',
#  'gällande',
#  'dessa',
#  'kan',
#  'komma',
#  'at',
#  'ändras',
#  'eller',
#  'justeras',
#  'i',
#  'framtiden',
#  'vi',
#  'strävar',
#  'eller',
#  'at',
#  'alltid',
#  'meddela',
#  'större',
#  'nyheter',
#  'via',
#  'veckobrevet',
#  'men',
#  'det',
#  'är',
#  'varje',
#  'medarbetares',
#  'ansvar',
#  'at',
#  'känna',
#  'till',
#  'de',
#  'regler',
#  'och',
#  'rutiner',
#  'som',
#  'dokumenteras',
#  'i',
#  'handboken',
#  'personalhandboken',
#  'är',
#  'en',
#  'del',
#  'av',
#  'decernos',
#  'ledningssystem',
#  'inka',
#  'som',
#  'ﬁnns',
#  'dokumenterat',
#  'i',
#  'vår',
#  'verksamhets',
#  'handbok',
#  'hela',
#  'verksamhetshandboken',
#  'ﬁnns',
#  'på',
#  'intranätet',
#  'affärsidé',
#  'vi',
#  'ska',
#  'utveckla',
#  'skräddarsydda',
#  'verksamhetssystem',
#  'som',
#  'effektiviserar',
#  'våra',
#  'kunders',
#  'verksamhet',
#  'vi',
#  'tar',
#  'helhetsansvar',
#  'och',
#  'levererar',
#  'hela',
#  'system',
#  'decerno',
#  'skapar',
#  'moderna',
#  'pålitliga',
#  'och',
#  'långsiktiga',
#  'systemlösningar',
#  'decerno',
#  'ska',
#  'vara',
#  'en',
#  'naturlig',
#  'partner',
#  'för',
#  'kunder',
#  'med',
#  'höga',
#  'krav',
#  'på',
#  'sina',
#  'systemlösningar',
#  'kundlöfte',
#  'pålitliga',
#  'systemlösningar',
#  'affärsidé',
#  'vi',
#  'ska',
#  'utveckla',
#  'skräddarsydda',
#  'system',
#  'som',
#  'effektiviserar',
#  'våra',
#  'kunders',
#  'verksamhet',
#  'vi',
#  'tar',
#  'helhetsansvar',
#  'och',
#  'levererar',
#  'hela',
#  'system',
#  'decerno',
#  'skapar',
#  'moderna',
#  'pålitliga',
#  'och',
#  'långsiktiga',
#  'systemlösningar',
#  'decerno',
#  'ska',
#  'vara',
#  'en',
#  'naturlig',
#  'partner',
#  'för',
#  'kunder',
#  'med',
#  'höga',
#  'krav',
#  ...]

# %%
len(word_tokens)
# Out:
# 11191

# %%
# Create a sequence of tokens
# Give the network 50 words
train_len = 50
text_sequences = []

for i in range(train_len, len(word_tokens)):
    seq = word_tokens[i - train_len:i]
    text_sequences.append(seq)
text_sequences
# Out:
# [['vi',
#   'skapar',
#   'värde',
#   'tillsammans',
#   'utforska',
#   'och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med'],
#  ['skapar',
#   'värde',
#   'tillsammans',
#   'utforska',
#   'och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga'],
#  ['värde',
#   'tillsammans',
#   'utforska',
#   'och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav'],
#  ['tillsammans',
#   'utforska',
#   'och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok'],
#  ['utforska',
#   'och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3'],
#  ['och',
#   'våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40'],
#  ['våga',
#   'pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument'],
#  ['pröva',
#   'tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare'],
#  ['tydlig',
#   'med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast'],
#  ['med',
#   'omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat'],
#  ['omtanke',
#   'gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220'],
#  ['gör',
#   'dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3'],
#  ['dig',
#   'själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken'],
#  ['själv',
#   'och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats'],
#  ['och',
#   'andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl'],
#  ['andra',
#   'stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-'],
#  ['stolta',
#   'personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14'],
#  ['personalhandbok',
#   'personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av'],
#  ['personalhandbok',
#   '2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats'],
#  ['2',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl'],
#  ['40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll'],
#  ['dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att'],
#  ['författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta'],
#  ['senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på'],
#  ['sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno'],
#  ['1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5'],
#  ['s3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1'],
#  ['personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken'],
#  ['mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6'],
#  ['dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2'],
#  ['2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll'],
#  ['08-14',
#   'av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal'],
#  ['av',
#   'mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7'],
#  ['mats',
#   'dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3'],
#  ['dahl',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön'],
#  ['vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och'],
#  ['decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner'],
#  ['är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8'],
#  ['bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1'],
#  ['i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy'],
#  ['sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8'],
#  ['på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2'],
#  ['att',
#   'leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön'],
#  ['leverera',
#   'pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar'],
#  ['pålitliga',
#   'system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8'],
#  ['system-',
#   'lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3'],
#  ['lösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus'],
#  ['för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8'],
#  ['kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4'],
#  ['med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh'],
#  ['höga',
#   'krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård'],
#  ['krav',
#   'personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9'],
#  ['personalhandbok',
#   '3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5'],
#  ['3',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion'],
#  ['40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och'],
#  ['dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård'],
#  ['författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9'],
#  ['senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6'],
#  ['sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika'],
#  ['1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och'],
#  ['s3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt'],
#  ['personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på'],
#  ['mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret'],
#  ['dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10'],
#  ['2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7'],
#  ['08-14',
#   'av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån'],
#  ['av',
#   'mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10'],
#  ['mats',
#   'dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8'],
#  ['dahl',
#   'innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon'],
#  ['innehåll',
#   'att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11'],
#  ['att',
#   'arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9'],
#  ['arbeta',
#   'på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning'],
#  ['på',
#   'decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på'],
#  ['decerno',
#   '5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid'],
#  ['5',
#   '1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12'],
#  ['1',
#   'personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4'],
#  ['personalhandboken',
#   '6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy'],
#  ['6',
#   '2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13'],
#  ['2',
#   'koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5'],
#  ['koll',
#   'ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling'],
#  ['ektivavtal',
#   '7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling',
#   'och'],
#  ['7',
#   '3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling',
#   'och',
#   'personlig'],
#  ['3',
#   'lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling',
#   'och',
#   'personlig',
#   'utveckling'],
#  ['lön',
#   'och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling',
#   'och',
#   'personlig',
#   'utveckling',
#   '14'],
#  ['och',
#   'förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
#   '3.9',
#   'blodgivning',
#   'på',
#   'arbetstid',
#   '12',
#   '4',
#   'mobiltelefonpolicy',
#   '13',
#   '5',
#   'kompetensutveckling',
#   'och',
#   'personlig',
#   'utveckling',
#   '14',
#   '5.1'],
#  ['förmåner',
#   '8',
#   '3.1',
#   'lönepolicy',
#   '8',
#   '3.2',
#   'lön',
#   'ersättningar',
#   '8',
#   '3.3',
#   'rekryteringsbonus',
#   '8',
#   '3.4',
#   'företagsh',
#   'älsovård',
#   '9',
#   '3.5',
#   'motion',
#   'och',
#   'friskvård',
#   '9',
#   '3.6',
#   'fika',
#   'och',
#   'frukt',
#   'på',
#   'kontoret',
#   '10',
#   '3.7',
#   'föräldraförmån',
#   '10',
#   '3.8',
#   'bildskärmglasögon',
#   '11',
# ...
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40'],
#  ['kunders',
#   'verksamhet',
#   'vi',
#   'tar',
#   'helhetsansvar',
#   'och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument'],
#  ['verksamhet',
#   'vi',
#   'tar',
#   'helhetsansvar',
#   'och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare'],
#  ['vi',
#   'tar',
#   'helhetsansvar',
#   'och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast'],
#  ['tar',
#   'helhetsansvar',
#   'och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat'],
#  ['helhetsansvar',
#   'och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220'],
#  ['och',
#   'levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3'],
#  ['levererar',
#   'hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken'],
#  ['hela',
#   'system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats'],
#  ['system',
#   'decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl'],
#  ['decerno',
#   'skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-'],
#  ['skapar',
#   'moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14'],
#  ['moderna',
#   'pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av'],
#  ['pålitliga',
#   'och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats'],
#  ['och',
#   'långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl'],
#  ['långsiktiga',
#   'systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2'],
#  ['systemlösningar',
#   'decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal'],
#  ['decerno',
#   'ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom'],
#  ['ska',
#   'vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno'],
#  ['vara',
#   'en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns'],
#  ['en',
#   'naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera'],
#  ['naturlig',
#   'partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala'],
#  ['partner',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter'],
#  ['för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter',
#   'decerno'],
#  ['kunder',
#   'med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter',
#   'decerno',
#   'ab'],
#  ['med',
#   'höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter',
#   'decerno',
#   'ab',
#   'samt'],
#  ['höga',
#   'krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter',
#   'decerno',
#   'ab',
#   'samt',
#   'decerno'],
#  ['krav',
#   'på',
#   'sina',
#   'systemlösningar',
#   'vision',
#   'decerno',
#   'är',
#   'bäst',
#   'i',
#   'sverige',
#   'på',
#   'att',
#   'leverera',
#   'pålitliga',
#   'systemlösningar',
#   'för',
#   'kunder',
#   'med',
#   'höga',
#   'krav',
#   'personalhandbok',
#   '7',
#   '40',
#   'dokument',
#   'författare',
#   'senast',
#   'sparat',
#   '1220',
#   's3',
#   'personalhandboken',
#   'mats',
#   'dahl',
#   '2023-',
#   '08-14',
#   'av',
#   'mats',
#   'dahl',
#   '2',
#   'kollektivavtal',
#   'inom',
#   'decerno',
#   'ﬁnns',
#   'ﬂera',
#   'legala',
#   'enheter',
#   'decerno',
#   'ab',
#   'samt',
#   'decerno',
#   'väst'],
#  ...]

# %%
nltk.download('punkt') # using the punkt tokenizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet') # using the wordnet dictionary
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4') # using the punkt tokenizer
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
sentence_tokens = nltk.sent_tokenize(raw_text)
sentence_tokens
# Out:
# [' \n \n  \nvi skapar värde tillsammans  \nutforska och våga pröva  \ntydlig med omtanke  \ngör dig själv och andra stolta  personalhandbok   personalhandbok  2 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n  \nvision:  \ndecerno är bäst i \nsverige på att leverera \npålitliga system-\nlösningar för kunder \nmed höga krav   personalhandbok  3 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ninnehåll   \natt arbeta på decerno  5 \n1. personalhandboken  6 \n2. koll ektivavtal  7 \n3. lön och förmåner  8 \n3.1 lönepolicy  8 \n3.2 lön, ersättningar  8 \n3.3 rekryteringsbonus  8 \n3.4 företagsh älsovård  9 \n3.5 motion och friskvård  9 \n3.6 fika och frukt på kontoret  10 \n3.7 föräldraförmån  10 \n3.8 bildskärmglasögon  11 \n3.9 blodgivning på arbetstid  12 \n4. mobiltelefonpolicy  13 \n5. kompetensutveckling och personlig  utveckling  14 \n5.1 kompetensutvecklingspolicy  14 \n5.2 konferenser  16 \n5.3 tidredovisning kurs och extern konferens  16 \n6. introduktion av nyanställda  17 \n6.1 introduktion  17 \n6.2 fadder  17 \n7. arbetstider och tidredovisning  18 \n7.1 riktlinjer för arbetstid  18 \n7.2 distansarbete  fel!',
#  'bokmärket är inte definierat .',
#  '8. decernomöten & sociala aktiviteter  21 \n8.1 obligatoriska decernomöten  21 \n8.2 regionala sociala aktiviteter  21 \n8.3 övriga sociala aktiviteter  21 \n9. frånvaro  23 \n9.1 planerad frånvaro  23 \n9.2 föräldraledighet  23 \n9.3 semester  23 \n9.4 läkarbesök  25 \n9.5 sjukfrånvaro  25 \n9.6 permission  27 \n10. utlägg och representation  28 \n10.1 utlägg  27 \n10.2 extern representation  28 \n10.3 intern representation  29 \n10.4 utköp av dator  30 \n11. resor i tjänsten  30 \n11.1 resepolicy  30 \n11.2 ersättning för reskostnad vid långvarigt arbete hos kund  32  personalhandbok  4 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n11.3 traktamente  32 \n11.4 semester i samband med tjänsteresa  33 \n11.5 restid  33 \n12. säkerhet och sekretess  34 \n12.1 sekretess  34 \n12.2 media 34 \n12.3 finansiell information  33 \n12.4 skyddsombud  34 \n12.5 säkerhetsrutiner it & programvarupolicy  34 \n13. arbetsmiljö och jämställdhet  35 \n13.1 arbetsmiljöpolicy  35 \n13.2 jämställdhetspolicy  35 \n14. försäkringspolicy  36 \n14.1 allmänt  36 \n14.2 omfattning  36 \n14.3 tjänstegrupplivförsäkring (tgl)  36 \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  37 \n14.5 kollektiv olycksfallsförsäkring hos if 37 \n14.6 sjukförsäkring  38 \n14.7 tjänstereseförsäkring  39 \n14.8 tjänstepension  39 \n14.9 sjukvårdsförsäkring  40  personalhandbok  5 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \natt arbeta på decerno  \ndet ska vara roligt at arbeta på decerno!',
#  'på decerno förenas vi kring et stort \nteknikintresse.',
#  'vi gillar tekniska utmaningar och at lösa svåra problem tillsammans.',
#  'företagskulturen är omhändertagande utan at \nhämma  egna initiativ och idéer.',
#  'decerno arbetar  med hela uppdrag.',
#  'at jobba \ntillsammans i tuﬀa projekt skapar en unik företagskultur.',
#  'det du inte redan kan får du lära dig av erfa rna kollegor.',
#  'vi bygger skräddarsydda verksamhetssystem och vårt kundlöfte \när pålitliga systemlösningar.',
#  'pålitlighet innebär at ta ansvar för \nhelheten.',
#  'at ha överblick och samtidigt kontroll på alla detaljer.',
#  'hos decerno har du stora möjlighet at ständ igt vidareutveckla din \nkompetens.',
#  'dels genom arbetskamraternas erfarenhet och dels \ngenom vår satsning på vidareutbildning.',
#  'på våra  konferensresor diskuterar vi lärdomar från våra projekt.',
#  'både vad gäller teknik, ledarskap och aﬀärsmannaskap.',
#  'resorna går till när och fjärran platser där vi kan \nkrydda vistelsen med berikande upplevelser.',
#  'alla anställdas insatser är avgörande för at \nföretag ets mål och vision ska uppnås.',
#  'syftet med \nföretagets personalpolitik är at utveckla  \nkunniga, motiverade och enga gerade  \nmedarbetare.',
#  'decerno uppmuntrar initiativ från medarbetarna som bidrar till utveckling av företaget.',
#  'en kontinuerlig \nkompetensutveckling är en förutsätning för at företagets \nmål och visioner ska uppnås.',
#  'företaget står och faller med engagerade medarbet are som \nanstränger sig för at leva upp till vår gemensamma värdegrund och \narbeta med decernos kundlöfte ”pålitliga systemlösningar” som mål.',
#  'tydlig med omtanke  \nmed omtanke är vi är tydliga, \ntransparenta och öppna med \nvarandra.',
#  'vi känner ansvar för \natt både dela och söka \ninformation.',
#  'prestigelösheten \när tydlig när vi delar med oss \nav vår kunskap och våra \nlärdomar.',
#  'gör dig själv och andra \nstolta  \nmed en hög yrkesheder \ngör vi vårt bästa och \nkänner en stolthet i det vi \nlevererar.',
#  'vi står för våra \nhandlingar och det vi \nsäger.',
#  'utforska och våga \npröva  \nmed nyfikenhet och e n vilja att \nständigt utvecklas vågar vi \ntänka nytt och testa nya vägar \nframåt.',
#  'vi är i en miljö där vi \nvågar spänna bågen och lära \noss av våra misstag.',
#  'vi skapar värde \ntillsammans  \nvi agerar alltid affärsmässigt \noch brinner för att göra \nskillnad och skapa värde.',
#  'med en stark laganda inkluderar vi, \nrespekterar och uppskattar \nvarandras olikheter.',
#  'personalhandbok  6 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n1. personalhandboken \ndenna personalhandbok gäller för alla bolag inom dec erno, dvs både för decerno ab och decerno väst \nab.',
#  'personalhandboken är din uppslagsbok för alla personalrelaterade frågor.',
#  'hitar du inte svaret på din \nfråga så ställ den till din närmsta chef.',
#  'flertalet av våra anställda arbetar som konsulter.',
#  'de får därför \nstörst utrymme i personalhandboken.',
#  'de som arbetar i andra roller såsom hr, sälj med ﬂera är \nsjälvklart lika viktiga men kan i något högre grad behöva söka svar från närmsta chef för frågor som är speciﬁka för rollen.',
#  'senaste versionen ﬁnns alltid  tillgänglig på intr anätet  de regler och f örmåner som ﬁnns beskrivna i \nhandboken är de nu gällande.',
#  'dessa kan komma at ändras eller justeras i framtiden.',
#  'vi strävar eller \nat alltid meddela större nyheter via veckobrevet, men det är varje medarbetares ansvar at känna till \nde regler och rutiner som dokumenteras i handboken.',
#  'personalhandboken är en del av decernos ledningssystem inka som ﬁnns dokumenterat i vår verksamhets handbok.',
#  'hela verksamhetshandboken ﬁnns på intranätet.',
#  'affärsidé  \nvi ska utveckla skräddarsydda \nverksamhetssystem som effektiviserar \nvåra kunders verksamhet.',
#  'vi tar helhetsansvar och levererar hela \nsystem.',
#  'decerno skapar moderna, pålitliga och \nlångsiktiga systemlösningar.',
#  'decerno ska vara en naturlig partner \nför kunder med höga krav på sina \nsystemlösningar.',
#  'kundlöfte  \npålitliga \nsystemlösningar  \naffärsidé  \nvi ska utveckla skräddarsydda system \nsom effektiviserar våra kunders \nverksamhet.',
#  'vi tar helhetsansvar och levererar hela \nsystem.',
#  'decerno skapar moderna, pålitliga och \nlångsiktiga systemlösningar.',
#  'decerno ska vara en naturlig partner för \nkunder med höga krav på sina  \nsystemlösningar .',
#  'vision:  \ndecerno är bäst i \nsverige på att \nleverera pålitliga \nsystemlösningar för \nkunder med höga \nkrav   personalhandbok  7 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n2. kollektivavtal  \ninom decerno ﬁnns ﬂera  legala enheter, decerno ab samt decerno väst  ab.',
#  'decerno väst ab följer  almega it -företagens kollektivavtal .',
#  'decerno ab har inte kollektivavtal.',
#  'vissa anställningsvillkor och förmåner regleras av kollektivavtalet och kan därför skilja sig åt.',
#  'deta \nkommer i förekommande fall vara beskrivet i personalhandboken.',
#  'vi strävar eller at så långt det är \nmöjligt ha samma villkor för alla bolag .',
#  'personalhandbok  8 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3. lön och förmåner  \ndecerno erbjuder alla anställda et stort antal \nförmåner och ersätn ingar.',
#  'lönen är en av de största \nmen det ﬁnns också många andra förmåner .',
#  '3.1 lönepolicy  \ndecernos lönepolitik är et medel för at stimulera och belöna goda arbetsinsatser.',
#  'grunden är därför en resultatinriktad lönesätning.',
#  'lönerna skall vara individuella på \net sät som är rätvist och bygger på saklig grund.',
#  'skillnader i lön får aldrig base ras \npå kön.',
#  'löneutvecklingen avgörs av ﬂera faktorer.',
#  'utöver personliga resultat kan det bestämmas av faktorer som arbetets svårighetsgrad och egen personlig utveckling.',
#  'vi är positiva till resultatbaserad bonus så länge denna upplevs som rätvis och sakligt grundad.',
#  'decernos löner skall vara marknadsmässiga.',
#  'vi jämför med relevant \nstatistik på arbetsmarknaden såsom sveriges ingenjörers statistik för civilingenjörer som arbetar med motsvarande arbetsuppgifter.',
#  'mer om vår lönepolicy och lönekriterier ﬁnns at läsa i verksamhetshandboken.',
#  '3.2 lön, ersättningar  \n• lön betalas ut senast den 25:e varje månad  \n• lön utbetalas för innevarande månad \n• semester, ledighet, sjukdom etc regleras månaden eller  \n• under lag för utlägg/resor inlämnas inom två veckor  \n• ersätning för utlägg betalas ut tillsammans med lön  \n3.2.1  löneväxling  \ndecerno erbjuder sina medarbetare löneväxling mot tjänstepension vilket kan vara et sät at höja \nsin totala pension.',
#  'det ﬁnns dock fallgropa r som gör at löneväxling inte lämpar sig för alla.',
#  'prata med \ndin närmsta chef om du är intresserad av at veta mer.',
#  '3.3 rekryteringsbonus  \ndecerno vill erbjuda generös rekryteringsbonus till alla anställda som hjälper oss at hita ﬂera medarbetare.',
#  'för at tipsa om en person till någon av våra rekryteringar, prata med hr .',
#  'vi betalar ut rekryteringsbonus enligt följande förutsätningar:  \n• den anställde tipsar om en person som de tror passar in hos oss som inte tidigare varit i kontakt med oss.',
#  'lön \npension  \nfriskvårds -\nbidrag  \nförmån  \nrekryterings -\nbonus  \nföräldra -\nförmån  \n personalhandbok  9 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n• summan för rekryteringsbonus är : \n10kkr – för juniora upp till 2 års relevant erfarenhet  \n25kkr – för personer med mer än 2 års relevant erfarenhet \n• för tips som  leder till en anställning utbetalas bonusen när personen börjar.',
#  '• rekryteringsbonusen gäller för alla medarbetare som inte har en ledande position inom \ndecerno.',
#  '3.4 företagshälsovård  \ndecerno erbjuder alla anställda företagshälsovård.',
#  'företagshälso vården arbetar förebyggande för at \nvåra anställda inte ska drabbas av någon form av sjukdom.',
#  'i företagshälsovården ingår bl.a.',
#  'regelbundna hälsoundersökningar.',
#  'hälsoundersökningar görs vartannat år.',
#  'hälsoundersökning görs på arbetstid och tidredovisas u nder ”dec admin, intern administration”  som \n”hälsokontroll enl.',
#  'plan” .',
#  'du får m ax registrera 1 timme inklusive restid  för en hälsoundersökning.',
#  '3.5 motion och friskvård \nsom arbetsgivare vill decerno uppmuntra och stöta våra medarbetare at leva et hälsosamt liv.',
#  'därför lämnar vi bidrag till motion och friskvård.',
#  'principen för ersätning är 50/50, d.v.s.',
#  'den anställde betalar hälften och decerno betalar hälften.',
#  'decerno lämnar bidrag för motion och friskvård med 50% av uppgifter upp till 8  000 kr.',
#  'decernos bidr ag \nblir alltså maximalt 4 000 kr per person.',
#  'beloppet räknas per kalenderår, d.v.s.',
#  '1 januari – 31 december.',
#  'decerno har avtal med et ﬂertal gym, bl.a.',
#  'sats, fitness24seven samt friskis  & svettis.',
#  'kontakta hr -\nchef  eller läs på intranätet för mer information.',
#  'vi följer skateverkets anvisningar för  vilka former av motion och friskvård som vi får bidra till.',
#  'se vidare www.skateverket.se\n, sök på motion eller friskvård.',
#  'personliga startavgifter och medlemsavgiter i idrotsföreningar är skatepliktiga och ersäts därför inte.',
#  'det är viktigt at det kvito som du lämnar in innehåller de uppgifter som krävs för at decerno ska få avdrag för kostnaden och at du ska kunna få ersätning för dina utlägg.',
#  'är du det minsta osäker på vad \nsom gäller, kontakta ekonomiavdelningen.',
#  'personalhandbok  10 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3.6 fika och frukt på kontoret  \nvåra ﬁkastunder tillsammans är viktiga tillfällen för at uppräthålla våra sociala kontakter på \narbetsplatsen.',
#  'här får man träﬀ a och diskutera med kollegor från andra projekt  eller avdelningar  som \nman kanske annars inte har så mycket daglig kontakt med.',
#  'vi ﬁkar tillsammans två gånger per dag .',
#  'vid distansarbete vill vi uppmuntra våra medarbetar e at boka \nin teams -ﬁka med varandra.',
#  'till morgonﬁkat på onsdagar serveras det frukost och på ellermiddagen på fredagar har vi fredagsﬁka \ndär det förutom kaﬀe och te serveras något got.',
#  'ansvaret för at ﬁxa fredagsﬁka, och at säta på kaﬀe och te till ﬁkarasterna går runt mellan alla som \narbetar  på kontoret.',
#  'vi får också frukt levererad till kontoren.',
#  '3.7 föräldraförmån  \n3.7.1  syfte  \ndecerno vill visa at familjen är viktig genom at underläta för småbarnsföräldrar, såväl mammor som \npappor, at utnytja den lagstadgade rättgheten at vara hemma med sit barn.',
#  'därför ger vi extra \nersätning utöver den man får från försäkringskassan .',
#  'föräldralönen ska underläta rekrytering av \nmedarbetare med hög kompetens.',
#  'föräldralönen ska också främja jämställdheten och int e minst \nmotivera även pappor at ta ut föräldraledighet.',
#  'föräldralönen gör at inkomstbortfallet vid föräldraledighet blir något mindre.',
#  'pension  betalas också in  i upp till 13 månader under föräldraledighet .',
#  'vi följer regelverket i a lmega it -företagens kollektivavtal som beskrivs nedan.',
#  '3.7.2  ledighet ens förläggning \nden anställde ska i god tid, ca 3  månader före ledighetens början, tillsammans med sin chef planera \noch komma överens om ledighetens förläggning.',
#  'ledigheten ska om möjligt förläggas så at verksam heten inte påtagligt störs.',
#  '3.7.3  ersättning vid föräldraledighet  \nunder tid som medarbetaren är föräldraledig utbetalas ersätning enligt följande under förutsätning at medarbetaren haft oavbruten anställning hos arbetsgivaren under minst et år före den först a dagen \nav föräldraledighet.',
#  'för en sammanhängande tretiodagarsperiod av föräldraledighet med hel föräldrapenning utbetalas \nen månadslön minus 30 sjukavdrag beräknat per dag enligt nedan.',
#  'avdraget baseras på 10 prisbasbelopp.',
#  'ersätning utges för två såda na tretiodagarsperioder.',
#  'för den som har tre års oavbruten \nanställning hos arbetsgivaren före den första dagen av föräldraledighet utges ersätning för sex tretiodagarsperioder.',
#  'antal tretiodagarsperioder av föräldralön enligt tabell nedan :  personalhandbok  11 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nanställnings tid vid företaget  1 år 3 år \nantal tretiodagarsperioder av föräldralön  2 6 \nden föräldralön arbetsgivaren ska betala beräknas genom at avdrag görs från lönen enligt nedan.',
#  'med \nbasbelopp avses prisbasbelopp.',
#  'avdrag/dag:   \nmånadslön  om högst  10 x basbeloppet/12  90%  x månadslönen  x 12 \n             365 \n \nmånadslön  över  10 x basbeloppet/12  90%  x månadslönen  x 12   + \n       365 \n \n10%  x (månadslönen  x 12 – 10 x basbeloppet ) \n365 \n \nersätning utges ej på lönedelar  över 15 prisbasbelopp.',
#  'vid tre fjärdedels, halv, en fjärdedels eller en åtondels föräldrapenning utbetalas tre fjärdedelar, \nhälften, en fjärdedel respektive en åtondel av belopp enligt ovan.',
#  'decerno erbjuder en utökad föräldraförmån och förlänger perioden för den som väljer at vara föräldraledig på deltid.',
#  'ersätningen kan dock inte överstiga det belopp som hade betalats ut vid 100% föräldraledighet.',
#  'ersätning utges för tretiodagarsperiod som infaller inom 24 månader räknat från barnets födelse eller \nvid erhållande av vårdnad i samband med adoption.',
#  'har föräldrapenning nedsats/indragits enligt lagen \nom allmän försäkring ska ersätning enligt ovan reduceras i motsvarande mån.',
#  '3.7.4  utbetalning \nföräldraförmånen betalas ut i samband med övriga löneutbetalningar, dvs.',
#  'den 25:e i månaden eller \nutagandet av föräldraförmånen.',
#  'tiden då man tar ut föräldraförmån ska tidredovisas under ”frånvaro”  som ”dec föräldraförmån”.',
#  'ange \nockså namnet på barnet so m du är föräldraledig för.',
#  '3.8 bildskärm glasögon \nnär dina privata glasögon inte räcker till framför skärmen, står vi som din arbetsgivare för et par kompleta glasögon med din styrk a anpassade eller skärmarbete, inklusive synundersökning hos \noptiker.',
#  'inköp a v glas och bågar sker hos  synoptik eller smartey es med vilka vi har avtal.',
#  'kostnaden \nfaktureras därmed direkt till decerno.',
#  'glastyperna som ingår är enkelslipade glas, närprogressiva glas och rumsprogressiva glas.',
#  'optikern gör \nbedömningen under synundersökningen vilka glas som passar dit synfel och arbete bäst.',
#  'inför dit besök hos optikern behöver du och närmsta chef fylla i och signera en rekvisition som du till \nundersökningstillfä llet.',
#  'kontakta  hr för rekvisition .',
#  'personalhandbok  12 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3.9 blodgivning på arbetstid  \nhos decerno har du möjlighet at ge blod på arbetstid.',
#  'det råder ofta brist på blod och vi vill därför \nuppmuntra och göra lätare at ge blod.',
#  'tiden registreras som ”intern admin ” som ”  blodgivnin g” och \nmed max en timme inklusive restid.',
#  'personalhandbok  13 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n4. mobiltelefonpolicy \nmobiltelefon är et viktigt och nödvändigt arbetsredskap och därför erbjuder decerno följande lösning:  \ntvå prismodeller vid inköp av valfri mobiltelefon.',
#  'alternativ 1 – väljer man at behålla sin telefon i 2 år får kostnaden uppgå till 8  000 kr inkl.',
#  'moms.',
#  'alternativ 2 – väljer man at behålla sin telefon i 3 år får kostnaden uppgå till 12  000 kr inkl.',
#  'moms.',
#  'meddela din närmsta chef innan köpet av telefon om du önskar nytja alternativ 1 eller 2.  \nman kan också välja at köpa en dyrare telefon och betala mellanskillnaden själv.',
#  'då  inköpsbeloppet \növerskrider maxgränsen dras mellanskillnaden inkl.',
#  'moms av som netolöneavdrag på kommande lön .',
#  'mellanskillnaden tillfaller decerno och återbetalas ej vid inköp av ny telefon eller avslutad anställning.',
#  'vi har abonnemang hos telia till fastpris där det ingår fria samtal, sms och mms inom sverige.',
#  'dessutom \ningår mobilsurf med 15 gb per månad.',
#  'samtliga kostnader utöver det som ingår i fastprisabonnem anget betalas av den anställde om man inte \nkan visa at det är arbetsrelaterat.',
#  'förlust /stöld  av mobiltelefon skall omgående meddelas till närmsta chef som då informerar it at \ntömma telefonen på information.',
#  'om telefonen går sönder så betalar decerno reparationen.',
#  'i det fall den inte går at laga eller inte är \nvärd at laga så ersäts telefonen med en likvärdig produkt.',
#  'vid inköp av telefon anmäls deta till kontorsassistent  som registrerar telefonen i vårt register.',
#  'utbyta telefoner kasseras.',
#  '4.1 hörlura r \ndecerno erbjuder alla sina anställda inköp av  hörlurar för et värde upp till 1  500 kr inkl.',
#  'moms.',
#  'inköp kan ske vartannat år och ska godkännas i förväg av närmsta chef.',
#  'inköp sker av den anställde själv och redovisas som utlägg i skovik.',
#  'om inköpsbeloppet överskrider maxgränsen anges endast maxbeloppet om 1  500 kr inkl.',
#  'moms i \nskovik.',
#  'i annat fall returneras utläggsredovisningen.',
#  'utbyta hörlurar kasseras.',
#  'personalhandbok  14 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n5. kompetensutveckling och personlig \n utveckling \n5.1 kompetensutveckling spolicy  \nkompetensutveckling är viktigt både för den personliga utvecklingen och \nför företagets utveckling.',
#  'vi satsar därför mycket på deta område.',
#  'samtidigt är det viktigt at poängtera at varje medarbetare själv ansvarar för sin \nkompetensutveckling.',
#  'till kompetensutveckling räknar vi all tid som hamnar på projekt inom \nverksamhetsområdet utbildning.',
#  'exempel på utbildning är rena kurser och \ndeltagande i konferenser som båda bokas med godkännande av närmaste \nchef.',
#  'annan utbildning är egen utbildning som fås genom inläsning av manualer/böcker/kursliteratur eller dylikt.',
#  'till utbildning räknas även \nkonferenser som decerno själva anor dnar.',
#  '5.1.1  målsättning  \n• 80 timmar per person och år och heltidsanställd avsäts för utbildning \n• eget ansvar at fortbilda sig  \n• närmsta chef godkänner utbildningen  \ndecernos mål för varje medarbetares är at ca 80 timmar per år av betald arbetstid skall avsätas för \nutbildning/vidareutveckling.',
#  'det motsvarar ca 5 % av en individs tillgängliga produktiva tid och är en \nrimlig målsätning för varje organisation.',
#  'därutöver är det vår förhoppning at var och en själv förkovrar \nsig yterligare genom at hålla sig à jour med vad som händer genom at läsa fackpress och intressant \nliteratur vid sidan om sit arbete.',
#  'det är i första hand medarbetarens eget ansvar och intresse at fortbilda sig.',
#  'den huvudsakliga utbildningen sker via projekten.',
#  'närmsta chef skall tillse at den \nutbildning som företaget bekostar ligger i båda parternas intresse.',
#  'för juniorkonsulter har chefen et \nsärskilt ansvar at både rekommendera och säkerställa at utbildning blir av och at den följer en röd \ntråd i konsultens utveckling.',
#  'tre dagar per år reserveras för den övergripande utbildning/vidareutveckling som decerno genomför \npå sina interna konferenser och den förkovring kring företagande, företagets utveckling och projekt \nsom genomförs på dessa konferenser.',
#  'sammantaget brukar vi dessutom avsäta yterligare tid för dessa \nvår- och höstkonferenser.',
#  'et riktmärke för den utbildning/vidareutveckling som decerno anser at man skall genomgå är at ca fyra dagar av tiden skall användas till utbildning/utveckling som syftar till sådant man kansk e inte just \nnu har avsätning för.',
#  'kunskaper som kan vara roliga, stimulerande eller framåtsyftande i arbetsrollen.',
#  'övrig utbildningstid bör anslås till konkret utbildning inom det ansvarsområde och arbete som man håller på med just nu.',
#  'sådan utbildning ä r den som får de mest positiva och konkreta resultaten enligt \nvår erfarenhet.',
#  'kurs  \nkonferens -\nresa  \ndec \nacademy  \nmedarbetar -\nsamtal   personalhandbok  15 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n5.1.2  dec academy  \ndec academy är vårt interna forum för kompetensutveckling.',
#  'syftet med dec academy är at skapa en \nmötesplats för diskussion och kunskapsutbyte om tekniska och andra a rbetsrelaterade frågor som är  \nviktiga för individen och decerno.',
#  'med viktigt menar vi viktigt på tre sät:  \n• teknik –  vi måsta ha tillgång till de metoder och verktyg som behövs för at skapa pålitliga \nsystemlösningar.',
#  '• kompetens – vi måste underhålla och utv eckla personalens kompetens så at de får en \npersonlig utveckling och behärskar de verktyg och metoder de behöver.',
#  '• marknad – vi måste se till at vi har just den kompetens som marknaden ellerfråg ar de \nnärmaste åren.',
#  'dec academy anordnar kompetens -seminarium där alla konsulter får delta.',
#  'seminarierna kan vara \nhelt interna eller med någon extern föredragshållare.',
#  'alla anställda uppmuntras at komma med egna idéer om vilka ämnen de vill beröra.',
#  'aktiviteterna sker på betald arbetstid men oftast utanför ordin arie arbetsdag.',
#  'tid för decacademy \ntidredovisas under ”dec /decv/  kompetens, personlig kompetensutveckling”  som ”decacademy”.',
#  '5.1.3  medarbetarsamtal  \nsyftet med medarbetarsamtalet är at ha en personlig dialog om hälsa och välbeﬁnnande, at prata om \ndin arbetssituation, at tydliggöra förväntningar, at följa upp prestation mot sata mål, at stimulera \noch utveckla din kompetens, at skapa et bra arbetsklimat, at fastställa individuella mål i enlighet med \nföretagets mål, at fastställa en personlig utve cklingsplan samt at ge underlag för planering och \nutveckling av decernos processer.',
#  'medarbetarsamtal sker en gång per år enligt särskild mall och kompleteras senare med et \nuppföljningssamtal samt et lönesamtal.',
#  'medarbetarsamtalet är et dubbelriktat samtal och din feedback till din chef är lika viktig som chefens \nfeedback till dig.',
#  'under samtalet ska man säta upp personliga mål och fastställa en kompetensutvecklingsplan.',
#  '5.1.4  mentor  \nsom en del av din kompetensutveckling ﬁnns det möjlighet at få en mentor.',
#  'decernos \nmentorskapsprogram är tänkt at vara under et år med målet at det ska leda till personlig och \nprofessionell utveckling, både för adept och mentor.',
#  'genom at som adept ta  hjälp av en mentor som \nhar viktig erfarenhet, kompetens och nätverk får du möjlighet at utvecklas och bli bätre på at \nhantera en situation, dit yrke eller en miljö.',
#  'en mentor är et stöd och et bollplank i din yrkesroll.',
#  'mentorns uppgift är at på o lika sät medverka \ntill din utveckling och at stödja och utmana dig utifrån den målsätning du har.',
#  'det kan vara lämpligt at ha en mentor om man:   \n• anställs som nyutexaminerad  \n• om du vill påverka din egen utveckling och är beredda at ta dig an nya uppgifter   personalhandbok  16 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n• om man tar sit första uppdrag i en ny roll, exempelvis som projektledare eller systemarkitekt  \n• i samband med rehabilitering  \nsom mentor får du möjlighet at dela med dig av den kunskap som du byggt upp under dit arbetsliv \nsamt öva på at vägleda o ch inspirera dina mindre erfarna kollegor, och på så vis utveckla \nledarskapsförmågor.',
#  'läs mer om vårt mentorskapsprogram på intranätet och prata med din närmsta chef om du tycker at \ndet skulle vara aktuellt för dig at ha en mentor.',
#  '5.2 konferenser \nvåra konf erenser är en mycket viktiga såväl för kompetensutveckling som för at bygga vår \nföretagskultur.',
#  'vi brukar arrangera två konferenser per år.',
#  '5.2.1  sommarkonferens  \nsommarkonferensen är normalt en kortare konferens med en heldag och ev övernatning.',
#  'programmet är en kombination av kompetensutveckling, information, team -building och sociala \naktiviteter.',
#  '5.2.2  höstkonferens  \nhöstkonferensen är en av de största satsningarna vi gör.',
#  'varje år samlas hela personalen för at under \nnågra intensiva dagar lära sig av varandra och uppleva saker tillsammans.',
#  'konferensen är mycket \nviktig både för kompetensutveckling och företagskultur.',
#  'höstkonferensen brukar genomföras i form av en resa.',
#  'vi har som tradition at krydda et intensivt konferensprogram med gemensamma upplevelser och besö k. vi har under åren besökt de ﬂesta av \nvärldens hörn, alltifrån japan till svalbard och mexiko.',
#  'vår höstkonferens är traditionellt en något längre konferens.',
#  'den brukar sträcka sig över två till tre arbetsdagar och en helg.',
#  'konferensens längd och resmål varierar och beror bland annat på hur det \ngår för bolaget.',
#  'höstkonferensen arrangeras av en resegrupp som består av  medarbetare på decerno.',
#  'för at möjliggöra de påkostade resor vi gör krävs at den anställde lägger viss egen tid.',
#  'den tid av \nkonferensen so m sker på arbetsdagar räknas som arbetstid och 8h per arbetsdag redovisas  på \n”dec /decv  kompetens, personlig kompetensutveckling”  som ”konferens intern” .',
#  'det ﬁnns också en \nspeciell aktivitet för förberedelser.',
#  'övrig tid under resan står den anställde för.',
#  '5.3 tidredovisning kurs och extern konferens  \nvid deltagande i externa kurser och konferenser redovisas max 8 timmar per dag inkl.',
#  'restid.',
#  'tid på \nhelgdagar redovisas inte.',
#  'kurs/konferens tidredovisas under ”dec /decv  kompetens, personlig kompetensutveckling”  som \n”konferens  extern”  eller ”kurs/seminarium” .',
#  'personalhandbok  17 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n6. introduktion av nyanställda  \n6.1 introduktion  \ndet är mycket viktigt at man som nyanställd får en bra introduktion och et got första intryck av \nföretaget.',
#  'et par gånger per år hålls introduktionsdagar där alla som anställts det senaste halvåret bjuds in .',
#  'utöver introduktions dagen  är det mycket viktigt at den nyanställda får träﬀa de personer som är \nviktiga för at komma igång med arbetet.',
#  'det bästa sätet at komma in och lära känna verksamheten \när alltid at arbeta i et projekt.',
#  'en plan för den nyanställdas första tid tas fram tillsammans med \nnärmsta chef.',
#  'uppföljning av introduktionen sker genom samtal med närmsta chef respektive hr eller 3 respektive \n6 månader.',
#  'däreller tar ordinarie rutiner med utvecklingssamtal vid.',
#  '6.2 fadder  \nvårt mål är at alla som börjar hos oss på decerno ska få bästa möjliga introduktion och et got första \nintryck av oss som arbetsplats.',
#  'det är därför viktigt at vi alla tänker på at göra det vi kan för at \nunderläta för våra nyanställda, både i at komm a in i arbetet och i gemenskapen.',
#  'oavset om det \nhandlar om at bjuda med på ﬁka/lunch eller svara på frågor om arbetet.',
#  'det kan också vara bra at ha \nyterligare en person at vända sig till, utöver sin närmsta chef om det dyker upp frågor mm.',
#  'alla \nnyan ställda får därför en fadder som har särskilt ansvar för at vara till stöd under de första 3 \nmånaderna .',
#  'ska du vara fadder åt en nyanställd?',
#  'tydligare riktlinjer ﬁnns hos hr/närmsta chef.',
#  'personalhandbok  18 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n7. arbetstider och tidredovisning \n7.1 riktlinjer för arbetstid  \nnormal arbetstid är 40 timmar  per vecka .',
#  'vi har ﬂexibel arbetstid och du kan själv styra när du arbetar \nunder förutsätning at det fungerar med dit projekt.',
#  'stäm av dina önskemål med din projektledare.',
#  '7.1.1  tidredovisning och tidbank  \nv årt system för at registrera a rbetad tid kallas maya.',
#  'i maya registreras all arbetad tid och eventuell \nfrånvaro.',
#  'varje vecka klarmarkeras av den anställde och atesteras sedan av närmsta chef, eller i vissa fall av din \nprojektledare.',
#  'vid månadsskifte ska du fakturaklarmarkera.',
#  'för at vår fakturering ska hinnas med \nenligt plan måste deta göras senast kl 8 den 1:a arbetsdagen i månaden.',
#  'lediga dagar är, förutom röda helgdagar  \n\uf0a7 midsommarafton  \n\uf0a7 julafton  \n\uf0a7 nyårsafton  \n\uf0a7 de år som naftonaldagen infaller på en lördag eller söndag \nfår medarbetaren 8h extra i sin tidbank för at kunna vara \nledig en annan dag.',
#  'den anställde planerar själv sin tid i samråd med projektledare/chef.',
#  'eventuell tid utöver ordinarie arbetstid sparas  i en tidbank i maya.',
#  'tid i tidbanken tas antingen ut i ledighet timme mot timme eller i \npengar.',
#  'det är tillåtet at ha minus i tidbanken, dock max 40 timmar.',
#  'du kan  göra avbrot i arbet et för privata ärenden under en arbetsdag, exempelvis bankärenden, b esöka \nsociala medier mm.',
#  'dessa ärenden får utföras f örutsat  at de  inte rapporteras  som arbetstid .',
#  'du kan få timmar från tidbanken utbetalda i pengar.',
#  'varje timme är värd ca månadslönen/166.',
#  'meddela ekonomiavdelningen i sådant fall.',
#  'om tidbanken överstiger 200 timmar betalas de \növerstigande timmarna över 150 timmar automatiskt ut.',
#  'denna utbetalning görs månaden eller varje \nkvartal.',
#  '7.1.2  personplanering  \nför at våra projektledare ska veta hur mycket resurser de har tillgängliga och vi ska kunna planera och prognosticera vår verksamhet ska alla konsulter planera sin tid.',
#  'planeringen görs tillsammans \nmed din projektledare och läggs in i maya.',
#  'planeringen ska uppdateras minst inför varje månadsskifte.',
#  'kom ihåg!',
#  'fakturaklarmarkera  \n i maya senast kl 8 \nden 1:a arbetsdagen \ni månaden.',
#  'personalhandbok  19 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n7.2 policy för distansarbete  \nvi tror på et ﬂexibelt arbetssät.',
#  'et ﬂexibelt arbetssät ger större frihet och kan bidra till en bätre \nbalans mellan arbete och fritid.',
#  'vi erbjuder därför våra medarbetare möjlighet at arbeta på distans \nunder förutsätning at de aktuella arbetsuppgifterna är lämpade och at omständigheterna medger \ndet.',
#  'många arbetsuppgifter lämpar sig bra för at utföra på distans.',
#  'samtidigt vill vi som arbetsgivare \nskapa en bra arbetsmiljö med stark företagskultur, gemenskap och laganda som stärks av at träﬀas fysiskt.',
#  'vi månar därför om  en balans mellan arbete på distans och på plats.',
#  'omfattning  \nmöjlighet till distansarbete och vilken omfatning som är lämplig, avgörs i samråd mellan \nmedarbetare, projektledare och närmsta chef där ömsesidigt förtroende utgör grunden.',
#  'möjligheten \ntill dis tansarbete kan över tid ändras beroende på exempelvis aktuella arbetsuppgifter, personliga \nförhållanden och verksamhetens behov.',
#  'arbetsgivaren kan alltid begära närvaro på arbetsplatsen.',
#  'denna policy omfatar distansarbete inom sverige.',
#  'vi är generellt positiva även till distansarbete \nutanför sverige men det arbetsrätsliga regelverket försvårar deta.',
#  'då skateregler, giltighet för \nförsäkringar etc skiljer sig från land till land måste deta alltid överenskommas tillsammans med vår \nhr-avdelning.',
#  'medarbetar en ansvarar själv för at ta reda på vilka regler som gäller i det aktuella \nlandet.',
#  'arbetstid och tillgänglighet  \nvid distansarbete ska medarbetaren vara tillgänglig på samma sät som vid arbete på kontoret under \nordinarie arbetstid.',
#  'det är viktigt at upp räthålla en nära kontakt med sina kollegor.',
#  'digitala \narbetsverktyg ska hållas uppdaterade med status och/eller annan information för at kunna bedriva det dagliga arbetet på et väl fungerande sät både för egen del och gentemot kollegor.',
#  'arbetsmiljö  \nen förutsätning för distansarbete är at medarbetaren har et arbetsutrymme utformat på et \nlämpligt sät.',
#  'arbetstagaren ska se till at arbetsplatsen är utformad och inredd på et ur \narbetsmiljösynpunkt lämpligt sät.',
#  'vid distansarbete ska chefen och medarbe taren samverka för at åstadkomma en hållbar arbetsmiljö.',
#  'arbetstagaren accepterar at arbetsgivaren eller kontakt med arbetstagaren får besöka denne på distansarbetsplatsen eller på annat lämpligt sät kan säkerställa sit arbetsmiljöansvar.',
#  'se vidare 115 0 arbetsmiljöpolicy.',
#  'utrustning  \nvid distansarbete kan medarbetaren, eller individuell behovsprövning, låna viss utrustning och \narbetsverktyg eller överenskommelse mellan medarbetare och chef.',
#  'medarbetaren svarar för en \nstabil internetuppkoppling.',
#  'det kommer alltid at ﬁnnas tillgång till plats och utrustning på våra kontor men vid omfatande \ndistansarbete kan tillgång till egen plats komma at begränsas.',
#  'personalhandbok  20 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsekretess  \narbetstagaren har en lojalitetsplikt mot arbetsgivaren även vid  distansarbete och ska iakta sekretess \nmed de uppgifter hen hanterar i distansarbetet enligt samma regler som på arbetsplatsen.',
#  'övrigt  \narbetstagaren har inte rät till restidsersätning eller traktamente i annan utsträckning än enligt \nföretagets policy oc h inte i något fall för resor mellan distans - och huvudarbetsplatsen.',
#  'personalhandbok  21 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n8. decernomöten & sociala aktiviteter  \ndecerno anordnar decernomöten  av två typer: obligatoriska och sociala.',
#  'de obligatoriska är av \ninformativ karaktär medan sociala möten handlar om at ha kul tillsammans med sina kollegor.',
#  'mötena är dels et forum för at förmedla information och dels et sät at bätre lära känna sina  \nkollegor och skapa en starkare företagskultur.',
#  '8.1 obligatoriska decernomöten  \nde obligatoriska informativa mötena som hålls är företagsinfo, regionmöten och gruppmöten.',
#  'se mer \nutförlig information om respektive mötesform och tidsrapportering nedan:  \ndedcerno info- en gång i månaden håller vd företagsinfo online för alla medarbetare.',
#  'här presenteras \nföretagsövergripande information, ekonomiskt utfall med mera.',
#  'regionmöten - var 4 -8:e vecka hålls det regionmöten i göteborg och stockholm.',
#  'innehållet för dessa \nmöten kan vara information om vad som händer i våra projekt, resultat för enheterna med mera.',
#  'oftast \nerbjuds mat på mötena som antingen hålls på kontoret eller i en extern lokal.',
#  'gruppmöten-  var 4 -8:e vecka håller respektive konsultchef i gruppmöten med sina med arbetare.',
#  'et \nviktigt mål med dessa möten är at skapa ﬂer möjligheter till dialog mellan chefer och medarbetare i \nen mindre grupp där det lätare för alla at komma till tals.',
#  'vid behov förekommer det även at lokala kontorsmöten hålls.',
#  'deltagande på de ssa möten är obligatoriskt och tiden tidsredovisas under ”dec/decv admin, intern \nadministration” som ”företagsmöte”.',
#  'tid för förberedelse inför dessa typer av möten tidsredovisas under ”dec/decv admin, intern administration” som ”förberedelse ftg -möte/aktivitet ”.',
#  '8.2 regionala sociala aktiviteter   \nunder året anordnas kontinuerligt olika sociala aktiviteter .',
#  'det är viktigt för oss at vi har roligt \ntillsammans även utanför projekten!',
#  'exempel på aktiviteter kan vara en aw, matlagning tillsammans, \nteaterbesök ell er go -cart, möjligheterna är oändliga!',
#  'de sociala aktiviteterna är naturligtvis frivilliga \noch räknas inte som arbetstid.',
#  'det är viktigt at aktiviteten är öppen för alla at anmäla sig till, även \nom det kan ﬁnnas begränsningar på antalet som kan delta i själva aktiviteten (tex de första 20 som \nanmäler sig får plats).',
#  'decerno täcker delar eller hela kostnaden för aktiviteten.',
#  'hur de sociala \naktiviteterna organiseras skiljer sig mellan regionerna ost, syd och väst.',
#  'i region ost och syd uppmuntrar vi de anst ällda at själv ta initiativ till sociala aktiviteter.',
#  'om du har \nen idé på något du skulle vilja göra tillsammans med dina kollegor så tveka inte at kontakta ulrika för \nregion ost eller viktor för region syd.',
#  'de hjälper till med planeringen av aktiviteten  och säkerställer \nat det passar in i kalendern med andra planerade arrangemang och at vi får en bra bredd i utbudet \nav aktiviteter.',
#  'i region väst så cirkulerar ansvaret medarbetare som tillsammans 2 och 2 anordnar aktiviteter enligt et schema.',
#  'personalhandbok  22 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ntid för förberedelse inför en social aktivitet tidredovisas under ”dec/dec v admin, intern \nadministration” som ”förberedelse ftg -möte/aktivitet”.',
#  'själva aktiviteten sker utanför arbetstid och \ntidredovisas ej.',
#  '8.3 övriga sociala aktiviteter  \nutöver ovan beskrivna aktiviteter anordnas även julfest och sommarfest vilka kan variera lite från \nkontor till kontor.',
#  'sociala aktiviteter kan oc kså anordnas per team eller projekt.',
#  'personalhandbok  23 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n9. frånvaro  \n9.1 planerad f rånvaro  \nfrånvaro ska planeras så långt i förväg som möjligt och ska stämmas av med projektledare f ör at vi ska \nkunna planera våra projekt .',
#  'vid planerad frånvaro i 3  dagar eller mer gör du  en frånvaro ansökan via \nmaya senast 1 månad innan  den planerade frånvaron .',
#  'glöm inte at också uppdatera din \npersonplanering.',
#  '9.2 föräldraledighet  \n9.2.1  ansökan om föräldraledighet  \nvid föräldraledighet under längre tid är det viktigt at du i god tid, minst 3  månader innan, an söker om \nledighet .',
#  'när föräldraledigheten  har beviljats meddelar du ekonomiavdelningen  för at lönehantering \noch pens ionsavsätningar ska bli korrekta.',
#  'för at utnytja vår föräldraförmån så behöver du ansöka i \nmaya med dec föräldraförmån för de månader so m du har rät till.',
#  'förutom föräldraledighet har du också rät at gå ned i arbetstid fram till dess at dit barn fyller åta år.',
#  'vid föräldraledighet i mer än 3 månader till 10  % eller mer ändras tjänstgöringsgraden i maya till den \narbetstid som godkänts  via frånvaroansökan.',
#  'pensionspremien beräknas utifrån den nya lönen.',
#  'om du skulle arbeta enstaka timmar under din föräldraledighet så redovisar du tiden för dessa timmar \noch de  blir plustimmar i din tidbank.',
#  '9.2.2  sjukvårdsförsäkring  \nunder den tid som du inte f år någon ersätning från decerno  under din föräldraledighet  så sparas \nförmånsbeskatningen till din första lön då du är tillbaka i arbetet.',
#  '9.3 semester  \ninom decerno tillämpar vi två olika upplägg för semester.',
#  'deta beror på at historiken har set olika \nut i de bolag som  idag  ingår i decerno.',
#  'kontakta löneavdelningen om du är osäker på vad som gäller \nför dig.',
#  '9.3.1   semesterår 1 april –  31 mars   \nvår standardmodell är baserat på semesterlagen oc h avser semesterår et 1 april – 31 mars med \nintjänandeår följt av utags år.',
#  'det innebär at  man  under sit första anställningsår arbetar in semester dagar  som sedan kan ta s ut \nunder det kommande semester året.',
#  'personalhandbok  24 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n9.3.1.1  semesterår 1 januari –  31 december     \nnågra medarbetare har av historiska skäl s emesterår et 1 januari – 31 december .',
#  'då sammanfallande \nintjänandeår och utags år innebär at man  arbetar in semesterdagar samma år som de ﬁnns \ntillgängliga at nytja.',
#  'vid avslutad anställning görs en avräkning mot intjänade semesterdagar  och en eventuell skuld \nkomm er at kvitas mot  din slut lön.',
#  '9.3.2  förskottssemester  \nvi erbjuder förskotssemester vilket innebär at du kan få möjlighet at vara ledig redan under dit \nförsta anställningsår i form av semester utan löneavdrag .',
#  'om du påbörjar din anställning före 1 september har du möjlighet at ta ut 30 förskotsdagar första \nåret och om du börjar din anställning eller den 1 september har du rät at ta ut 5  semesterdagar .',
#  'under dit andra anställningsår får d u tillgång till de semesterdagar du tjänat in under dit första \nanställningsår.',
#  'de semesterdagar som du ännu inte har arbetat in fylls ut med förskotssemester  upp \ntill din semesterrät  och med hänsyn tagen till eventuellt ej semestergrundande frånvaro.',
#  'exempel: du anställs den 1 oktober.',
#  'fram till den 31 mars kan du ta ut 5 dagar i förskotssemester.',
#  'den 1 april får du 30 nya semesterdagar.',
#  'ellersom du bara hunnit arbeta in semester under 6 \nmånader är 15 av dessa dagar betalda och resterande dagar blir fö rskotssemester.',
#  'vid avslutad anställning inom 5 år från dit anställningsdatum sker en avräkning mot intjänade dagar \noch en eventuell skuld kvitas mot  din slutlön .',
#  '9.3.3  obetalda semesterdagar  \nvid avstående av nytjande till förskotssemester så har man som an ställd i en lighet med \nsemesterlagen rät at ta ut obetald semester.',
#  'om du påbörjar din anställning innan  1 september har du rät ta ut 25 obetalda  semester dagar och \nom du börjar din anställning den 1 september eller senare har du rät at ta ut 5 obetalda \nsemesterdagar .',
#  '9.3.4  riktlinjer för semesteruttag  \nenligt semesterlagen har v arje arbetstagare har rät till en sammanhängande semester på minst fyra \nveckor under perioden juni – augusti.',
#  'endast i undantagsfall får semestern förl äggas till annan tid.',
#  'för at vi ska kunna säkerställa din sysselsätning vill vi at m inst 3 veckor skall tas ut under vecka 26 till \n32 om inget annat överenskommits.',
#  'semesterlagen säger också at du ska ta ut minst 20 semesterdagar under semesteråret.',
#  'de ta gäller \nunder förutsätning at dagarna är intjänade och betalda.',
#  'överskjutande semesterdagar  kan sparas för \nutag senare år, dock i max 5 år.',
#  'årets semesterdagar måste tas ut före sparade dagar från tidigare år.',
#  'personalhandbok  25 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsemester planeras i samråd med projektledare och/eller närmsta chef.',
#  'semesteransökan ska läggas in \ni maya och godkännas av närmaste chef.',
#  'för sommarsemestern ska semesteransökan vara inlämnad \nsenast den 30 april.',
#  '9.3.5  semesterlönetillägg  \nf ö r  v a r j e  i n t j ä n a d  s e m e s t e r d a g  s o m  t a s  u t  f å r  d u ,  u t ö v e r  d i n  l ö n ,  et semesterlönetillägg .',
#  'kontakta \nlöneavdelningen  (payroll@decerno.se)  om du vill ha mer information om deta.',
#  '9.3.6  semestergrundande frånvaro  \nvissa typer av  frånvaro är semestergrundande.',
#  'deta  regleras av semesterlagen.',
#  'följande \nfrånvaroorsaker från arbetet ger rät till semesterledighet (listan är inte heltäckande) .',
#  'sjukdom , maximalt 180 kalenderdagar per intjänandeår.',
#  'föräldrapenning , maximalt 120 kalenderdagar vid varje födsel.',
#  'deta gäller även vid ﬂerbarnsbörd.',
#  'för en förälder med ensam vårdnad är gränsen 180 kalenderdagar.',
#  'vid föräldraledighet på deltid räknas 86 arbetsdagar.',
#  'havandeskapspenning\n, maximalt 50 dagar är semesterlöneg rundande.',
#  'tillfällig föräldrapennin g, maximalt 120 dagar per barn och år för barn under 12 år.',
#  'närståendevård , maximalt 45 kalenderdagar per intjänandeår.',
#  '9.4 läkarbesök  \nläkarbesök är giltig frånvaro och redovisas som en egen aktivitet i maya.',
#  'tiden  ersäts inte av \narbetsgivaren.',
#  'när du rapporterar frånvarotypen ”läkarbesök”  i maya görs löneavdrag för tiden på \nnästkommande lön.',
#  'se dock  3.4 om företagshälsovård.',
#  '9.5 sjukfrånvaro  \nde mesta av reglerna kring sjukfrånvaro styrs av lagar och förordningar.',
#  'därutöver ger decerno en utökad sjuklön så som beskrivs under punkterna 9.5.4 - 9.5.7.',
#  '9.5.1  frånvaroanmälan vid sjukdom  \nnär du blir sjuk gör du en frånvaroanmäl an i maya.',
#  'när du gör en frånvaroanmälan i maya skickas  det \nautomatiskt m ejl till närmsta chef .',
#  'du ska själv meddela din projektledare och  dina projektkamrater .',
#  '9.5.2  karensavdrag  \nvi följer sjuklönelagen och kollektivavtalet för it -företag där karensavdrag mots varar 20 procent av en \nnormal arbetsvecka.',
#  'karensavdrag kan därmed behöva göras på mer eller mindre än en dag men inte \nmed mer än vad som svarar mot 20 procent av en normal arbetsvecka, beroende på när den anställde \nblir sjuk.',
# ...
#  'om arbete utförs under resa, t ex på tåg, räknas tiden som arbetstid, inte restid.',
#  'resor s ka i möjligaste mån ske utöver ordinarie arbetstid.',
#  'för medarbetare som har rät till restidsersätning gäller följande:  \nrestid ersäts som arbetstid.',
#  'restid utöver ordinarie arbetstid sparas i tidbanken maya.',
#  'vissa resor räknas inte som restid och ersäts  därmed inte, det gäller:  \n• resor till/från bostaden till tjänstestället (kontor eller kund i samma stad).',
#  '• resor till/från sociala aktiviteter.',
#  '• resor till/från utbildningar och konferenser.',
#  '• utlandsresor ersäts inte utöver ordinarie arbetstid.',
#  'för medarbetare som inte har rät till restidsersätning gäller följande:  \nrestid kompenseras vanligtvis med semesterdagar och ersäts därför normalt inte, men undantag kan \ngöras, det gäller:  \n• medarbetare som behöver göra längre resor till kund eller annat konto r än tjänstestället kan \nfå ersätning för restid i vissa fall.',
#  'deta är en individuell överenskommelse med närmsta chef.',
#  '• medarbetare som siter i et projekt som kräver regelbundna resor till annan stad kan få \nersätning för restid i vissa fall.',
#  'deta är e n individuell överenskommelse med närmsta chef.',
#  'rapportering av restid i maya: \nrestid mellan kunder eller till/från projekt och ordinarie arbetsplats debiteras om möjligt kund och \ntiden rapporteras på projektet.',
#  'restid som inte kan debiteras kund rapporter as på "dec/decv admin, intern administration" - "resa" \nom du har rät till restidsersätning:   personalhandbok  34 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n12. säkerhet och sekretess  \n12.1 sekretess  \nalla medarbetare skall i samband med anställningen skriva på et sekretessavtal.',
#  'besökare eller andra icke anställda får inte läm nas ensamma och utan tillsyn på företaget.',
#  'konﬁdentiell \ninformation får inte ligga framme obevakat.',
#  'varje dator ska loggas ut och skärmen ska stängas \nav/alternativt svart skärmsläckare ska vara igång eller arbetsdagens slut.',
#  'informationen på varje dator \nskall skyddas med lösenord.',
#  'vidare information ﬁnns i verksamhetshandbokens it -handbok.',
#  '12.2 media  \nfrågor från media som gäller företaget skall i första hand besvaras av vd eller annan ansvarig chef.',
#  '12.3 finansiell information \ndå decerno ingår i addnode group som ä r noterat på börsen får vi inte lämna ut i nformafton om \nföretagets ekonomiska ställning och resultat, vunna oﬀerter eller annan  marknadspåverkande \ninformation.',
#  '12.4 skyddsombud  \nskyddsombud på decerno är : \nstockholm – hanna runebrand <hanna.runebrand@decerno.se>  \nkista  – edgard george <edgard.george@decerno.se>  \nuppsala – filip gölander  <ﬁlip.golander@decerno.se>  \ngöteborg  – eva fredell <eva.fredell@decerno.se>  \nmalmö – johan ro dhe <johan.rodhe @decerno.se>  \n12.5 säkerhetsrutiner it & programvarupolicy  \nse it-handboken som ligger på intranätet under min anställning.',
#  'personalhandbok  35 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n13. arbetsmiljö och jämställdhet  \n13.1 arbetsmiljöpolicy  \nvi lägger ner mycket arbete på at skapa en bra arbetsmiljö för våra anställda.',
#  'vårt arbete ﬁnns \nbeskrivet i verksamhetshandboken, bl.a.',
#  'i 1150 arbetsmiljöpolicy  1252 arbetsmiljöarbete.',
#  '13.2 jämställdhetspolicy  \njämställdhet är en hjärtefråga för decerno och de t är en självklarhet at alla anställda oavset kön, \nbakgrund, religion etc ska behandlas lika.',
#  'vårt arbete beskrivs i verksamhetshandboken, bl  a i 1160 \njämställdhetspolicy.',
#  'personalhandbok  36 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14. försäkringspolicy  \n14.1 allmänt  \nförsäkringspolicyn klargör och vägleder företagets pers onal beträﬀande försäkringslösningar vid \nnyrekrytering, under anställning och vid avslutad anställning.',
#  'decerno väst ab följer kollektivavtalets försäkringspolicy vad gäller tjänstepension och sjukpension \n(itp).',
#  'decerno  ellersträvar som helhet vara likvä rdiga med kollektivavtalet.',
#  'decerno har rät at förändra \nförsäkringspolicyn vid exempelvis förändringar inom socialförsäkrings - eller skatelagsstiftningen samt \nfölja förändringar i kollektivavtal.',
#  'pensionsförsäkring och sjukförsäkring tecknas i normalfallet fr  o m månaden eller anställningens \nbörjan samt avslutas fr  o m månaden eller at anställningen upphör.',
#  'övriga försäkringar träder i kraft \nnär anställningen börjar.',
#  'många förmåner utrycks i förhållande till prisbasbelopp.',
#  '14.2 omfattning  \nförsäkringspolic yn omfatar samtliga tillsvidareanställda med månadslön.',
#  'i de fall någon/några av \nförsäkringarna omfatar andra anställningsformer eller timanställda innefatas även dessa anställda.',
#  'vissa försäkringar upphör at gälla eller uppnådd pensionsålder .',
#  '14.3 tjänste grupplivförsäkring (tgl)  \nför alla anställda mellan 18 -65 år ﬁnns en grupplivförsäkring.',
#  'vid dödsfall utbetalas et grundbelopp \noch eventuellt et eller ﬂera barntillägg:  \n\uf0a7 grundbeloppet är maximerat till 6 basbelopp  \n\uf0a7 barntillägg är för varje barn under 17 år lika med 2 basbelopp  \ngrundbeloppet reduceras fr.o.m.',
#  '55 års ålder.',
#  'barntillägget reduceras när barnet fyller 17 år och \nförsvinner helt när barnet fyllt 20 år.',
#  'grundbelo ppet utbetalas skatefrit till förmånstagare enligt följande ordning:  \n1. make/maka/registrerad partner  \n2. barn eller barnbarn oavset ålder  \n3. föräldrar \nom annan förmånstagare önskas skall deta skriftligen anmälas till försäkringsbolaget.',
#  'kontakta hr om \ndu har frågor angående tgl.',
#  'obs!',
#  'om du är sambo eller saknar anhöriga i personkretsen ovan bör överväga at ändra \nförmånstagarförordnande.',
#  'personalhandbok  37 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  \nförsäkringen gäller under arbetstid .',
#  'tfa lämnar ersätning för; inkomstförlust, kostnader, sveda och värk, rehabilitering, lyte och men, \nolägenheter i övrigt, framtida merkostnader, underhåll till ellerlevande och begravningskostnader.',
#  'tfa gäller när skador har orsakats av:  \n\uf0a7 olycksfall i arbetet, som förorsakar arb etsoförmåga i mer än 14 dagar eller medfört \nbestående medicinsk invaliditet.',
#  'ersätning kan även utges vid färdolycksfall om \ntraﬁkskadelagen inte är tillämplig.',
#  '\uf0a7 arbetssjukdom som varar i minst 180 dagar om försäkringskassan bedömt sjukdomen som \narbetsskad a.',
#  '14.5 kollektiv olycksfallsförsäkring  hos if \nförsäkringen gäller för alla anställda.',
#  'den g äller vid olycksfallsskada som drabbar den försäkrade både under arbetstid och under fritid , dvs \ndygnet runt .',
#  'försäkringen gäller i norden.',
#  'dock gäller följande moment även utanför norden - i max 1 \når: medicinsk invaliditet, ekonomisk invaliditet och dödsfall orsakat av olycksfall.',
#  'olycksfallsförsäkringen gäller utan självrisk och ger ersätning för: \n\uf0a7 kostnader för vård, medicin och hjälpmedel  (även  för behandling av tan dskada vid olycksfall)   \n\uf0a7 resekostnader i samband med vård och behandling \n\uf0a7 sveda och värk  \n\uf0a7 viss inkomstersätning  \n\uf0a7 invaliditetsersätning  / ersätning vid bestående skada  \n\uf0a7 överfall  \n\uf0a7 ersätning vid förlorad arbetsförmåga  \n\uf0a7 krishantering  \n\uf0a7 merkostnader - ersätning för personliga tillhörigheter  \nförsäkringen ger inte ersätning för medvetet framkallade skador.',
#  'inte heller lämnar den ersätning för \nskador i samband med elitidrot eller farliga aktiviteter .',
#  'försäkringen gäller inte under arbete för annan \narbe tsgivare än  decerno , inte heller direkt resa till och från deta arbete.',
#  'den ger maximal ersätning på 10 basbelopp vid medicinsk invaliditet och 20 basbelopp vid \nförvärvsmässig invaliditet.',
#  'försäkringen klassiﬁceras som en skatepliktig förmån och därm ed sker en förmånsbeskatning av \npremierna på ert lönebesked  årsvis för innevarande år from den månad anställning inleds.',
#  'ingen \nåterbetalning sker när anställningen upphör.',
#  'försäkring en är ej valbar för personalen då vi som arbetsgivare måste säkerställa a t vi är rät \nförsäkrade för at  kunna erbjuda kombinationen av arbete både på kontor och  distans.',
#  'personalhandbok  38 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14.6 sjukförsäkring \nutöver basskyddet från försäkringskassan har alla tillsvidareanställda en kompleterande \nsjukförsäkring .',
#  '14.6.1  decerno väst ab  \ndecerno väst ab ha r kollektivavtal och är därmed anslutna till itp .',
#  'läs mer om itp på \nwww.collectum.se .',
#  'vi har också kompleterat sjukförsäkringen i itp med rehabiliteringsförsäkring \ninklusive samtalss töd hos euroaccident.',
#  'dessa beskrivs närmare i stycket nedan.',
#  '14.6.2  decerno ab  \ndecerno ab  har sjukförsäkring motsvarande  itp-nivå (euroaccident plansjuk) .',
#  'observera at den \nanställde vid anslutningen måste vara fullt arbetsför.',
#  'd v s at den anställde kan fullgöra sit vanliga \narbete utan inskränkningar och inte uppbär sjuklön från arbetsgivaren eller får utbetalningar från \nförsäkringskassan .',
#  'försäkringen  träder in eller 3 månaders sjukskrivning till minst 25 % och ger, tillsammans med \nersätning från försäkringskassan, ca 70 % av lönen.',
#  'i försäkringen ingår också et förtidskapital vid ev.',
#  'förtidspensionering.',
#  '14.6.2.1  rehabiliteringsförsäkring \ndecerno har även e n rehabiliteringsförsäkring tecknad som heter "comeback" för at så snabbt som \nmöjligt säta in åtgärder och behandlingar för at få tillbaka en medarbetare som blivit sjuk.',
#  'försäkringen tillgodoser alla steg i processen, vilket innebär at en professionell rehabiliteringsledare ansvarar för utredning, planering och åtgärder.',
#  '14.6.2.2  samtalsstöd - för privata och arbetsrelaterade problem  \nsamtalsstöd ﬁnns när medarbetare har problem som kan påverka arbetsförmågan eller den allmänna \nhälsan – oavset om problemen är privata eller arbetsrelaterade.',
#  'för chefer ﬁnns även et särskilt stöd \ni chefsrollen.',
#  'obalans i livet behöver inte vara arbetsrelaterad.',
#  'det kan vara andra saker som kan påverka den \nallmänna hälsan eller arbetsförmågan.',
#  'tjänsten samtalsstöd omfatar rådgivning, chefsstöd, hälsocoaching och individuellt krisstöd.',
#  'medarbetare och chefer får hjälp oavset om det handlar om konﬂikter på jobbet, stresshantering, juridiska, ekonomiska eller livsstilsrelaterade frågor.',
#  'samtalen sker under full sekretess mot arbetsgivaren.',
#  'tjänsten erbjuder stöd och hjälp från legitimerade psykologer, beteendevetare, ekonomer, jurister, \nchefsstöd och hä lsocoach.',
#  'du kan utnytja upp till fem konsultaftoner i samma ärende.',
#  'samtalsstöd är öppet på telefon alla dagar dygnet runt.',
#  'telefonnummer till samtalsstöd : 0771 – 10 50 \n15  \nför mer information se länk:  \nhtps://euroaccident.com/se/privat/samtalsstod\n  \nsamtal med psykolog   personalhandbok  39 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsom nämns ovan ingår det samtal med legitimerad psykolog i samtalsstödet .',
#  'i försäkringen ingår fem \nsamtal á 45 min per kalenderår.',
#  'telefonnu mmer till psykolog: 0200 – 21 63 00  \n14.7 tjänstereseförsäkring  \nfinns tecknad hos europeiska via addnode.',
#  'försäkringsnummer: 8307 77522  \nhemsida: www.europeiska.se  \ntelefon: 0770- 456 900.',
#  '14.8 tjänstepension \ndecernos pensionslösningar ser lite olika ut beroende på om du är anställd i et bolag som har \nkollektivavtal eller inte.',
#  'se vad som gäller för dig under punkterna nedan:  \n14.8.1  decerno ab  \ntjänstepension tecknas mellan 25 och 65 års ålder hos avanza pension.',
#  'decernos pensionsplan innebär at premieberäkning av tjänstepension görs enligt nedanstående \ntabell.',
#  'årspremien beräknas på din årslön, d.v.s.',
#  'månadslönen x 12 och aktuellt inkomstbasbelopp.',
#  'exemplet baseras på inkomstbasbelopp för 2016.  \nmånadspremie vid olika månadslöner: \nmånadslön  brutolön  \n0-7,5 ibb  \n<=444 750 \n4,5%  brutolön  \n>7,5 ibb  \n>444 750 \n30%  premie/  \nmånad \n25 000  13 500  - 1 125  \n35 000  18 900          - 1 575  \n45 000  20 014  28 575 4 049 \n \nde olika försäkringsmomenten är:  \n\uf0a7 återbetalningsskydd utgångspunkten är den enskildes privata familjesituation.',
#  '\uf0a7 ålderspension den anställde väljer själv hur han/hon vill förvalta pensionssparandet.',
#  'sparpremien \nförvaltas via valda fonder.',
#  'den anställde ansvarar själv  för hur stort det slutgiltiga \npensionskapitalet blir vid pensionsdagen.',
#  'enligt decernos pensionsplan hos avanza säts \npremierna initialt in på avanzas fond utan avgiter, avanza zero om du inte väljer at fördela kapitalet på andra fonder eller enskilda aktier.',
#  'personalhandbok  40 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n\uf0a7 premiebefrielse (obligatorisk)  \nnyt från 2012 är at avgiten (fn 2,9% av premien) ligger utanför pensionssparandet enligt \novan.',
#  'den ingår som en del i försäkringssparandet, förutsat at den anställdes \nhälsotillstånd är fullgot.',
#  'den innebär at försäkringsgivaren går in och betalar \ntjänstepensionspremien i händelse av at den anställde blir långtidssjuk (längre tid än 3 månader = karenstid).',
#  'denna försäkring är obligatorisk och får inte avtalas bort av den anställde.',
#  'det är viktigt ellersom decern os skyldighet at betala tjänstepensionspremie vid \nlångtidssjukdom upphör eller 3 månaders sjukskrivning.',
#  '14.8.2  decerno väst ab  \nsom anställd i et bolag med kollektivavtal har du tjänstepensionen itp som är et försäkringspaket som innefatar:  \n• pension – som du kan ta ut fr ån 55 år \n• ersätning vid l ångvarig sjukdom  \n• skydd f ör din familj n är du d ör \nläs mer om din tjänstepension på www.collectum.se  \n14.9 sjukvårdsförsäkring  \nnär du är tillsvidareanställd på decerno får du en  sjukvård sförsäkring  via euro accident  (privataccess \nsilver) .',
#  'försäkringspremien betalas av decerno.',
#  'för alla fysiska läkarbesök och behandlingar utgår en \navgit om ca 500 kr vid första besöket per skada/vår dinsats.',
#  'decerno bekostar en sådan avgit till varje \nmedarbetare per kalenderår .',
#  'för at försäkringen ska kunna tecknas krävs det at du är fullt arbetsför.',
#  'med en sjukvårdsförsäkring får man en ”snabb -kö” till kvaliﬁcerad privat specialistvård.',
#  'försäkrin gen \ngör det möjligt at boka tid direkt hos specialistläkare .',
#  'om du skulle behöva en operafton så ordnas \ndet också via försäkringen och du slipper onödiga väntetider.',
#  'i försäkringen ingår även en e -vårdtjänst  helt frit för alla försäkringstagare.',
#  'den kan användas för at \nkonsultera en läkare över webben och få rådgivning samt receptförskrivningar  för ”enklare åkommor”.',
#  'för at försäkringen ska gälla behöver  man  söka vård direkt när man får symptom.',
#  'om man tidigare \nupplevt samma  symptom eller sökt vård för sina symptom  senaste 12 månaderna så täcker inte \nförsäkringen in.',
#  'försäkringen är en skatepliktig förmån och förmånsbeskatas varje månad from den månad \nanställningen inleds tom den månad anställningen upphö r. \n \nköp privata försäkringar   \ndu kan även köpa privata  försäkringar till dig och din familj via avanza.',
#  'det ﬁnns \nsjukvårdsförsäkringar, olycksfallsförsäkringar, livförsäkringar mm.',
#  'dessa försäkringar är helt fristående \nfrån decerno och betalas och  administreras således privat.',
#  'har ni frågor vänder ni er direkt till \navanzas kundsupport på 08 -409 20  000.   avanza privata försäkringar']

# %%
# Text-processing
lemmer = nltk.stem.WordNetLemmatizer()

# %%
ready_tokens = []
for token in word_tokens:
    l = lemmer.lemmatize(token)
    if token not in our_token_string:
        ready_tokens.append(l)

# %%
# Tokenization
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]

# %%
our_no_string = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~  \n \n  \n \n \n  \n\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_{|}~\t\n�u '
remove_punc_dict = dict((ord(punct), None) for punct in string.punctuation)

# %%
string.punctuation + our_token_string
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~  \n \n  \n \n \n  \n\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_{|}~\t\n�u '

# %%
# Remoce stop words
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punc_dict)))

# %%
greet_inputs = ('hej', 'hejsan', 'hur är läget?', 'halloj?', 'Hej', 'Hejsan', 'Hur är läget?', 'Halloj')

# %%
greet_responses = ('Hej!', 'Hejsan!', 'Hej där!', 'Hej på dig!!')

# %%
def greet(sentence):
    for word in sentence.split():
        if word.lower() in greet_inputs:
            return random.choice(greet_responses)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # convert text to number (numeric representation)
from sklearn.metrics.pairwise import cosine_similarity

# %%
def response(user_response):
    robo1_response = ''
    TfidfVec = TfidfVectorizer(tokenizer = LemNormalize, stop_words = 'english')
    tfidf = TfidfVec.fit_transform(sentence_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx = vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    if(req_tfidf == 0):
        robo1_response = robo1_response + 'Jag är ledsen. Jag är inte förmögen till att förstå din fråga!'
        return robo1_response
    else:
        robo1_response = robo1_response + sentence_tokens[idx] + '\n'
        return robo1_response

# %%
# Defining chatflow / botflow
print('Hej! Jag är en bot som kan svara på frågor kring personalhandboken. Säg hej till mig för att starta igång mig. Skriv hej då för att avsluta.')
flag = True
while(flag == True):
    user_response = input()
    user_response = user_response.lower()
    if(user_response != 'hej då'):
        if(user_response == 'tack' or user_response == 'tackar'):
            flag = False
            print('Bot: You are welcome...')
        else:
            if(greet(user_response) != None):
                print('Bot: ' + greet(user_response))
            else:
                sentence_tokens.append(user_response)
                word_tokens = word_tokens + nltk.word_tokenize(user_response)
                final_words = list(set(word_tokens))
                print('Bot: ', end = '')
                print(response(user_response))
                sentence_tokens.remove(user_response)
    else:
        flag = False 
        print('Bot: Hej då - på återseende!')
# Out:
# Hej! Jag är en bot som kan svara på frågor kring personalhandboken. Säg hej till mig för att starta igång mig. Skriv hej då för att avsluta.
# hej
# Bot: Hejsan!
# vad vet du om decerno
# C:\Users\emch\AppData\Local\anaconda3\envs\cuda_environment\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   warnings.warn(
# Bot: kontakta löneavdelningen om du är osäker på vad som gäller
# för dig.
#
# kan du berätta om lön
# Bot: 3.2 lön, ersättningar
# • lön betalas ut senast den 25:e varje månad
# • lön utbetalas för innevarande månad
# • semester, ledighet, sjukdom etc regleras månaden eller
# • under lag för utlägg/resor inlämnas inom två veckor
# • ersätning för utlägg betalas ut tillsammans med lön
# 3.2.1  löneväxling
# decerno erbjuder sina medarbetare löneväxling mot tjänstepension vilket kan vara et sät at höja
# sin totala pension.
#
# berätta om semester
# Bot: 9.3 semester
# inom decerno tillämpar vi två olika upplägg för semester.
#
# vad är uppläggen för semester
# Bot: 9.3 semester
# inom decerno tillämpar vi två olika upplägg för semester.
#
# upplägg semester
# Bot: 9.3 semester
# inom decerno tillämpar vi två olika upplägg för semester.
#
# planerad frånvaro
# Bot: vid planerad frånvaro i 3  dagar eller mer gör du  en frånvaro ansökan via
# maya senast 1 månad innan  den planerade frånvaron .
#
# föräldrarledighet
# Bot: Jag är ledsen. Jag är inte förmögen till att förstå din fråga!
# föräldraledighet
# Bot: 9.2 föräldraledighet
# 9.2.1  ansökan om föräldraledighet
# vid föräldraledighet under längre tid är det viktigt at du i god tid, minst 3  månader innan, an söker om
# ledighet .
#
# sjukvårdsförsäkring
# Bot: med en sjukvårdsförsäkring får man en ”snabb -kö” till kvaliﬁcerad privat specialistvård.
