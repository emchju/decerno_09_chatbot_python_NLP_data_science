# %%
import numpy as np
import nltk
import string
import random
import PyPDF2

# %%
# Create file object variable (opening method will be rb)
pdffileobj=open('personalhandboken.pdf','rb')

# %%
# Create reader variable that will read the pdffileobj
pdfreader = PyPDF2.PdfReader(pdffileobj)

# %%
# This will store the number of pages of this pdf file
x = len(pdfreader.pages)
x
# Out:
# 40

# %%
# Create a variable that will select the selected number of pages
page = pdfreader.pages[0]
text = page.extract_text()
print(text)
# Out:
#
#
#
# Vi skapar värde �llsammans
# U�orska och våga pröva
# Tydlig med omtanke
# Gör dig själv och andra stolta  Personalhandbok

# %%
complete_text = ''
for i in range(0, x):
    page = pdfreader.pages[i]
    text = page.extract_text()
    complete_text = complete_text + text
complete_text
# Out:
# ' \n \n  \nVi skapar värde �llsammans  \nU�orska och våga pröva  \nTydlig med omtanke  \nGör dig själv och andra stolta  Personalhandbok   Personalhandbok  2 ( 40 ) \n \nDokument:  Författare:  Senast sparat:   \n1220 S3 Personalhandboken  Mats Dahl  2023- 08-14 av Mats Dahl   \n \n  \nVision:  \nDecerno är bäst i \nSverige på att leverera \npålitliga system-\nlösningar för kunder \nmed höga krav   Personalhandbok  3 ( 40 ) \n \nDokument:  Författare:  Senast sparat:   \n1220 S3 Personalhandboken  Mats Dahl  2023- 08-14 av Mats Dahl   \n \nInnehåll   \nATT ARBETA PÅ DECERNO  5 \n1. PERSONALHANDBOKEN  6 \n2. KOLL EKTIVAVTAL  7 \n3. LÖN OCH FÖRMÅNER  8 \n3.1 LÖNEPOLICY  8 \n3.2 LÖN, ERSÄTTNINGAR  8 \n3.3 REKRYTERINGSBONUS  8 \n3.4 FÖRETAGSH ÄLSOVÅRD  9 \n3.5 MOTION OCH FRISKVÅRD  9 \n3.6 FIKA OCH FRUKT PÅ KONTORET  10 \n3.7 FÖRÄLDRAFÖRMÅN  10 \n3.8 BILDSKÄRMGLASÖGON  11 \n3.9 BLODGIVNING PÅ ARBETSTID  12 \n4. MOBILTELEFONPOLICY  13 \n5. KOMPETENSUTVECKLING OCH PERSONLIG  UTVECKLING  14 \n5.1 KOMPETENSUTVECKLINGSPOLICY  14 \n5.2 KONFERENSER  16 \n5.3 TIDREDOVISNING KURS OCH EXTERN KONFERENS  16 \n6. INTRODUKTION AV NYANSTÄLLDA  17 \n6.1 INTRODUKTION  17 \n6.2 FADDER  17 \n7. ARBETSTIDER OCH TIDREDOVISNING  18 \n7.1 RIKTLINJER FÖR ARBETSTID  18 \n7.2 DISTANSARBETE  FEL! BOKMÄRKET ÄR INTE DEFINIERAT . \n8. DECERNOMÖTEN & SOCIALA AKTIVITETER  21 \n8.1 OBLIGATORISKA DECERNOMÖTEN  21 \n8.2 REGIONALA SOCIALA AKTIVITETER  21 \n8.3 ÖVRIGA SOCIALA AKTIVITETER  21 \n9. FRÅNVARO  23 \n9.1 PLANERAD FRÅNVARO  23 \n9.2 FÖRÄLDRALEDIGHET  23 \n9.3 SEMESTER  23 \n9.4 LÄKARBESÖK  25 \n9.5 SJUKFRÅNVARO  25 \n9.6 PERMISSION  27 \n10. UTLÄGG OCH REPRESENTATION  28 \n10.1 UTLÄGG  27 \n10.2 EXTERN REPRESENTATION  28 \n10.3 INTERN REPRESENTATION  29 \n10.4 UTKÖP AV DATOR  30 \n11. RESOR I TJÄNSTEN  30 \n11.1 RESEPOLICY  30 \n11.2 ERSÄTTNING FÖR RESKOSTNAD VID LÅNGVARIGT ARBETE HOS KUND  32  Personalhandbok  4 ( 40 ) \n \nDokument:  Författare:  Senast sparat:   \n1220 S3 Personalhandboken  Mats Dahl  2023- 08-14 av Mats Dahl   \n \n11.3 TRAKTAMENTE  32 \n11.4 SEMESTER I SAMBAND MED TJÄNSTERESA  33 \n11.5 RESTID  33 \n12. SÄKERHET OCH SEKRETESS  34 \n12.1 SEKRETESS  34 \n12.2 MEDIA 34 \n12.3 FINANSIELL INFORMATION  33 \n12.4 SKYDDSOMBUD  34 \n12.5 SÄKERHETSRUTINER IT & PROGRAMVARUPOLICY  34 \n13. ARBETSMILJÖ OCH JÄMSTÄLLDHET  35 \n13.1 ARBETSMILJÖPOLICY  35 \n13.2 JÄMSTÄLLDHETSPOLICY  35 \n14. FÖRSÄKRINGSPOLICY  36 \n14.1 ALLMÄNT  36 \n14.2 OMFATTNING  36 \n14.3 TJÄNSTEGRUPPLIVFÖRSÄKRING (TGL)  36 \n14.4 TRYGGHETSFÖRSÄKRING VID ARBETSSKADA (TFA)  37 \n14.5 KOLLEKTIV OLYCKSFALLSFÖRSÄKRING HOS IF 37 \n14.6 SJUKFÖRSÄKRING  38 \n14.7 TJÄNSTERESEFÖRSÄKRING  39 \n14.8 TJÄNSTEPENSION  39 \n14.9 SJUKVÅRDSFÖRSÄKRING  40  Personalhandbok  5 ( 40 ) \n \nDokument:  Författare:  Senast sparat:   \n1220 S3 Personalhandboken  Mats Dahl  2023- 08-14 av Mats Dahl   \n \nAtt arbeta på Decerno  \nDet ska vara roligt at arbeta på Decerno!  \nPå Decerno förenas vi kring et stort \nteknikintresse. Vi gillar tekniska utmaningar och at lösa svåra problem �llsammans.  \nFöretagskulturen är omhändertagande utan at \nhämma  egna ini�a�v och idéer.  \nDecerno arbetar  med hela uppdrag. At jobba \n�llsammans i tuﬀa projekt skapar en unik företagskultur. Det du inte redan kan får du lära dig av erfa rna kollegor.  \nVi bygger skräddarsydda verksamhetssystem och vårt kundlö�e \när pålitliga systemlösningar. Pålitlighet innebär at ta ansvar för \nhelheten. At ha överblick och sam�digt kontroll på alla detaljer.   \nHos Decerno har du stora möjlighet at ständ igt vidareutveckla din \nkompetens. Dels genom arbetskamraternas erfarenhet och dels \ngenom vår satsning på vidareutbildning.  \nPå våra  konferensresor diskuterar vi lärdomar från våra projekt. \nBåde vad gäller teknik, ledarskap och aﬀärsmannaskap. \nResorna går �ll när och �ärran platser där vi kan \nkrydda vistelsen med berikande upplevelser.  \nAlla anställdas insatser är avgörande för at \nföretag ets mål och vision ska uppn ...

# %%
raw_doc = complete_text.lower() # converting enitre text to lowercase
raw_doc
# Out:
# ' \n \n  \nvi skapar värde �llsammans  \nu�orska och våga pröva  \ntydlig med omtanke  \ngör dig själv och andra stolta  personalhandbok   personalhandbok  2 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n  \nvision:  \ndecerno är bäst i \nsverige på att leverera \npålitliga system-\nlösningar för kunder \nmed höga krav   personalhandbok  3 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ninnehåll   \natt arbeta på decerno  5 \n1. personalhandboken  6 \n2. koll ektivavtal  7 \n3. lön och förmåner  8 \n3.1 lönepolicy  8 \n3.2 lön, ersättningar  8 \n3.3 rekryteringsbonus  8 \n3.4 företagsh älsovård  9 \n3.5 motion och friskvård  9 \n3.6 fika och frukt på kontoret  10 \n3.7 föräldraförmån  10 \n3.8 bildskärmglasögon  11 \n3.9 blodgivning på arbetstid  12 \n4. mobiltelefonpolicy  13 \n5. kompetensutveckling och personlig  utveckling  14 \n5.1 kompetensutvecklingspolicy  14 \n5.2 konferenser  16 \n5.3 tidredovisning kurs och extern konferens  16 \n6. introduktion av nyanställda  17 \n6.1 introduktion  17 \n6.2 fadder  17 \n7. arbetstider och tidredovisning  18 \n7.1 riktlinjer för arbetstid  18 \n7.2 distansarbete  fel! bokmärket är inte definierat . \n8. decernomöten & sociala aktiviteter  21 \n8.1 obligatoriska decernomöten  21 \n8.2 regionala sociala aktiviteter  21 \n8.3 övriga sociala aktiviteter  21 \n9. frånvaro  23 \n9.1 planerad frånvaro  23 \n9.2 föräldraledighet  23 \n9.3 semester  23 \n9.4 läkarbesök  25 \n9.5 sjukfrånvaro  25 \n9.6 permission  27 \n10. utlägg och representation  28 \n10.1 utlägg  27 \n10.2 extern representation  28 \n10.3 intern representation  29 \n10.4 utköp av dator  30 \n11. resor i tjänsten  30 \n11.1 resepolicy  30 \n11.2 ersättning för reskostnad vid långvarigt arbete hos kund  32  personalhandbok  4 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n11.3 traktamente  32 \n11.4 semester i samband med tjänsteresa  33 \n11.5 restid  33 \n12. säkerhet och sekretess  34 \n12.1 sekretess  34 \n12.2 media 34 \n12.3 finansiell information  33 \n12.4 skyddsombud  34 \n12.5 säkerhetsrutiner it & programvarupolicy  34 \n13. arbetsmiljö och jämställdhet  35 \n13.1 arbetsmiljöpolicy  35 \n13.2 jämställdhetspolicy  35 \n14. försäkringspolicy  36 \n14.1 allmänt  36 \n14.2 omfattning  36 \n14.3 tjänstegrupplivförsäkring (tgl)  36 \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  37 \n14.5 kollektiv olycksfallsförsäkring hos if 37 \n14.6 sjukförsäkring  38 \n14.7 tjänstereseförsäkring  39 \n14.8 tjänstepension  39 \n14.9 sjukvårdsförsäkring  40  personalhandbok  5 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \natt arbeta på decerno  \ndet ska vara roligt at arbeta på decerno!  \npå decerno förenas vi kring et stort \nteknikintresse. vi gillar tekniska utmaningar och at lösa svåra problem �llsammans.  \nföretagskulturen är omhändertagande utan at \nhämma  egna ini�a�v och idéer.  \ndecerno arbetar  med hela uppdrag. at jobba \n�llsammans i tuﬀa projekt skapar en unik företagskultur. det du inte redan kan får du lära dig av erfa rna kollegor.  \nvi bygger skräddarsydda verksamhetssystem och vårt kundlö�e \när pålitliga systemlösningar. pålitlighet innebär at ta ansvar för \nhelheten. at ha överblick och sam�digt kontroll på alla detaljer.   \nhos decerno har du stora möjlighet at ständ igt vidareutveckla din \nkompetens. dels genom arbetskamraternas erfarenhet och dels \ngenom vår satsning på vidareutbildning.  \npå våra  konferensresor diskuterar vi lärdomar från våra projekt. \nbåde vad gäller teknik, ledarskap och aﬀärsmannaskap. \nresorna går �ll när och �ärran platser där vi kan \nkrydda vistelsen med berikande upplevelser.  \nalla anställdas insatser är avgörande för at \nföretag ets mål och vision ska uppn ...

# %%
nltk.download('punkt') # using the punkt tokenizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet') # using the wordnet dictionary
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4') # using the punkt tokenizer
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\emch\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
sentence_tokens = nltk.sent_tokenize(raw_doc)
sentence_tokens
# Out:
# [' \n \n  \nvi skapar värde �llsammans  \nu�orska och våga pröva  \ntydlig med omtanke  \ngör dig själv och andra stolta  personalhandbok   personalhandbok  2 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n  \nvision:  \ndecerno är bäst i \nsverige på att leverera \npålitliga system-\nlösningar för kunder \nmed höga krav   personalhandbok  3 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ninnehåll   \natt arbeta på decerno  5 \n1. personalhandboken  6 \n2. koll ektivavtal  7 \n3. lön och förmåner  8 \n3.1 lönepolicy  8 \n3.2 lön, ersättningar  8 \n3.3 rekryteringsbonus  8 \n3.4 företagsh älsovård  9 \n3.5 motion och friskvård  9 \n3.6 fika och frukt på kontoret  10 \n3.7 föräldraförmån  10 \n3.8 bildskärmglasögon  11 \n3.9 blodgivning på arbetstid  12 \n4. mobiltelefonpolicy  13 \n5. kompetensutveckling och personlig  utveckling  14 \n5.1 kompetensutvecklingspolicy  14 \n5.2 konferenser  16 \n5.3 tidredovisning kurs och extern konferens  16 \n6. introduktion av nyanställda  17 \n6.1 introduktion  17 \n6.2 fadder  17 \n7. arbetstider och tidredovisning  18 \n7.1 riktlinjer för arbetstid  18 \n7.2 distansarbete  fel!',
#  'bokmärket är inte definierat .',
#  '8. decernomöten & sociala aktiviteter  21 \n8.1 obligatoriska decernomöten  21 \n8.2 regionala sociala aktiviteter  21 \n8.3 övriga sociala aktiviteter  21 \n9. frånvaro  23 \n9.1 planerad frånvaro  23 \n9.2 föräldraledighet  23 \n9.3 semester  23 \n9.4 läkarbesök  25 \n9.5 sjukfrånvaro  25 \n9.6 permission  27 \n10. utlägg och representation  28 \n10.1 utlägg  27 \n10.2 extern representation  28 \n10.3 intern representation  29 \n10.4 utköp av dator  30 \n11. resor i tjänsten  30 \n11.1 resepolicy  30 \n11.2 ersättning för reskostnad vid långvarigt arbete hos kund  32  personalhandbok  4 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n11.3 traktamente  32 \n11.4 semester i samband med tjänsteresa  33 \n11.5 restid  33 \n12. säkerhet och sekretess  34 \n12.1 sekretess  34 \n12.2 media 34 \n12.3 finansiell information  33 \n12.4 skyddsombud  34 \n12.5 säkerhetsrutiner it & programvarupolicy  34 \n13. arbetsmiljö och jämställdhet  35 \n13.1 arbetsmiljöpolicy  35 \n13.2 jämställdhetspolicy  35 \n14. försäkringspolicy  36 \n14.1 allmänt  36 \n14.2 omfattning  36 \n14.3 tjänstegrupplivförsäkring (tgl)  36 \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  37 \n14.5 kollektiv olycksfallsförsäkring hos if 37 \n14.6 sjukförsäkring  38 \n14.7 tjänstereseförsäkring  39 \n14.8 tjänstepension  39 \n14.9 sjukvårdsförsäkring  40  personalhandbok  5 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \natt arbeta på decerno  \ndet ska vara roligt at arbeta på decerno!',
#  'på decerno förenas vi kring et stort \nteknikintresse.',
#  'vi gillar tekniska utmaningar och at lösa svåra problem �llsammans.',
#  'företagskulturen är omhändertagande utan at \nhämma  egna ini�a�v och idéer.',
#  'decerno arbetar  med hela uppdrag.',
#  'at jobba \n�llsammans i tuﬀa projekt skapar en unik företagskultur.',
#  'det du inte redan kan får du lära dig av erfa rna kollegor.',
#  'vi bygger skräddarsydda verksamhetssystem och vårt kundlö�e \när pålitliga systemlösningar.',
#  'pålitlighet innebär at ta ansvar för \nhelheten.',
#  'at ha överblick och sam�digt kontroll på alla detaljer.',
#  'hos decerno har du stora möjlighet at ständ igt vidareutveckla din \nkompetens.',
#  'dels genom arbetskamraternas erfarenhet och dels \ngenom vår satsning på vidareutbildning.',
#  'på våra  konferensresor diskuterar vi lärdomar från våra projekt.',
#  'både vad gäller teknik, ledarskap och aﬀärsmannaskap.',
#  'resorna går �ll när och �ärran platser där vi kan \nkrydda vistelsen med berikande upplevelser.',
#  'alla anställdas insatser är avgörande för at \nföretag ets mål och vision ska uppnås.',
#  'sy�et med \nföretagets personalpoli�k är at utveckla  \nkunniga, mo�verade och enga gerade  \nmedarbetare.',
#  'decerno uppmuntrar ini�a�v från medarbetarna som bidrar �ll utveckling av företaget.',
#  'en kon�nuerlig \nkompetensutveckling är en förutsätning för at företagets \nmål och visioner ska uppnås.',
#  'företaget står och faller med engagerade medarbet are som \nanstränger sig för at leva upp �ll vår gemensamma värdegrund och \narbeta med decernos kundlö�e ”pålitliga systemlösningar” som mål.',
#  'tydlig med omtanke  \nmed omtanke är vi är tydliga, \ntransparenta och öppna med \nvarandra.',
#  'vi känner ansvar för \natt både dela och söka \ninformation.',
#  'prestigelösheten \när tydlig när vi delar med oss \nav vår kunskap och våra \nlärdomar.',
#  'gör dig själv och andra \nstolta  \nmed en hög yrkesheder \ngör vi vårt bästa och \nkänner en stolthet i det vi \nlevererar.',
#  'vi står för våra \nhandlingar och det vi \nsäger.',
#  'utforska och våga \npröva  \nmed nyfikenhet och e n vilja att \nständigt utvecklas vågar vi \ntänka nytt och testa nya vägar \nframåt.',
#  'vi är i en miljö där vi \nvågar spänna bågen och lära \noss av våra misstag.',
#  'vi skapar värde \ntillsammans  \nvi agerar alltid affärsmässigt \noch brinner för att göra \nskillnad och skapa värde.',
#  'med en stark laganda inkluderar vi, \nrespekterar och uppskattar \nvarandras olikheter.',
#  'personalhandbok  6 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n1. personalhandboken \ndenna personalhandbok gäller för alla bolag inom dec erno, dvs både för decerno ab och decerno väst \nab.',
#  'personalhandboken är din uppslagsbok för alla personalrelaterade frågor.',
#  'hitar du inte svaret på din \nfråga så ställ den �ll din närmsta chef.',
#  'flertalet av våra anställda arbetar som konsulter.',
#  'de får därför \nstörst utrymme i personalhandboken.',
#  'de som arbetar i andra roller såsom hr, sälj med ﬂera är \nsjälvklart lika vik�ga men kan i något högre grad behöva söka svar från närmsta chef för frågor som är speciﬁka för rollen.',
#  'senaste versionen ﬁnns all�d  �llgänglig på intr anätet  de regler och f örmåner som ﬁnns beskrivna i \nhandboken är de nu gällande.',
#  'dessa kan komma at ändras eller justeras i fram�den.',
#  'vi strävar e�er \nat all�d meddela större nyheter via veckobrevet, men det är varje medarbetares ansvar at känna �ll \nde regler och ru�ner som dokumenteras i handboken.',
#  'personalhandboken är en del av decernos ledningssystem inka som ﬁnns dokumenterat i vår verksamhets handbok.',
#  'hela verksamhetshandboken ﬁnns på intranätet.',
#  'affärsidé  \nvi ska utveckla skräddarsydda \nverksamhetssystem som effektiviserar \nvåra kunders verksamhet.',
#  'vi tar helhetsansvar och levererar hela \nsystem.',
#  'decerno skapar moderna, pålitliga och \nlångsiktiga systemlösningar.',
#  'decerno ska vara en naturlig partner \nför kunder med höga krav på sina \nsystemlösningar.',
#  'kundlöfte  \npålitliga \nsystemlösningar  \naffärsidé  \nvi ska utveckla skräddarsydda system \nsom effektiviserar våra kunders \nverksamhet.',
#  'vi tar helhetsansvar och levererar hela \nsystem.',
#  'decerno skapar moderna, pålitliga och \nlångsiktiga systemlösningar.',
#  'decerno ska vara en naturlig partner för \nkunder med höga krav på sina  \nsystemlösningar .',
#  'vision:  \ndecerno är bäst i \nsverige på att \nleverera pålitliga \nsystemlösningar för \nkunder med höga \nkrav   personalhandbok  7 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n2. kollektivavtal  \ninom decerno ﬁnns ﬂera  legala enheter, decerno ab samt decerno väst  ab.',
#  'decerno väst ab följer  almega it -företagens kollek �vavtal .',
#  'decerno ab har inte kollek�vavtal.',
#  'vissa anställningsvillkor och förmåner regleras av kollek�vavtalet och kan därför skilja sig åt.',
#  'deta \nkommer i förekommande fall vara beskrivet i personalhandboken.',
#  'vi strävar e�er at så långt det är \nmöjligt ha samma villkor för alla bolag .',
#  'personalhandbok  8 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3. lön och förmåner  \ndecerno erbjuder alla anställda et stort antal \nförmåner och ersätn ingar.',
#  'lönen är en av de största \nmen det ﬁnns också många andra förmåner .',
#  '3.1 lönepolicy  \ndecernos lönepoli�k är et medel för at s�mulera och belöna goda arbetsinsatser.',
#  'grunden är därför en resulta�nriktad lönesätning.',
#  'lönerna skall vara individuella på \net sät som är rätvist och bygger på saklig grund.',
#  'skillnader i lön får aldrig base ras \npå kön.',
#  'löneutvecklingen avgörs av ﬂera faktorer.',
#  'utöver personliga resultat kan det bestämmas av faktorer som arbetets svårighetsgrad och egen personlig utveckling.',
#  'vi är posi�va �ll resultatbaserad bonus så länge denna upplevs som rätvis och sakligt grundad.',
#  'decernos löner skall vara marknadsmässiga.',
#  'vi jämför med relevant \nsta�s�k på arbetsmarknaden såsom sveriges ingenjörers sta�s�k för civilingenjörer som arbetar med motsvarande arbetsuppgi�er.',
#  'mer om vår lönepolicy och lönekriterier ﬁnns at läsa i verksamhetshandboken.',
#  '3.2 lön, ersättningar  \n• lön betalas ut senast den 25:e varje månad  \n• lön utbetalas för innevarande månad \n• semester, ledighet, sjukdom etc regleras månaden e�er  \n• under lag för utlägg/resor inlämnas inom två veckor  \n• ersätning för utlägg betalas ut �llsammans med lön  \n3.2.1  löneväxling  \ndecerno erbjuder sina medarbetare löneväxling mot tjänstepension vilket kan vara et sät at höja \nsin totala pension.',
#  'det ﬁnns dock fallgropa r som gör at löneväxling inte lämpar sig för alla.',
#  'prata med \ndin närmsta chef om du är intresserad av at veta mer.',
#  '3.3 rekryteringsbonus  \ndecerno vill erbjuda generös rekryteringsbonus �ll alla anställda som hjälper oss at hita ﬂera medarbetare.',
#  'för at �psa om en person �ll någon av våra rekryteringar, prata med hr .',
#  'vi betalar ut rekryteringsbonus enligt följande förutsätningar:  \n• den anställde �psar om en person som de tror passar in hos oss som inte �digare varit i kontakt med oss.',
#  'lön \npension  \nfriskvårds -\nbidrag  \nförmån  \nrekryterings -\nbonus  \nföräldra -\nförmån  \n personalhandbok  9 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n• summan för rekryteringsbonus är : \n10kkr – för juniora upp �ll 2 års relevant erfarenhet  \n25kkr – för personer med mer än 2 års relevant erfarenhet \n• för �ps som  leder �ll en anställning utbetalas bonusen när personen börjar.',
#  '• rekryteringsbonusen gäller för alla medarbetare som inte har en ledande posi�on inom \ndecerno.',
#  '3.4 företagshälsovård  \ndecerno erbjuder alla anställda företagshälsovård.',
#  'företagshälso vården arbetar förebyggande för at \nvåra anställda inte ska drabbas av någon form av sjukdom.',
#  'i företagshälsovården ingår bl.a.',
#  'regelbundna hälsoundersökningar.',
#  'hälsoundersökningar görs vartannat år.',
#  'hälsoundersökning görs på arbets�d och �dredovisas u nder ”dec admin, intern administration”  som \n”hälsokontroll enl.',
#  'plan” .',
#  'du får m ax registrera 1 �mme inklusive res�d  för en hälsoundersökning.',
#  '3.5 motion och friskvård \nsom arbetsgivare vill decerno uppmuntra och stöta våra medarbetare at leva et hälsosamt liv.',
#  'därför lämnar vi bidrag �ll mo�on och friskvård.',
#  'principen för ersätning är 50/50, d.v.s.',
#  'den anställde betalar häl�en och decerno betalar häl�en.',
#  'decerno lämnar bidrag för mo�on och friskvård med 50% av utgi�er upp �ll 8  000 kr.',
#  'decernos bidr ag \nblir alltså maximalt 4 000 kr per person.',
#  'beloppet räknas per kalenderår, d.v.s.',
#  '1 januari – 31 december.',
#  'decerno har avtal med et ﬂertal gym, bl.a.',
#  'sats, fitness24seven samt friskis  & sve�s.',
#  'kontakta hr -\nchef  eller läs på intranätet för mer informa� on.',
#  'vi följer skateverkets anvisningar för  vilka former av mo�on och friskvård som vi får bidra �ll.',
#  'se vidare www.skateverket.se\n, sök på mo�on eller friskvård.',
#  'personliga s tartavgi�er och medlemsavgi�er i idrotsföreningar är skateplik�ga och ersäts därför inte.',
#  'det är vik�gt at det kvito som du lämnar in innehåller de uppgi�er som krävs för at decerno ska få avdrag för kostnaden och at du ska kunna få ersätning för dina utlägg.',
#  'är du det minsta osäker på vad \nsom gäller, kontakta ekonomiavdelningen.',
#  'personalhandbok  10 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3.6 fika och frukt på kontoret  \nvåra ﬁkastunder �llsammans är vik�ga �llfällen för at uppräthålla våra sociala kontakter på \narbetsplatsen.',
#  'här får man träﬀ a och diskutera med kollegor från andra projekt  eller avdelningar  som \nman kanske annars inte har så mycket daglig kontakt med.',
#  'vi ﬁkar �llsammans två gånger per dag .',
#  'vid distansarbete vill vi uppmuntra våra medarbetar e at boka \nin teams -ﬁka med varandra.',
#  'till morgonﬁkat på onsdagar serveras det frukost och på e�ermiddagen på fredagar har vi fredagsﬁka \ndär det förutom kaﬀe och te serveras något got.',
#  'ansvaret för at ﬁxa fredagsﬁka, och at säta på kaﬀe och te �ll ﬁkarasterna går runt mellan alla som \narbetar  på kontoret.',
#  'vi får också frukt levererad �ll kontoren.',
#  '3.7 föräldraförmån  \n3.7.1  syfte  \ndecerno vill visa at familjen är vik�g genom at underläta för småbarnsföräldrar, såväl mammor som \npappor, at utnytja den lagstadgade rä�gheten at vara hemma med sit barn.',
#  'därför ger vi extra \nersätning utöver den man får från försäkringskassan .',
#  'föräldralönen ska underläta rekrytering av \nmedarbetare med hög kompetens.',
#  'föräldralönen ska också främja jämställdheten och int e minst \nmo�vera även pappor at ta ut föräldraledighet.',
#  'föräldralönen gör at inkomstbor�allet vid föräldraledighet blir något mindre.',
#  'pension  betalas också in  i upp �ll 13 månader under föräldraledighet .',
#  'vi följer regelverket i a lmega it -företagens kollek�vavtal som beskrivs nedan.',
#  '3.7.2  ledighet ens förläggning \nden anställde ska i god �d, ca 3  månader före ledighetens början, �llsammans med sin chef planera \noch komma överens om ledighetens förläggning.',
#  'ledigheten ska om möjligt förläggas så at verksam heten inte påtagligt störs.',
#  '3.7.3  ersättning vid föräldraledighet  \nunder �d som medarbetaren är föräldraledig utbetalas ersätning enligt följande under förutsätning at medarbetaren ha� oavbruten anställning hos arbetsgivaren under minst et år före den först a dagen \nav föräldraledighet.',
#  'för en sammanhängande tre�odagarsperiod av föräldraledighet med hel föräldrapenning utbetalas \nen månadslön minus 30 sjukavdrag beräknat per dag enligt nedan.',
#  'avdraget baseras på 10 prisbasbelopp.',
#  'ersätning utges för två såda na tre�odagarsperioder.',
#  'för den som har tre års oavbruten \nanställning hos arbetsgivaren före den första dagen av föräldraledighet utges ersätning för sex tre�odagarsperioder.',
#  'antal tre�odagarsperioder av föräldralön enligt tabell nedan :  personalhandbok  11 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nanställnings �d vid företaget  1 år 3 år \nantal tre�odagarsperioder av föräldralön  2 6 \nden föräldralön arbetsgivaren ska betala beräknas genom at avdrag görs från lönen enligt nedan.',
#  'med \nbasbelopp avses prisbasbelopp.',
#  'avdrag/dag:   \nmånadslön  om högst  10 x basbeloppet/12  90%  x månadslönen  x 12 \n             365 \n \nmånadslön  över  10 x basbeloppet/12  90%  x månadslönen  x 12   + \n       365 \n \n10%  x (månadslönen  x 12 – 10 x basbeloppet ) \n365 \n \nersätning utges ej på lönedelar  över 15 prisbasbelopp.',
#  'vid tre �ärdedels, halv, en �ärdedels eller en åtondels föräldrapenning utbetalas tre �ärdedelar, \nhäl�en, en �ärdedel respek�ve en åtondel av belopp enligt ovan.',
#  'decerno erbjuder en utökad föräldraförmån och förlänger perioden för den som väljer at vara föräldraledig på del�d.',
#  'ersätningen kan dock inte övers�ga det belopp som hade betalats ut vid 100% föräldraledighet.',
#  'ersätning utges för tre�odagarsperiod som infaller inom 24 månader räknat från barnets födelse eller \nvid erhållande av vårdnad i samband med adop�on.',
#  'har föräldrapenning nedsats/indragits enligt lagen \nom allmän försäkring ska ersätning enligt ovan reduceras i motsvarande mån.',
#  '3.7.4  utbetalning \nföräldraförmånen betalas ut i samband med övriga löneutbetalningar, dvs.',
#  'den 25:e i månaden e�er \nutagandet av föräldraförmånen.',
#  'tiden då man tar ut föräldraförmån ska �dredovisas under ”frånvaro”  som ”dec föräldraförmån”.',
#  'ange \nockså namnet på barnet so m du är föräldraledig för.',
#  '3.8 bildskärm glasögon \nnär dina privata glasögon inte räcker �ll framför skärmen, står vi som din arbetsgivare för et par kompleta glasögon med din styrk a anpassade e�er skärmarbete, inklusive synundersökning hos \nop�ker.',
#  'inköp a v glas och bågar sker hos  synop�k eller smartey es med vilka vi har avtal.',
#  'kostnaden \nfaktureras därmed direkt �ll decerno.',
#  'glastyperna som ingår är enkelslipade glas, närprogressiva glas och rumsprogressiva glas.',
#  'op�kern gör \nbedömningen under synundersökningen vilka glas som passar dit synfel och arbete bäst.',
#  'inför dit besök hos op�kern behöver du och närmsta chef fylla i och signera en rekvisi�on som du �ll \nundersöknings�llfä llet.',
#  'kontakta  hr för rekvisi�on .',
#  'personalhandbok  12 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n3.9 blodgivning på arbetstid  \nhos decerno har du möjlighet at ge blod på arbets�d.',
#  'det råder o�a brist på blod och vi vill därför \nuppmuntra och göra lätare at ge blod.',
#  'tiden registreras som ”intern admin ” som ”  blodgivnin g” och \nmed max en �mme inklusive res�d.',
#  'personalhandbok  13 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n4. mobiltelefonpolicy \nmobiltelefon är et vik�gt och nödvändigt arbetsredskap och därför erbjuder decerno följande lösning:  \ntvå prismodeller vid inköp av valfri mobiltelefon.',
#  'alterna�v 1 – väljer man at behålla sin telefon i 2 år får kostnaden uppgå �ll 8  000 kr inkl.',
#  'moms.',
#  'alterna�v 2 – väljer man at behålla sin telefon i 3 år får kostnaden uppgå �ll 12  000 kr inkl.',
#  'moms.',
#  'meddela din närmsta chef innan köpet av telefon om du önskar nytja alterna�v 1 eller 2.  \nman kan också välja at köpa en dyrare telefon och betala mellanskillnaden själv.',
#  'då  inköpsbeloppet \növerskrider maxgränsen dras mellanskillnaden inkl.',
#  'moms av som netolöneavdrag på kommande lön .',
#  'mellanskillnaden �llfaller decerno och återbetalas ej vid inköp av ny telefon eller avslutad anställning.',
#  'vi har abonnemang hos telia �ll fastpris där det ingår fria samtal, sms och mms inom sverige.',
#  'dessutom \ningår mobilsurf med 15 gb per månad.',
#  'samtliga kostnader utöver det som ingår i fastprisabonnem anget betalas av den anställde om man inte \nkan visa at det är arbetsrelaterat.',
#  'förlust /stöld  av mobiltelefon skall omgående meddelas �ll närmsta chef som då informerar it at \ntömma telefonen på informa�on.',
#  'om telefonen går sönder så betalar decerno repara�onen.',
#  'i det fall den inte går at laga eller inte är \nvärd at laga så ersäts telefonen med en likvärdig produkt.',
#  'vid inköp av telefon anmäls deta �ll kontorsassistent  som registrerar telefonen i vårt register.',
#  'utbyta telefoner kasseras.',
#  '4.1 hörlura r \ndecerno erbjuder alla sina anställda inköp av  hörlurar för et värde upp �ll 1  500 kr inkl.',
#  'moms.',
#  'inköp kan ske vartannat år och ska godkännas i förväg av närmsta chef.',
#  'inköp sker av den anställde själv och redovisas som utlägg i skovik.',
#  'om inköpsbeloppet överskrider maxgränsen anges endast maxbeloppet om 1  500 kr inkl.',
#  'moms i \nskovik.',
#  'i annat fall returneras utläggsredovisningen.',
#  'utbyta hörlurar kasseras.',
#  'personalhandbok  14 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n5. kompetensutveckling och personlig \n utveckling \n5.1 kompetensutveckling spolicy  \nkompetensutveckling är vik�gt både för den personliga utvecklingen och \nför företagets utveckling.',
#  'vi satsar därför mycket på deta område.',
#  'sam�digt är det vik�gt at poängtera at varje medarbetare själv ansvarar för sin \nkompetensutveckling.',
#  'till kompetensutveckling räknar vi all �d som hamnar på projekt inom \nverksamhetsområdet utbildning.',
#  'exempel på utbildning är rena kurser och \ndeltagande i konferenser som båda bokas med godkännande av närmaste \nchef.',
#  'annan utbildning är egen utbildning som fås genom inläsning av manualer/böcker/kursliteratur eller dylikt.',
#  'till utbildning räknas även \nkonferenser som decerno själva anor dnar.',
#  '5.1.1  målsättning  \n• 80 �mmar per person och år och hel�dsanställd avsäts för utbildning \n• eget ansvar at fortbilda sig  \n• närmsta chef godkänner utbildningen  \ndecernos mål för varje medarbetares är at ca 80 �mmar per år av betald arbets�d skall avsätas för \nutbildning/vidareutveckling.',
#  'det motsvarar ca 5 % av en individs �llgängliga produk�va �d och är en \nrimlig målsätning för varje organisa�on.',
#  'därutöver är det vår förhoppning at var och en själv förkovrar \nsig yterligare genom at hålla sig à jour med vad som händer genom at läsa fackpress och intressant \nliteratur vid sidan om sit arbete.',
#  'det är i första hand medarbetarens eget ansvar och intresse at fortbilda sig.',
#  'den huvudsakliga utbildningen sker via projekten.',
#  'närmsta chef skall � llse at den \nutbildning som företaget bekostar ligger i båda parternas intresse.',
#  'för juniorkonsulter har chefen et \nsärskilt ansvar at både rekommendera och säkerställa at utbildning blir av och at den följer en röd \ntråd i konsultens utveckling.',
#  'tre dagar per år reserveras för den övergripande utbildning/vidareutveckling som decerno genomför \npå sina interna konferenser och den förkovring kring företagande, företagets utveckling och projekt \nsom genomförs på dessa konferenser.',
#  'sammantaget brukar vi dessutom avsäta yterligare �d för dessa \nvår- och höstkonferenser.',
#  'et riktmärke för den utbildning/vidareutveckling som decerno anser at man skall genomgå är at ca fyra dagar av �den skall användas �ll utbildning/utveckling som sy�ar �ll sådant man kansk e inte just \nnu har avsätning för.',
#  'kunskaper som kan vara roliga, s�mulerande eller framåtsy�ande i arbetsrollen.',
#  'övrig utbildnings�d bör anslås �ll konkret utbildning inom det ansvarsområde och arbete som man håller på med just nu.',
#  'sådan utbildning ä r den som får de mest posi�va och konkreta resultaten enligt \nvår erfarenhet.',
#  'kurs  \nkonferens -\nresa  \ndec \nacademy  \nmedarbetar -\nsamtal   personalhandbok  15 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n5.1.2  dec academy  \ndec academy är vårt interna forum för kompetensutveckling.',
#  'sy�et med dec academy är at skapa en \nmötesplats för diskussion och kunskapsutbyte om tekniska och andra a rbetsrelaterade frågor som är  \nvik�ga för individen och decerno.',
#  'med vik�gt menar vi vik�gt på tre sät:  \n• teknik –  vi måsta ha �llgång �ll de metoder och verktyg som behövs för at skapa pålitliga \nsystemlösningar.',
#  '• kompetens – vi måste underhålla och utv eckla personalens kompetens så at de får en \npersonlig utveckling och behärskar de verktyg och metoder de behöver.',
#  '• marknad – vi måste se �ll at vi har just den kompetens som marknaden e�erfråg ar de \nnärmaste åren.',
#  'dec academy anordnar kompetens -seminarium där alla konsulter får delta.',
#  'seminarierna kan vara \nhelt interna eller med någon extern föredragshållare.',
#  'alla anställda uppmuntras at komma med egna idéer om vilka ämnen de vill beröra.',
#  'ak�viteterna sker på betald arbets�d men o�ast utanför ordin arie arbetsdag.',
#  'tid för decacademy \n�dredovisas under ”dec /decv/  kompetens, personlig kompetensutveckling”  som ”decacademy”.',
#  '5.1.3  medarbetarsamtal  \nsy�et med medarbetarsamtalet är at ha en personlig dialog om hälsa och välbeﬁnnande, at prata om \ndin arbetssitua�on, at tydliggöra förväntningar, at följa upp presta�on mot sata mål, at s�mulera \noch utveckla din kompetens, at skapa et bra arbetsklimat, at fastställa individuella mål i enlighet med \nföretagets mål, at fastställa en personlig utve cklingsplan samt at ge underlag för planering och \nutveckling av decernos processer.',
#  'medarbetarsamtal sker en gång per år enligt särskild mall och kompleteras senare med et \nuppföljningssamtal samt et lönesamtal.',
#  'medarbetarsamtalet är et dubbelriktat samtal och din feedback �ll din chef är lika vik�g som chefens \nfeedback �ll dig.',
#  'under samtalet ska man säta upp personliga mål och fastställa en kompetensutvecklingsplan.',
#  '5.1.4  mentor  \nsom en del av din kompetensutveckling ﬁnns det möjlighet at få en mentor.',
#  'decernos \nmentorskapsprogram är tänkt at vara under et år med målet at det ska leda �ll personlig och \nprofessionell utveckling, både för adept och mentor.',
#  'genom at som adept ta  hjälp av en mentor som \nhar vik�g erfarenhet, kompetens och nätverk får du möjlighet at utvecklas och bli bätre på at \nhantera en situa�on, dit yrke eller en miljö.',
#  'en mentor är et stöd och et bollplank i din yrkesroll.',
#  'mentorns uppgi� är at på o lika sät medverka \n�ll din utveckling och at stödja och utmana dig u�från den målsätning du har.',
#  'det kan vara lämpligt at ha en mentor om man:   \n• anställs som nyutexaminerad  \n• om du vill påverka din egen utveckling och är beredda at ta dig an nya uppg i�er   personalhandbok  16 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n• om man tar sit första uppdrag i en ny roll, exempelvis som projektledare eller systemarkitekt  \n• i samband med rehabilitering  \nsom mentor får du möjlighet at dela med dig av den kunskap som du byggt upp under dit arbetsliv \nsamt öva på at vägleda o ch inspirera dina mindre erfarna kollegor, och på så vis utveckla \nledarskapsförmågor.',
#  'läs mer om vårt mentorskapsprogram på intranätet och prata med din närmsta chef om du tycker at \ndet skulle vara aktuellt för dig at ha en mentor.',
#  '5.2 konferenser \nvåra konf erenser är en mycket vik�ga såväl för kompetensutveckling som för at bygga vår \nföretagskultur.',
#  'vi brukar arrangera två konferenser per år.',
#  '5.2.1  sommarkonferens  \nsommarkonferensen är normalt en kortare konferens med en heldag och ev övernatning.',
#  'programmet är en kombina�on av kompetensutveckling, informa�on, team -building och sociala \nak�viteter.',
#  '5.2.2  höstkonferens  \nhöstkonferensen är en av de största satsningarna vi gör.',
#  'varje år samlas hela personalen för at under \nnågra intensiva dagar lära sig av varandra och uppleva saker �llsammans.',
#  'konferensen är mycket \nvik�g både för kompetensutveckling och företagskultur.',
#  'höstkonferensen brukar genomföras i form av en resa.',
#  'vi har som tradi�on at krydda et intensivt konferensprogram med gemensamma upplevelser och besö k. vi har under åren besökt de ﬂesta av \nvärldens hörn, all�från japan �ll svalbard och mexiko.',
#  'vår höstkonferens är tradi�onellt en något längre konferens.',
#  'den brukar sträcka sig över två �ll tre arbetsdagar och en helg.',
#  'konferensens längd och resmål varierar och beror bland annat på hur det \ngår för bolaget.',
#  'höstkonferensen arrangeras av en resegrupp som består av  medarbetare på decerno.',
#  'för at möjliggöra de påkostade resor vi gör krävs at den anställde lägger viss egen �d.',
#  'den �d av \nkonferensen so m sker på arbetsdagar räknas som arbets�d och 8h per arbetsdag redovisas  på \n”dec /decv  kompetens, personlig kompetensutveckling”  som ”konferens intern” .',
#  'det ﬁnns också en \nspeciell ak�vitet för förberedelser.',
#  'övrig �d under resan står den anställde för.',
#  '5.3 tidredovisning kurs och extern konferens  \nvid deltagande i externa kurser och konferenser redovisas max 8 �mmar per dag inkl.',
#  'res�d.',
#  'tid på \nhelgdagar redovisas inte.',
#  'kurs/konferens �dredovisas under ”dec /decv  kompetens, personlig kompetensutveckling”  som \n”konferens  extern”  eller ”kurs/seminarium” .',
#  'personalhandbok  17 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n6. introduktion av nyanställda  \n6.1 introduktion  \ndet är mycket vik�gt at man som nyanställd får en bra introduk�on och et got första intryck av \nföretaget.',
#  'et par gånger per år hålls introduk�onsdagar där alla som anställts det senaste halvåret bjuds in .',
#  'utöver introduk�ons dagen  är det mycket vik �gt at den nyanställda får träﬀa de personer som är \nvik�ga för at komma igång med arbetet.',
#  'det bästa sätet at komma in och lära känna verksamheten \när all�d at arbeta i et projekt.',
#  'en plan för den nyanställdas första �d tas fram �llsammans med \nnärmsta chef.',
#  'uppföljning av introduk�onen sker genom samtal med närmsta chef respek�ve hr e�er 3 respek�ve \n6 månader.',
#  'däre�er tar ordinarie ru�ner med utvecklingssamtal vid.',
#  '6.2 fadder  \nvårt mål är at alla som börjar hos oss på decerno ska få bästa möjliga introduk�on och et got första \nintryck av oss som arbetsplats.',
#  'det är därför vik�gt at vi alla tänker på at göra det vi kan för at \nunderläta för våra nyanställda, både i at komm a in i arbetet och i gemenskapen.',
#  'oavset om det \nhandlar om at bjuda med på ﬁka/lunch eller svara på frågor om arbetet.',
#  'det kan också vara bra at ha \nyterligare en person at vända sig �ll, utöver sin närmsta chef om det dyker upp frågor mm.',
#  'alla \nnyan ställda får därför en fadder som har särskilt ansvar för at vara �ll stöd under de första 3 \nmånaderna .',
#  'ska du vara fadder åt en nyanställd?',
#  'tydligare riktlinjer ﬁnns hos hr/närmsta chef.',
#  'personalhandbok  18 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n7. arbetstider och tidredovisning \n7.1 riktlinjer för arbetstid  \nnormal arbets�d är 40 �mmar  per vecka .',
#  'vi har ﬂexibel arbets�d och du kan själv styra när du arbetar \nunder förutsätning at det fungerar med dit projekt.',
#  'stäm av dina önskemål med din projektledare.',
#  '7.1.1  tidredovisning och tidbank  \nv årt system för at registrera a rbetad �d kallas maya.',
#  'i maya registreras all arbetad �d och eventuell \nfrånvaro.',
#  'varje vecka klarmarkeras av den anställde och atesteras sedan av närmsta chef, eller i vissa fall av din \nprojektledare.',
#  'vid månadsski�e ska du fakturaklarmarkera.',
#  'för at vår fakturering ska hinnas med \nenligt plan måste deta göras senast kl 8 den 1:a arbetsdagen i månaden.',
#  'lediga dagar är, förutom röda helgdagar  \n\uf0a7 midsommara�on  \n\uf0a7 jula�on  \n\uf0a7 nyårsa�on  \n\uf0a7 de år som na�onaldagen infaller på en lördag eller söndag \nfår medarbetaren 8h extra i sin �dbank för at kunna vara \nledig en annan dag.',
#  'den anställde planerar själv sin �d i samråd med projektledare/chef.',
#  'eventuell �d utöver ordinarie arbets�d sparas  i en �dbank i maya.',
#  'tid i �dbanken tas an�ngen ut i ledighet �mme mot �mme eller i \npengar.',
#  'det är �llåtet at ha minus i �dbanken, dock max 40 �mmar.',
#  'du kan  göra avbrot i arbet et för privata ärenden under en arbetsdag, exempelvis bankärenden, b esöka \nsociala medier mm.',
#  'dessa ärenden får u�öras f örutsat  at de  inte rapporteras  som arbets�d .',
#  'du kan få �mmar från �dbanken utbetalda i pengar.',
#  'varje �mme är värd ca månadslönen/166.',
#  'meddela ekonomiavdelningen i sådant fall.',
#  'om �dbanken övers�ger 200 �mmar betalas de \növers�gande �mmarna över 150 �mmar automa�skt ut.',
#  'denna utbetalning görs månaden e�er varje \nkvartal.',
#  '7.1.2  personplanering  \nför at våra projektledare ska veta hur mycket resurser de har �llgängliga och vi ska kunna planera och pr ognos�cera vår verksamhet ska alla konsulter planera sin �d.',
#  'planeringen görs �llsammans \nmed din projektledare och läggs in i maya.',
#  'planeringen ska uppdateras minst inför varje månadsski�e.',
#  'kom ihåg!',
#  'fakturaklarmarkera  \n i maya senast kl 8 \nden 1:a arbetsdagen \ni månaden.',
#  'personalhandbok  19 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n7.2 policy för distansarbete  \nvi tror på et ﬂexibelt arbetssät.',
#  'et ﬂexibelt arbetssät ger större frihet och kan bidra �ll en bätre \nbalans mellan arbete och fri�d.',
#  'vi erbjuder därför våra medarbetare möjlighet at arbeta på distans \nunder förutsätning at de aktuella arbetsuppgi�erna är lämpade och at omständigheterna medger \ndet.',
#  'många arbetsuppgi�er lämpar sig bra för at u�öra på distans.',
#  'sam�digt vill vi som arbetsgivare \nskapa en bra arbetsmiljö med stark företagskultur, gemenskap och laganda som stärks av at träﬀas fysiskt.',
#  'vi månar därför om  en balans mellan arbete på distans och på plats.',
#  'omfattning  \nmöjlighet �ll distansarbete och vilken omfatning som är lämplig, avgörs i samråd mellan \nmedarbetare, projektledare och närmsta chef där ömsesidigt förtroende utgör grunden.',
#  'möjligheten \n�ll dis tansarbete kan över �d ändras beroende på exempelvis aktuella arbetsuppgi�er, personliga \nförhållanden och verksamhetens behov.',
#  'arbetsgivaren kan all�d begära närvaro på arbetsplatsen.',
#  'denna policy omfatar distansarbete inom sverige.',
#  'vi är generellt pos i�va även �ll distansarbete \nutanför sverige men det arbetsrätsliga regelverket försvårar deta.',
#  'då skateregler, gil�ghet för \nförsäkringar etc skiljer sig från land �ll land måste deta all�d överenskommas �llsammans med vår \nhr-avdelning.',
#  'medarbetar en ansvarar själv för at ta reda på vilka regler som gäller i det aktuella \nlandet.',
#  'arbets�d och �llgänglighet  \nvid distansarbete ska medarbetaren vara �llgänglig på samma sät som vid arbete på kontoret under \nordinarie arbets�d.',
#  'det är vik�gt at upp räthålla en nära kontakt med sina kollegor.',
#  'digitala \narbetsverktyg ska hållas uppdaterade med status och/eller annan informa�on för at kunna bedriva det dagliga arbetet på et väl fungerande sät både för egen del och gentemot kollegor.',
#  'arbetsmiljö  \nen förutsätning för distansarbete är at medarbetaren har et arbetsutrymme u�ormat på et \nlämpligt sät.',
#  'arbetstagaren ska se �ll at arbetsplatsen är u�ormad och inredd på et ur \narbetsmiljösynpunkt lämpligt sät.',
#  'vid distansarbete ska chefen och medarbe taren samverka för at åstadkomma en hållbar arbetsmiljö.',
#  'arbetstagaren accepterar at arbetsgivaren e�er kontakt med arbetstagaren får besöka denne på distansarbetsplatsen eller på annat lämpligt sät kan säkerställa sit arbetsmiljöansvar.',
#  'se vidare 115 0 arbetsmiljöpolicy.',
#  'utrustning  \nvid distansarbete kan medarbetaren, e�er individuell behovsprövning, låna viss utrustning och \narbetsverktyg e�er överenskommelse mellan medarbetare och chef.',
#  'medarbetaren svarar för en \nstabil internetuppkoppling.',
#  'det kommer all�d at ﬁnnas �llgång �ll plats och utrustning på våra kontor men vid omfatande \ndistansarbete kan �llgång �ll egen plats komma at begränsas.',
#  'personalhandbok  20 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsekretess  \narbetstagaren har en lojalitetsplikt mot arbetsgivaren även vid  distansarbete och ska iakta sekretess \nmed de uppgi�er hen hanterar i distansarbetet enligt samma regler som på arbetsplatsen.',
#  'övrigt  \narbetstagaren har inte rät �ll res�dsersätning eller traktamente i annan utsträckning än enligt \nföretagets policy oc h inte i något fall för resor mellan distans - och huvudarbetsplatsen.',
#  'personalhandbok  21 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n8. decernomöten & sociala aktiviteter  \ndecerno anordnar decernomöten  av två typer: obligatoriska och sociala.',
#  'de obligatoriska är av \ninforma�v karaktär medan sociala möten handlar om at ha kul �llsammans med sina kollegor.',
#  'mötena är dels et forum för at förmedla informa�on och dels et sät at bätre lära känna sina  \nkollegor och skapa en starkare företagskultur.',
#  '8.1 obligatoriska decernomöten  \nde obligatoriska informa�va mötena som hålls är företagsinfo, regionmöten och gruppmöten.',
#  'se mer \nu�örlig informa�on om respek�ve mötesform och �dsrapportering nedan:  \ndedcerno info- en gång i månaden håller vd företagsinfo online för alla medarbetare.',
#  'här presenteras \nföretagsövergripande informa�on, ekonomiskt u�all med mera.',
#  'regionmöten - var 4 -8:e vecka hålls det regionmöten i göteborg och stockholm.',
#  'innehållet för dessa \nmöten kan vara informa�on om vad som händer i våra projekt, resultat för enheterna med mera.',
#  'o�ast \nerbjuds mat på mötena som an�ngen hålls på kontoret eller i en extern lokal.',
#  'gruppmöten-  var 4 -8:e vecka håller respek�ve konsultchef i gruppmöten med sina med arbetare.',
#  'et \nvik�gt mål med dessa möten är at skapa ﬂer möjligheter �ll dialog mellan chefer och medarbetare i \nen mindre grupp där det lätare för alla at komma �ll tals.',
#  'vid behov förekommer det även at lokala kontorsmöten hålls.',
#  'deltagande på de ssa möten är obligatoriskt och �den �dsredovisas under ”dec/decv admin, intern \nadministra�on” som ”företagsmöte”.',
#  'tid för förberedelse inför dessa typer av möten �dsredovisas under ”dec/decv admin, intern administra�on” som ”förberedelse �g -möte/ak� vitet ”.',
#  '8.2 regionala sociala aktiviteter   \nunder året anordnas kon�nuerligt olika sociala ak�viteter .',
#  'det är vik�gt för oss at vi har roligt \n�llsammans även utanför projekten!',
#  'exempel på ak�viteter kan vara en aw, matlagning �llsammans, \nteaterbesök ell er go -cart, möjligheterna är oändliga!',
#  'de sociala ak�viteterna är naturligtvis frivilliga \noch räknas inte som arbets�d.',
#  'det är vik�gt at ak�viteten är öppen för alla at anmäla sig �ll, även \nom det kan ﬁnnas begränsningar på antalet som kan delta i själva ak�viteten (tex de första 20 som \nanmäler sig får plats).',
#  'decerno täcker delar eller hela kostnaden för ak�viteten.',
#  'hur de sociala \nak�viteterna organiseras skiljer sig mellan regionerna ost, syd och väst.',
#  'i region ost och syd uppmuntrar vi de anst ällda at själv ta ini�a�v �ll sociala ak�viteter.',
#  'om du har \nen idé på något du skulle vilja göra �llsammans med dina kollegor så tveka inte at kontakta ulrika för \nregion ost eller viktor för region syd.',
#  'de hjälper �ll med planeringen av ak�viteten  och säkerställer \nat det passar in i kalendern med andra planerade arrangemang och at vi får en bra bredd i utbudet \nav ak�viteter.',
#  'i region väst så cirkulerar ansvaret medarbetare som �llsammans 2 och 2 anordnar ak�viteter enligt et schema.',
#  'personalhandbok  22 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \ntid för förberedelse inför en social ak�vitet �dredovisas under ”dec/dec v admin, intern \nadministra�on” som ”förberedelse �g -möte/ak�vitet”.',
#  'själva ak�viteten sker utanför arbets�d och \n�dredovisas ej.',
#  '8.3 övriga sociala aktiviteter  \nutöver ovan beskrivna ak�viteter anordnas även julfest och sommarfest vilka kan variera lite från \nkontor �ll kontor.',
#  'sociala ak�viteter kan oc kså anordnas per team eller projekt.',
#  'personalhandbok  23 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n9. frånvaro  \n9.1 planerad f rånvaro  \nfrånvaro ska planeras så långt i förväg som möjligt och ska stämmas av med projektledare f ör at vi ska \nkunna planera våra projekt .',
#  'vid planerad frånvaro i 3  dagar eller mer gör du  en frånvaro ansökan via \nmaya senast 1 månad innan  den planerade frånvaron .',
#  'glöm inte at också uppdatera din \npersonplanering.',
#  '9.2 föräldraledighet  \n9.2.1  ansökan om föräldraledighet  \nvid föräldraledighet under längre �d är det vik�gt at du i god �d, minst 3  månader innan, an söker om \nledighet .',
#  'när föräldraledigheten  har beviljats meddelar du ekonomiavdelningen  för at lönehantering \noch pens ionsavsätningar ska bli korrekta.',
#  'för at utnytja vår föräldraförmån så behöver du ansöka i \nmaya med dec föräldraförmån för de månader so m du har rät �ll.',
#  'förutom föräldraledighet har du också rät at gå ned i arbets�d fram �ll dess at dit barn fyller åta år.',
#  'vid föräldraledighet i mer än 3 månader �ll 10  % eller mer ändras tjänstgöringsgraden i maya �ll den \narbets�d som godkänts  via frånvaroansökan.',
#  'pensionspremien beräknas u�från den nya lönen.',
#  'om du skulle arbeta enstaka �mmar under din föräldraledighet så redovisar du �den för dessa �mmar \noch de  blir plus�mmar i din �dbank.',
#  '9.2.2  sjukvårdsförsäkring  \nunder den �d som du inte f år någon ersätning från decerno  under din föräldraledighet  så sparas \nförmånsbeskatningen �ll din första lön då du är �llbaka i arbetet.',
#  '9.3 semester  \ninom decerno �llämpar vi två olika upplägg för semester.',
#  'deta beror på at historiken har set olika \nut i de bolag som  idag  ingår i decerno.',
#  'kontakta löneavdelningen om du är osäker på vad som gäller \nför dig.',
#  '9.3.1   semesterår 1 april –  31 mars   \nvår standardmodell är baserat på semesterlagen oc h avser semesterår et 1 april – 31 mars med \nintjänandeår följt av utags år.',
#  'det innebär at  man  under sit första anställningsår arbetar in semester dagar  som sedan kan ta s ut \nunder det kommande semester året.',
#  'personalhandbok  24 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n9.3.1.1  semesterår 1 januari –  31 december     \nnågra medarbetare har av historiska skäl s emesterår et 1 januari – 31 december .',
#  'då sammanfallande \nintjänandeår och utags år innebär at man  arbetar in semesterdagar samma år som de ﬁnns \n�llgängliga at nytja.',
#  'vid avslutad anställning görs en avräkning mot intjänade semesterdagar  och en eventuell skuld \nkomm er at kvitas mot  din slut lön.',
#  '9.3.2  förskottssemester  \nvi erbjuder förskotssemester vilket innebär at du kan få möjlighet at vara ledig redan under dit \nförsta anställningsår i form av semester utan löneavdrag .',
#  'om du påbörjar din anställning före 1 september har du möjlighet at ta ut 30 förskotsdagar första \nåret och om du börjar din anställning e�er den 1 september har du rät at ta ut 5  semesterdagar .',
#  'under dit andra anställningsår får d u �llgång �ll de semesterdagar du tjänat in under dit första \nanställningsår.',
#  'de semesterdagar som du ännu inte har arbetat in fylls ut med förskotssemester  upp \n�ll din semesterrät  och med hänsyn tagen �ll eventuellt ej semestergrundande frånvaro.',
#  'exempel: du anställs den 1 oktober.',
#  'fram �ll den 31 mars kan du ta ut 5 dagar i förskotssemester.',
#  'den 1 april får du 30 nya semesterdagar.',
#  'e�ersom du bara hunnit arbeta in semester under 6 \nmånader är 15 av dessa dagar betalda och resterande dagar blir fö rskotssemester.',
#  'vid avslutad anställning inom 5 år från dit anställningsdatum sker en avräkning mot intjänade dagar \noch en eventuell skuld kvitas mot  din slutlön .',
#  '9.3.3  obetalda semesterdagar  \nvid avstående av nytjande �ll förskotssemester så har man som an ställd i en lighet med \nsemesterlagen rät at ta ut obetald semester.',
#  'om du påbörjar din anställning innan  1 september har du rät ta ut 25 obetalda  semester dagar och \nom du börjar din anställning den 1 september eller senare har du rät at ta ut 5 obetalda \nsemesterdagar .',
#  '9.3.4  riktlinjer för semesteruttag  \nenligt semesterlagen har v arje arbetstagare har rät �ll en sammanhängande semester på minst fyra \nveckor under perioden juni – augus�.',
#  'endast i undantagsfall får semestern förl äggas �ll annan �d.',
#  'för at vi ska kunna säkerställa din sysselsätning vill vi at m inst 3 veckor skall tas ut under vecka 26 �ll \n32 om inget annat överenskommits.',
#  'semesterlagen säger också at du ska ta ut minst 20 semesterdagar under semesteråret.',
#  'de ta gäller \nunder förutsätning at dagarna är intjänade och betalda.',
#  'överskjutande semesterdagar  kan sparas för \nutag senare år, dock i max 5 år.',
#  'årets semesterdagar måste tas ut före sparade dagar från �digare år.',
#  'personalhandbok  25 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsemester planeras i samråd med projektledare och/eller närmsta chef.',
#  'semesteransökan ska läggas in \ni maya och godkännas av närmaste chef.',
#  'för sommarsemestern ska semesteransökan vara inlämnad \nsenast den 30 april.',
#  '9.3.5  semesterlönetillägg  \nf ö r  v a r j e  i n t j ä n a d  s e m e s t e r d a g  s o m  t a s  u t  f å r  d u ,  u t ö v e r  d i n  l ö n ,  et semesterlöne�llägg .',
#  'kontakta \nlöneavdelningen  (payroll@decerno.se)  om du vill ha mer informa�on om deta.',
#  '9.3.6  semestergrundande frånvaro  \nvissa typer av  frånvaro är semestergrundande.',
#  'deta  regleras av semesterlagen.',
#  'följande \nfrånvaroorsaker från arbetet ger rät �ll semesterledighet (listan är inte heltäckande) .',
#  'sjukdom , maximalt 180 kalenderdagar per intjänandeår.',
#  'föräldrapenning , maximalt 120 kalenderdagar vid varje födsel.',
#  'deta gäller även vid ﬂerbarnsbörd.',
#  'för en förälder med ensam vårdnad är gränsen 180 kalenderdagar.',
#  'vid föräldraledighet på del�d räknas 86 arbetsdagar.',
#  'havandeskapspenning\n, maximalt 50 dagar är semesterlöneg rundande.',
#  'tillfällig föräldrapennin g, maximalt 120 dagar per barn och år för barn under 12 år.',
#  'närståendevård , maximalt 45 kalenderdagar per intjänandeår.',
#  '9.4 läkarbesök  \nläkarbesök är gil�g frånvaro och redovisas som en egen ak�vitet i maya.',
#  'tiden  ersäts inte av \narbetsgivaren.',
#  'när du rapporterar frånvarotypen ”läkarbesök”  i maya görs löneavdrag för �den på \nnästkommande lön.',
#  'se dock  3.4 om företagshälsovård.',
#  '9.5 sjukfrånvaro  \nde mesta av reglerna kring sjukfrånvaro styrs av lagar och förordningar.',
#  'därutöver ger decerno en utökad sjuklön så som beskrivs under punkterna 9.5.4 - 9.5.7.',
#  '9.5.1  frånvaroanmälan vid sjukdom  \nnär du blir sjuk gör du en frånvaroanmäl an i maya.',
#  'när du gör en frånvaroanmälan i maya skickas  det \nautoma�skt m ejl �ll närmsta chef .',
#  'du ska själv meddela din projektledare och  dina projektkamrater .',
#  '9.5.2  karensavdrag  \nvi följer sjuklönelagen och kollek�vavtalet för it -företag där karensavdrag mots varar 20 procent av en \nnormal arbetsvecka.',
#  'karensavdrag kan därmed behöva göras på mer eller mindre än en dag men inte \nmed mer än vad som svarar mot 20 procent av en normal arbetsvecka, beroende på när den anställde \nblir sjuk.',
#  'personalhandbok  26 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n9.5.2.1  återinsjuknande  \nom du  blir sj uk igen inom fem kalenderdagar från at den förra sjukperioden avslutades innebär  det at \nsjuklöneperioden fortsäter.',
#  'om fullt karensavdrag inte gjorts vid första sjukperioden ska yterligare \nkarensavdrag göras i den fortsata sjukperioden.',
#  'det går inte at få  mer än �o karens�llfällen under en tolvmånadersperiod.',
#  '9.5.3  läkarintyg  \nfrån och med den åtonde kalenderdagen  i sjukperioden är du skyldig at lämna läkarintyg �ll \narbetsgivaren.',
# ...
#  'om arbete u�örs under resa, t ex på tåg, räknas �den som arbets�d, inte res�d.',
#  'resor s ka i möjligaste mån ske utöver ordinarie arbets�d.',
#  'för medarbetare som har rät �ll res�dsersätning gäller följande:  \nres�d ersäts som arbets�d.',
#  'res�d utöver ordinarie arbets�d sparas i �dbanken maya.',
#  'vissa resor räknas inte som res�d och ersäts  därmed inte, det gäller:  \n• resor �ll/från bostaden �ll tjänstestället (kontor eller kund i samma stad).',
#  '• resor �ll/från sociala ak�viteter.',
#  '• resor �ll/från utbildningar och konferenser.',
#  '• utlandsresor ersäts inte utöver ordinarie arbets�d.',
#  'för medarbetare som inte har rät �ll res�dsersätning gäller följande:  \nres�d kompenseras vanligtvis med semesterdagar och ersäts därför normalt inte, men undantag kan \ngöras, det gäller:  \n• medarbetare som behöver göra längre resor �ll kund eller annat konto r än tjänstestället kan \nfå ersätning för res�d i vissa fall.',
#  'deta är en individuell överenskommelse med närmsta chef.',
#  '• medarbetare som siter i et projekt som kräver regelbundna resor �ll annan stad kan få \nersätning för res�d i vissa fall.',
#  'deta är e n individuell överenskommelse med närmsta chef.',
#  'rapportering av res�d i maya: \nres�d mellan kunder eller �ll/från projekt och ordinarie arbetsplats debiteras om möjligt kund och \n�den rapporteras på projektet.',
#  'res�d som inte kan debiteras kund rapporter as på "dec/decv admin, intern administration" - "resa" \nom du har rät �ll res�dsersätning:   personalhandbok  34 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n12. säkerhet och sekretess  \n12.1 sekretess  \nalla medarbetare skall i samband med anställningen skriva på et sekretessavtal.',
#  'besökare eller andra icke anställda får inte läm nas ensamma och utan �llsyn på företaget.',
#  'konﬁden�ell \ninforma�on får inte ligga framme obevakat.',
#  'varje dator ska loggas ut och skärmen ska stängas \nav/alterna�vt svart skärmsläckare ska vara igång e�er arbetsdagens slut.',
#  'informa�onen på varje dator \nskall skyddas med lösenord.',
#  'vidare informa�on ﬁnns i verksamhetshandbokens it -handbok.',
#  '12.2 media  \nfrågor från media som gäller företaget skall i första hand besvaras av vd eller annan ansvarig chef.',
#  '12.3 finansiell information \ndå decerno ingår i addnode group som ä r noterat på börsen får vi inte lämna ut i nforma�on om \nföretagets ekonomiska ställning och resultat, vunna oﬀerter eller annan  marknadspåverkande \ninforma�on.',
#  '12.4 skyddsombud  \nskyddsombud på decerno är : \nstockholm – hanna runebrand <hanna.runebrand@decerno.se>  \nkista  – edgard george <edgard.george@decerno.se>  \nuppsala – filip gölander  <ﬁlip.golander@decerno.se>  \ngöteborg  – eva fredell <eva.fredell@decerno.se>  \nmalmö – johan ro dhe <johan.rodhe @decerno.se>  \n12.5 säkerhetsrutiner it & programvarupolicy  \nse it-handboken som ligger på intranätet under min anställning.',
#  'personalhandbok  35 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n13. arbetsmiljö och jämställdhet  \n13.1 arbetsmiljöpolicy  \nvi lägger ner mycket arbete på at skapa en bra arbetsmiljö för våra anställda.',
#  'vårt arbete ﬁnns \nbeskrivet i verksamhetshandboken, bl.a.',
#  'i 1150 arbetsmiljöpolicy  1252 arbetsmiljöarbete.',
#  '13.2 jämställdhetspolicy  \njämställdhet är en hjärtefråga för decerno och de t är en självklarhet at alla anställda oavset kön, \nbakgrund, religion etc ska behandlas lika.',
#  'vårt arbete beskrivs i verksamhetshandboken, bl  a i 1160 \njämställdhetspolicy.',
#  'personalhandbok  36 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14. försäkringspolicy  \n14.1 allmänt  \nförsäkringspolicyn klargör och vägleder företagets pers onal beträﬀande försäkringslösningar vid \nnyrekrytering, under anställning och vid avslutad anställning.',
#  'decerno väst ab följer kollek�vavtalets försäkringspolicy vad gäller tjänstepension och sjukpension \n(itp).',
#  'decerno  e�ersträvar som helhet vara likvä rdiga med kollek�vavtalet.',
#  'decerno har rät at förändra \nförsäkringspolicyn vid exempelvis förändringar inom socialförsäkrings - eller skatelags��ningen samt \nfölja förändringar i kollek�vavtal.',
#  'pensionsförsäkring och sjukförsäkring tecknas i normalfallet fr  o m månaden e�er anställningens \nbörjan samt avslutas fr  o m månaden e�er at anställningen upphör.',
#  'övriga försäkringar träder i kra� \nnär anställningen börjar.',
#  'många förmåner utrycks i förhållande �ll prisbasbelopp.',
#  '14.2 omfattning  \nförsäkringspolic yn omfatar samtliga �llsvidareanställda med månadslön.',
#  'i de fall någon/några av \nförsäkringarna omfatar andra anställningsformer eller �manställda innefatas även dessa anställda.',
#  'vissa försäkringar upphör at gälla e�er uppnådd pensionsålder .',
#  '14.3 tjänste grupplivförsäkring (tgl)  \nför alla anställda mellan 18 -65 år ﬁnns en grupplivförsäkring.',
#  'vid dödsfall utbetalas et grundbelopp \noch eventuellt et eller ﬂera barn�llägg:  \n\uf0a7 grundbeloppet är maximerat �ll 6 basbelopp  \n\uf0a7 barn�llägg är för varje barn under 17 år lika med 2 basbelopp  \ngrundbeloppet reduceras fr.o.m.',
#  '55 års ålder.',
#  'barn�llägget reduceras när barnet fyller 17 år och \nförsvinner helt när barnet fyllt 20 år.',
#  'grundbelo ppet utbetalas skatefrit �ll förmånstagare enligt följande ordning:  \n1. make/maka/registrerad partner  \n2. barn eller barnbarn oavset ålder  \n3. föräldrar \nom annan förmånstagare önskas skall deta skri�ligen anmälas �ll försäkringsbolaget.',
#  'kontakta hr om \ndu har frågor angående tgl.',
#  'obs!',
#  'om du är sambo eller saknar anhöriga i personkretsen ovan bör överväga at ändra \nförmånstagarförordnande.',
#  'personalhandbok  37 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14.4 trygghetsförsäkring vid arbetsskada (tfa)  \nförsäkringen gäller under arbets�d .',
#  'tfa lämnar ersätning för; inkoms�örlust, kostnader, sveda och värk, rehabilitering, lyte och men, \nolägenheter i övrigt, fram�da merkostnader, underhåll �ll e�erlevande och begravningskostnader.',
#  'tfa gäller när skador har orsakats av:  \n\uf0a7 olycksfall i arbetet, som förorsakar arb etsoförmåga i mer än 14 dagar eller medfört \nbestående medicinsk invaliditet.',
#  'ersätning kan även utges vid färdolycksfall om \ntraﬁkskadelagen inte är �llämplig.',
#  '\uf0a7 arbetssjukdom som varar i minst 180 dagar om försäkringskassan bedömt sjukdomen som \narbetsskad a.',
#  '14.5 kollektiv olycksfallsförsäkring  hos if \nförsäkringen gäller för alla anställda.',
#  'den g äller vid olycksfallsskada som drabbar den försäkrade både under arbets�d och under fri�d , dvs \ndygnet runt .',
#  'försäkringen gäller i norden.',
#  'dock gäller följande moment även utanför norden - i max 1 \når: medicinsk invaliditet, ekonomisk invaliditet och dödsfall orsakat av olycksfall.',
#  'olycksfallsförsäkringen gäller utan självrisk och ger ersätning för: \n\uf0a7 kostnader för vård, medicin och hjälpmedel  (även  för behandling av tan dskada vid olycksfall)   \n\uf0a7 resekostnader i samband med vård och behandling \n\uf0a7 sveda och värk  \n\uf0a7 viss inkomstersätning  \n\uf0a7 invaliditetsersätning  / ersätning vid bestående skada  \n\uf0a7 överfall  \n\uf0a7 ersätning vid förlorad arbetsförmåga  \n\uf0a7 krishantering  \n\uf0a7 merkostnader - ersätning för personliga �llhörigheter  \nförsäkringen ger inte ersätning för medvetet framkallade skador.',
#  'inte heller lämnar den ersätning för \nskador i samband med eli�drot eller farliga ak�viteter .',
#  'försäkringen gäller inte under arbete för annan \narbe tsgivare än  decerno , inte heller direkt resa �ll och från deta arbete.',
#  'den ger maximal ersätning på 10 basbelopp vid medicinsk invaliditet och 20 basbelopp vid \nförvärvsmässig invaliditet.',
#  'försäkringen klassiﬁceras som en skateplik�g förmån och därm ed sker en förmånsbeskatning av \npremierna på ert lönebesked  årsvis för innevarande år from den månad anställning inleds.',
#  'ingen \nåterbetalning sker när anställningen upphör.',
#  'försäkring en är ej valbar för personalen då vi som arbetsgivare måste säkerställa a t vi är rät \nförsäkrade för at  kunna erbjuda kombina�onen av arbete både på kontor och  distans.',
#  'personalhandbok  38 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n14.6 sjukförsäkring \nutöver basskyddet från försäkringskassan har alla �llsvidareanställda en kompleterande \nsjukförsäkring .',
#  '14.6.1  decerno väst ab  \ndecerno väst ab ha r kollek�vavtal och är därmed anslutna �ll itp .',
#  'läs mer om itp på \nwww.collectum.se .',
#  'vi har också kompleterat sjukförsäkringen i itp med rehabiliteringsförsäkring \ninklusive samtalss töd hos euroaccident.',
#  'dessa beskrivs närmare i stycket nedan.',
#  '14.6.2  decerno ab  \ndecerno ab  har sjukförsäkring motsvarande  itp-nivå (euroaccident plansjuk) .',
#  'observera at den \nanställde vid anslutningen måste vara fullt arbetsför.',
#  'd v s at den anställde kan fullgöra sit vanliga \narbete utan inskränkningar och inte uppbär sjuklön från arbetsgivaren eller får utbetalningar från \nförsäkringskassan .',
#  'försäkringen  träder in e�er 3 månaders sjukskrivning �ll minst 25 % och ger, �llsammans med \nersätning från försäkringskassan, ca 70 % av lönen.',
#  'i försäkringen ingår också et för�dskapital vid ev.',
#  'för�dspensionering.',
#  '14.6.2.1  rehabiliteringsförsäkring \ndecerno har även e n rehabiliteringsförsäkring tecknad som heter "comeback" för at så snabbt som \nmöjligt säta in åtgärder och behandlingar för at få �llbaka en medarbetare som blivit sjuk.',
#  'försäkringen �llgodoser alla steg i processen, vilket innebär at en professionell rehabiliteringsledare ansvarar för utredning, planering och åtgärder.',
#  '14.6.2.2  samtalsstöd - för privata och arbetsrelaterade problem  \nsamtalsstöd ﬁnns när medarbetare har problem som kan påverka arbetsförmågan eller den allmänna \nhälsan – oavset om problemen är privata eller arbetsrelaterade.',
#  'för chefer ﬁnns även et särskilt stöd \ni chefsrollen.',
#  'obalans i livet behöver inte vara arbetsrelaterad.',
#  'det kan vara andra saker som kan påverka den \nallmänna hälsan eller arbetsförmågan.',
#  'tjänsten samtalsstöd omfatar rådgivning, chefsstöd, hälsocoaching och individuellt krisstöd.',
#  'medarbetare och chefer får hjälp oavset om det handlar om konﬂikter på jobbet, stresshantering, juridiska, ekonomiska eller livss�lsrelaterade frågor.',
#  'samtalen sker under full sekretess mot arbetsgivaren.',
#  'tjänsten erbjuder stöd och hjälp från legi�merade psykologer, beteendevetare, ekonomer, jurister, \nchefsstöd och hä lsocoach.',
#  'du kan utnytja upp �ll fem konsulta�oner i samma ärende.',
#  'samtalsstöd är öppet på telefon alla dagar dygnet runt.',
#  'telefonnummer �ll samtalsstöd : 0771 – 10 50 \n15  \nför mer informa�on se länk:  \nhtps://euroaccident.com/se/privat/samtalsstod\n  \nsamtal med psykolog   personalhandbok  39 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \nsom nämns ovan ingår det samtal med legi�merad psykolog i samtalsstödet .',
#  'i försäkringen ingår fem \nsamtal á 45 min per kalenderår.',
#  'telefonnu mmer �ll psykolog: 0200 – 21 63 00  \n14.7 tjänstereseförsäkring  \nfinns tecknad hos europeiska via addnode.',
#  'försäkringsnummer: 8307 77522  \nhemsida: www.europeiska.se  \ntelefon: 0770- 456 900.',
#  '14.8 tjänstepension \ndecernos pensionslösningar ser lite olika ut beroende på om du är anställd i et bolag som har \nkollek�vavtal eller inte.',
#  'se vad som gäller för dig under punkterna nedan:  \n14.8.1  decerno ab  \ntjänstepension tecknas mellan 25 och 65 års ålder hos avanza pension.',
#  'decernos pensionsplan innebär at premieberäkning av tjänstepension görs enligt nedanstående \ntabell.',
#  'årspremien beräknas på din årslön, d.v.s.',
#  'månadslönen x 12 och aktuellt inkomstbasbelopp.',
#  'exemplet baseras på inkomstbasbelopp för 2016.  \nmånadspremie vid olika månadslöner: \nmånadslön  brutolön  \n0-7,5 ibb  \n<=444 750 \n4,5%  brutolön  \n>7,5 ibb  \n>444 750 \n30%  premie/  \nmånad \n25 000  13 500  - 1 125  \n35 000  18 900          - 1 575  \n45 000  20 014  28 575 4 049 \n \nde olika försäkringsmomenten är:  \n\uf0a7 återbetalningsskydd utgångspunkten är den enskildes privata familjesitua�on.',
#  '\uf0a7 ålderspension den anställde väljer själv hur han/hon vill förvalta pensionssparandet.',
#  'sparpremien \nförvaltas via valda fonder.',
#  'den anställde ansvarar själv  för hur stort det slutgil�ga \npensionskapitalet blir vid pensionsdagen.',
#  'enligt decernos pensionsplan hos avanza säts \npremierna ini�alt in på avanzas fond utan avgi�er, avanza zero om du inte väljer at fördela kapitalet på andra fonder eller enskilda ak�er.',
#  'personalhandbok  40 ( 40 ) \n \ndokument:  författare:  senast sparat:   \n1220 s3 personalhandboken  mats dahl  2023- 08-14 av mats dahl   \n \n\uf0a7 premiebefrielse (obligatorisk)  \nnyt från 2012 är at avgi�en (fn 2,9% av premien) ligger utanför pensionssparandet enligt \novan.',
#  'den ingår som en del i försäkringssparandet, förutsat at den anställdes \nhälso�llstånd är fullgot.',
#  'den innebär at försäkringsgivaren går in och betalar \ntjänstepensionspremien i händelse av at den anställde blir lång�dssjuk (längre �d än 3 månader = karens�d).',
#  'denna försäkring är obligatorisk och får inte avtalas bort av den anställde.',
#  'det är vik�gt e�ersom decern os skyldighet at betala tjänstepensionspremie vid \nlång�dssjukdom upphör e�er 3 månaders sjukskrivning.',
#  '14.8.2  decerno väst ab  \nsom anställd i et bolag med kollek�vavtal har du tjänstepensionen itp som är et försäkringspaket som innefatar:  \n• pension – som du kan ta ut fr ån 55 år \n• ersätning vid l ångvarig sjukdom  \n• skydd f ör din familj n är du d ör \nläs mer om din tjänstepension på www.collectum.se  \n14.9 sjukvårdsförsäkring  \nnär du är �llsvidareanställd på decerno får du en  sjukvård sförsäkring  via euro accident  (privataccess \nsilver) .',
#  'försäkringspremien betalas av decerno.',
#  'för alla fysiska läkarbesök och behandlingar utgår en \navgi� om ca 500 kr vid första besöket per skada/vår dinsats.',
#  'decerno bekostar en sådan avgi� �ll varje \nmedarbetare per kalenderår .',
#  'för at försäkringen ska kunna tecknas krävs det at du är fullt arbetsför.',
#  'med en sjukvårdsförsäkring får man en ”snabb -kö” �ll kvaliﬁcerad privat specialistvård.',
#  'försäkrin gen \ngör det möjligt at boka �d direkt hos specialistläkare .',
#  'om du skulle behöva en opera�on så ordnas \ndet också via försäkringen och du slipper onödiga vänte�der.',
#  'i försäkringen ingår även en e -vårdtjänst  helt frit för alla försäkringstagare.',
#  'den kan användas för at \nkonsultera en läkare över webben och få rådgivning samt recep�örskrivningar  för ”enklare åkommor”.',
#  'för at försäkringen ska gälla behöver  man  söka vård direkt när man får symptom.',
#  'om man �digare \nupplevt samma  symptom eller sökt vård för sina symptom  senaste 12 månaderna så täcker inte \nförsäkringen in.',
#  'försäkringen är en skateplik�g förmån och förmånsbeskatas varje månad from den månad \nanställningen inleds tom den månad anställningen upphö r. \n \nköp privata försäkringar   \ndu kan även köpa privata  försäkringar �ll dig och din familj via avanza.',
#  'det ﬁnns \nsjukvårdsförsäkringar, olycksfallsförsäkringar, livförsäkringar mm.',
#  'dessa försäkringar är helt fristående \nfrån decerno och betalas och  administreras således privat.',
#  'har ni frågor vänder ni er direkt �ll \navanzas kundsupport på 08 -409 20  000.   avanza privata försäkringar']

# %%
word_tokens = nltk.word_tokenize(raw_doc)
word_tokens
# Out:
# ['vi',
#  'skapar',
#  'värde',
#  '�llsammans',
#  'u�orska',
#  'och',
#  'våga',
#  'pröva',
#  'tydlig',
#  'med',
#  'omtanke',
#  'gör',
#  'dig',
#  'själv',
#  'och',
#  'andra',
#  'stolta',
#  'personalhandbok',
#  'personalhandbok',
#  '2',
#  '(',
#  '40',
#  ')',
#  'dokument',
#  ':',
#  'författare',
#  ':',
#  'senast',
#  'sparat',
#  ':',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'vision',
#  ':',
#  'decerno',
#  'är',
#  'bäst',
#  'i',
#  'sverige',
#  'på',
#  'att',
#  'leverera',
#  'pålitliga',
#  'system-',
#  'lösningar',
#  'för',
#  'kunder',
#  'med',
#  'höga',
#  'krav',
#  'personalhandbok',
#  '3',
#  '(',
#  '40',
#  ')',
#  'dokument',
#  ':',
#  'författare',
#  ':',
#  'senast',
#  'sparat',
#  ':',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'innehåll',
#  'att',
#  'arbeta',
#  'på',
#  'decerno',
#  '5',
#  '1.',
#  'personalhandboken',
#  '6',
#  '2.',
#  'koll',
#  'ektivavtal',
#  '7',
#  '3.',
#  'lön',
#  'och',
#  'förmåner',
#  '8',
#  '3.1',
#  'lönepolicy',
#  '8',
#  '3.2',
#  'lön',
#  ',',
#  'ersättningar',
#  '8',
#  '3.3',
#  'rekryteringsbonus',
#  '8',
#  '3.4',
#  'företagsh',
#  'älsovård',
#  '9',
#  '3.5',
#  'motion',
#  'och',
#  'friskvård',
#  '9',
#  '3.6',
#  'fika',
#  'och',
#  'frukt',
#  'på',
#  'kontoret',
#  '10',
#  '3.7',
#  'föräldraförmån',
#  '10',
#  '3.8',
#  'bildskärmglasögon',
#  '11',
#  '3.9',
#  'blodgivning',
#  'på',
#  'arbetstid',
#  '12',
#  '4.',
#  'mobiltelefonpolicy',
#  '13',
#  '5.',
#  'kompetensutveckling',
#  'och',
#  'personlig',
#  'utveckling',
#  '14',
#  '5.1',
#  'kompetensutvecklingspolicy',
#  '14',
#  '5.2',
#  'konferenser',
#  '16',
#  '5.3',
#  'tidredovisning',
#  'kurs',
#  'och',
#  'extern',
#  'konferens',
#  '16',
#  '6.',
#  'introduktion',
#  'av',
#  'nyanställda',
#  '17',
#  '6.1',
#  'introduktion',
#  '17',
#  '6.2',
#  'fadder',
#  '17',
#  '7.',
#  'arbetstider',
#  'och',
#  'tidredovisning',
#  '18',
#  '7.1',
#  'riktlinjer',
#  'för',
#  'arbetstid',
#  '18',
#  '7.2',
#  'distansarbete',
#  'fel',
#  '!',
#  'bokmärket',
#  'är',
#  'inte',
#  'definierat',
#  '.',
#  '8.',
#  'decernomöten',
#  '&',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '8.1',
#  'obligatoriska',
#  'decernomöten',
#  '21',
#  '8.2',
#  'regionala',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '8.3',
#  'övriga',
#  'sociala',
#  'aktiviteter',
#  '21',
#  '9.',
#  'frånvaro',
#  '23',
#  '9.1',
#  'planerad',
#  'frånvaro',
#  '23',
#  '9.2',
#  'föräldraledighet',
#  '23',
#  '9.3',
#  'semester',
#  '23',
#  '9.4',
#  'läkarbesök',
#  '25',
#  '9.5',
#  'sjukfrånvaro',
#  '25',
#  '9.6',
#  'permission',
#  '27',
#  '10.',
#  'utlägg',
#  'och',
#  'representation',
#  '28',
#  '10.1',
#  'utlägg',
#  '27',
#  '10.2',
#  'extern',
#  'representation',
#  '28',
#  '10.3',
#  'intern',
#  'representation',
#  '29',
#  '10.4',
#  'utköp',
#  'av',
#  'dator',
#  '30',
#  '11.',
#  'resor',
#  'i',
#  'tjänsten',
#  '30',
#  '11.1',
#  'resepolicy',
#  '30',
#  '11.2',
#  'ersättning',
#  'för',
#  'reskostnad',
#  'vid',
#  'långvarigt',
#  'arbete',
#  'hos',
#  'kund',
#  '32',
#  'personalhandbok',
#  '4',
#  '(',
#  '40',
#  ')',
#  'dokument',
#  ':',
#  'författare',
#  ':',
#  'senast',
#  'sparat',
#  ':',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  '11.3',
#  'traktamente',
#  '32',
#  '11.4',
#  'semester',
#  'i',
#  'samband',
#  'med',
#  'tjänsteresa',
#  '33',
#  '11.5',
#  'restid',
#  '33',
#  '12.',
#  'säkerhet',
#  'och',
#  'sekretess',
#  '34',
#  '12.1',
#  'sekretess',
#  '34',
#  '12.2',
#  'media',
#  '34',
#  '12.3',
#  'finansiell',
#  'information',
#  '33',
#  '12.4',
#  'skyddsombud',
#  '34',
#  '12.5',
#  'säkerhetsrutiner',
#  'it',
#  '&',
#  'programvarupolicy',
#  '34',
#  '13.',
#  'arbetsmiljö',
#  'och',
#  'jämställdhet',
#  '35',
#  '13.1',
#  'arbetsmiljöpolicy',
#  '35',
#  '13.2',
#  'jämställdhetspolicy',
#  '35',
#  '14.',
#  'försäkringspolicy',
#  '36',
#  '14.1',
#  'allmänt',
#  '36',
#  '14.2',
#  'omfattning',
#  '36',
#  '14.3',
#  'tjänstegrupplivförsäkring',
#  '(',
#  'tgl',
#  ')',
#  '36',
#  '14.4',
#  'trygghetsförsäkring',
#  'vid',
#  'arbetsskada',
#  '(',
#  'tfa',
#  ')',
#  '37',
#  '14.5',
#  'kollektiv',
#  'olycksfallsförsäkring',
#  'hos',
#  'if',
#  '37',
#  '14.6',
#  'sjukförsäkring',
#  '38',
#  '14.7',
#  'tjänstereseförsäkring',
#  '39',
#  '14.8',
#  'tjänstepension',
#  '39',
#  '14.9',
#  'sjukvårdsförsäkring',
#  '40',
#  'personalhandbok',
#  '5',
#  '(',
#  '40',
#  ')',
#  'dokument',
#  ':',
#  'författare',
#  ':',
#  'senast',
#  'sparat',
#  ':',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  'att',
#  'arbeta',
#  'på',
#  'decerno',
#  'det',
#  'ska',
#  'vara',
#  'roligt',
#  'at',
#  'arbeta',
#  'på',
#  'decerno',
#  '!',
#  'på',
#  'decerno',
#  'förenas',
#  'vi',
#  'kring',
#  'et',
#  'stort',
#  'teknikintresse',
#  '.',
#  'vi',
#  'gillar',
#  'tekniska',
#  'utmaningar',
#  'och',
#  'at',
#  'lösa',
#  'svåra',
#  'problem',
#  '�llsammans',
#  '.',
#  'företagskulturen',
#  'är',
#  'omhändertagande',
#  'utan',
#  'at',
#  'hämma',
#  'egna',
#  'ini�a�v',
#  'och',
#  'idéer',
#  '.',
#  'decerno',
#  'arbetar',
#  'med',
#  'hela',
#  'uppdrag',
#  '.',
#  'at',
#  'jobba',
#  '�llsammans',
#  'i',
#  'tuﬀa',
#  'projekt',
#  'skapar',
#  'en',
#  'unik',
#  'företagskultur',
#  '.',
#  'det',
#  'du',
#  'inte',
#  'redan',
#  'kan',
#  'får',
#  'du',
#  'lära',
#  'dig',
#  'av',
#  'erfa',
#  'rna',
#  'kollegor',
#  '.',
#  'vi',
#  'bygger',
#  'skräddarsydda',
#  'verksamhetssystem',
#  'och',
#  'vårt',
#  'kundlö�e',
#  'är',
#  'pålitliga',
#  'systemlösningar',
#  '.',
#  'pålitlighet',
#  'innebär',
#  'at',
#  'ta',
#  'ansvar',
#  'för',
#  'helheten',
#  '.',
#  'at',
#  'ha',
#  'överblick',
#  'och',
#  'sam�digt',
#  'kontroll',
#  'på',
#  'alla',
#  'detaljer',
#  '.',
#  'hos',
#  'decerno',
#  'har',
#  'du',
#  'stora',
#  'möjlighet',
#  'at',
#  'ständ',
#  'igt',
#  'vidareutveckla',
#  'din',
#  'kompetens',
#  '.',
#  'dels',
#  'genom',
#  'arbetskamraternas',
#  'erfarenhet',
#  'och',
#  'dels',
#  'genom',
#  'vår',
#  'satsning',
#  'på',
#  'vidareutbildning',
#  '.',
#  'på',
#  'våra',
#  'konferensresor',
#  'diskuterar',
#  'vi',
#  'lärdomar',
#  'från',
#  'våra',
#  'projekt',
#  '.',
#  'både',
#  'vad',
#  'gäller',
#  'teknik',
#  ',',
#  'ledarskap',
#  'och',
#  'aﬀärsmannaskap',
#  '.',
#  'resorna',
#  'går',
#  '�ll',
#  'när',
#  'och',
#  '�ärran',
#  'platser',
#  'där',
#  'vi',
#  'kan',
#  'krydda',
#  'vistelsen',
#  'med',
#  'berikande',
#  'upplevelser',
#  '.',
#  'alla',
#  'anställdas',
#  'insatser',
#  'är',
#  'avgörande',
#  'för',
#  'at',
#  'företag',
#  'ets',
#  'mål',
#  'och',
#  'vision',
#  'ska',
#  'uppnås',
#  '.',
#  'sy�et',
#  'med',
#  'företagets',
#  'personalpoli�k',
#  'är',
#  'at',
#  'utveckla',
#  'kunniga',
#  ',',
#  'mo�verade',
#  'och',
#  'enga',
#  'gerade',
#  'medarbetare',
#  '.',
#  'decerno',
#  'uppmuntrar',
#  'ini�a�v',
#  'från',
#  'medarbetarna',
#  'som',
#  'bidrar',
#  '�ll',
#  'utveckling',
#  'av',
#  'företaget',
#  '.',
#  'en',
#  'kon�nuerlig',
#  'kompetensutveckling',
#  'är',
#  'en',
#  'förutsätning',
#  'för',
#  'at',
#  'företagets',
#  'mål',
#  'och',
#  'visioner',
#  'ska',
#  'uppnås',
#  '.',
#  'företaget',
#  'står',
#  'och',
#  'faller',
#  'med',
#  'engagerade',
#  'medarbet',
#  'are',
#  'som',
#  'anstränger',
#  'sig',
#  'för',
#  'at',
#  'leva',
#  'upp',
#  '�ll',
#  'vår',
#  'gemensamma',
#  'värdegrund',
#  'och',
#  'arbeta',
#  'med',
#  'decernos',
#  'kundlö�e',
#  '”',
#  'pålitliga',
#  'systemlösningar',
#  '”',
#  'som',
#  'mål',
#  '.',
#  'tydlig',
#  'med',
#  'omtanke',
#  'med',
#  'omtanke',
#  'är',
#  'vi',
#  'är',
#  'tydliga',
#  ',',
#  'transparenta',
#  'och',
#  'öppna',
#  'med',
#  'varandra',
#  '.',
#  'vi',
#  'känner',
#  'ansvar',
#  'för',
#  'att',
#  'både',
#  'dela',
#  'och',
#  'söka',
#  'information',
#  '.',
#  'prestigelösheten',
#  'är',
#  'tydlig',
#  'när',
#  'vi',
#  'delar',
#  'med',
#  'oss',
#  'av',
#  'vår',
#  'kunskap',
#  'och',
#  'våra',
#  'lärdomar',
#  '.',
#  'gör',
#  'dig',
#  'själv',
#  'och',
#  'andra',
#  'stolta',
#  'med',
#  'en',
#  'hög',
#  'yrkesheder',
#  'gör',
#  'vi',
#  'vårt',
#  'bästa',
#  'och',
#  'känner',
#  'en',
#  'stolthet',
#  'i',
#  'det',
#  'vi',
#  'levererar',
#  '.',
#  'vi',
#  'står',
#  'för',
#  'våra',
#  'handlingar',
#  'och',
#  'det',
#  'vi',
#  'säger',
#  '.',
#  'utforska',
#  'och',
#  'våga',
#  'pröva',
#  'med',
#  'nyfikenhet',
#  'och',
#  'e',
#  'n',
#  'vilja',
#  'att',
#  'ständigt',
#  'utvecklas',
#  'vågar',
#  'vi',
#  'tänka',
#  'nytt',
#  'och',
#  'testa',
#  'nya',
#  'vägar',
#  'framåt',
#  '.',
#  'vi',
#  'är',
#  'i',
#  'en',
#  'miljö',
#  'där',
#  'vi',
#  'vågar',
#  'spänna',
#  'bågen',
#  'och',
#  'lära',
#  'oss',
#  'av',
#  'våra',
#  'misstag',
#  '.',
#  'vi',
#  'skapar',
#  'värde',
#  'tillsammans',
#  'vi',
#  'agerar',
#  'alltid',
#  'affärsmässigt',
#  'och',
#  'brinner',
#  'för',
#  'att',
#  'göra',
#  'skillnad',
#  'och',
#  'skapa',
#  'värde',
#  '.',
#  'med',
#  'en',
#  'stark',
#  'laganda',
#  'inkluderar',
#  'vi',
#  ',',
#  'respekterar',
#  'och',
#  'uppskattar',
#  'varandras',
#  'olikheter',
#  '.',
#  'personalhandbok',
#  '6',
#  '(',
#  '40',
#  ')',
#  'dokument',
#  ':',
#  'författare',
#  ':',
#  'senast',
#  'sparat',
#  ':',
#  '1220',
#  's3',
#  'personalhandboken',
#  'mats',
#  'dahl',
#  '2023-',
#  '08-14',
#  'av',
#  'mats',
#  'dahl',
#  '1.',
#  'personalhandboken',
#  'denna',
#  'personalhandbok',
#  'gäller',
#  'för',
#  'alla',
#  'bolag',
#  'inom',
#  'dec',
#  'erno',
#  ',',
#  'dvs',
#  'både',
#  'för',
#  'decerno',
#  'ab',
#  'och',
#  'decerno',
#  'väst',
#  'ab',
#  '.',
#  'personalhandboken',
#  'är',
#  'din',
#  'uppslagsbok',
#  'för',
#  'alla',
#  'personalrelaterade',
#  'frågor',
#  '.',
#  'hitar',
#  'du',
#  'inte',
#  'svaret',
#  'på',
#  'din',
#  'fråga',
#  'så',
#  'ställ',
#  'den',
#  '�ll',
#  'din',
#  'närmsta',
#  'chef',
#  '.',
#  'flertalet',
#  'av',
#  'våra',
#  'anställda',
#  'arbetar',
#  'som',
#  'konsulter',
#  '.',
#  'de',
#  'får',
#  'därför',
#  'störst',
#  'utrymme',
#  'i',
#  'personalhandboken',
#  '.',
#  'de',
#  'som',
#  'arbetar',
#  'i',
#  'andra',
#  'roller',
#  'såsom',
#  'hr',
#  ',',
#  'sälj',
#  'med',
#  'ﬂera',
#  'är',
#  'självklart',
#  'lika',
#  'vik�ga',
#  'men',
#  'kan',
#  'i',
#  'något',
#  'högre',
#  'grad',
#  'behöva',
#  'söka',
#  'svar',
#  'från',
#  'närmsta',
#  'chef',
#  'för',
#  'frågor',
#  'som',
#  'är',
#  'speciﬁka',
#  'för',
#  'rollen',
#  '.',
#  'senaste',
#  'versionen',
#  'ﬁnns',
#  'all�d',
#  '�llgänglig',
#  'på',
#  'intr',
#  'anätet',
#  'de',
#  'regler',
#  'och',
#  'f',
#  'örmåner',
#  'som',
#  'ﬁnns',
#  'beskrivna',
#  'i',
#  'handboken',
#  'är',
#  'de',
#  'nu',
#  'gällande',
#  '.',
#  'dessa',
#  'kan',
#  'komma',
#  'at',
#  'ändras',
#  'eller',
#  'justeras',
#  'i',
#  'fram�den',
#  '.',
#  'vi',
#  'strävar',
#  'e�er',
#  'at',
#  'all�d',
#  'meddela',
#  'större',
#  'nyheter',
#  'via',
#  'veckobrevet',
#  ',',
#  'men',
#  'det',
#  'är',
#  'varje',
#  'medarbetares',
#  'ansvar',
#  'at',
#  'känna',
#  '�ll',
#  'de',
#  'regler',
#  'och',
#  'ru�ner',
#  'som',
#  'dokumenteras',
#  'i',
#  'handboken',
#  '.',
#  'personalhandboken',
#  'är',
#  'en',
#  'del',
#  'av',
#  'decernos',
#  'ledningssystem',
#  'inka',
#  'som',
#  'ﬁnns',
#  'dokumenterat',
#  'i',
#  'vår',
#  'verksamhets',
#  'handbok',
#  '.',
#  'hela',
#  'verksamhetshandboken',
#  ...]

# %%
# Text-processing
lemmer = nltk.stem.WordNetLemmatizer()

# %%
# Tokenization
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]

# %%
remove_punc_dict = dict((ord(punct), None) for punct in string.punctuation)

# %%
# Remoce stop words
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punc_dict)))

# %%
greet_inputs = ('hej', 'hejsan', 'hur är läget?', 'halloj?', 'Hej', 'Hejsan', 'Hur är läget?', 'Halloj')

# %%
greet_responses = ('Hej!', 'Hejsan!', 'Hej där!', 'Hej på dig!!')

# %%
def greet(sentence):
    for word in sentence.split():
        if word.lower() in greet_inputs:
            return random.choice(greet_responses)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # convert text to number (numeric representation)
from sklearn.metrics.pairwise import cosine_similarity

# %%
def response(user_response):
    robo1_response = ''
    TfidfVec = TfidfVectorizer(tokenizer = LemNormalize, stop_words = 'english')
    tfidf = TfidfVec.fit_transform(sentence_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx = vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    if(req_tfidf == 0):
        robo1_response = robo1_response + 'Jag är ledsen. Jag är inte förmögen till att förstå din fråga!'
        return robo1_response
    else:
        robo1_response = robo1_response + sentence_tokens[idx]
        return robo1_response

# %%
# Defining chatflow / botflow
flag = True
print('Hej! Jag är en bot som kan svara på frågor kring personalhandboken. Säg hej till mig för att starta igång mig. Skriv hej då för att avsluta.')
while(flag == True):
    user_response = input()
    user_response = user_response.lower()
    if(user_response != 'hej då'):
        if(user_response == 'tack' or user_response == 'tackar'):
            flag = False
            print('Bot: You are welcome...')
        else:
            if(greet(user_response) != None):
                print('Bot: ' + greet(user_response))
            else:
                sentence_tokens.append(user_response)
                word_tokens = word_tokens + nltk.word_tokenize(user_response)
                final_words = list(set(word_tokens))
                print('Bot: ', end = '')
                print(response(user_response))
                sentence_tokens.remove(user_response)
    else:
        flag = False 
        print('Bot: Hej då - på återseende!')
# Out:
# Hej! Jag är en bot som kan svara på frågor kring personalhandboken. Säg hej till mig för att starta igång mig. Skriv hej då för att avsluta.
# hej
# Bot: Hejsan!
# hur mår du
# Bot:
# C:\Users\emch\AppData\Local\anaconda3\envs\cuda_environment\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# C:\Users\emch\AppData\Local\anaconda3\envs\cuda_environment\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   warnings.warn(
# när du gör tjänsteresor får du också ersätning för den trängselskat  som du betalar.
# friskvård
# Bot: därför lämnar vi bidrag �ll mo�on och friskvård.
# hur mycket får jag i friskvård
# Bot: vi följer skateverkets anvisningar för  vilka former av mo�on och friskvård som vi får bidra �ll.
# hur mycket pengar får jag i friskvård
# Bot: du kan få �mmar från �dbanken utbetalda i pengar.
# hur många kr får jag i friskvård
# Bot: ersätning/mil                                        skatefri                           skateplik�g
# egen bil                                                     25 kr                                    10 kr
# förmånsbil (hybrid/bensin)                  12 kr                                  10 kr
# förmånsbil (diesel)                                12 kr                                   10 kr
# förmånsbil (el)                                      9,50 kr                                 10  kr
# 11.1.7  kollektiva  färdmedel
# resa i tjänsten med allmänna färdme del ersäts med fak�sk kostnad.
# vad kan jag få för gymkort?
# Bot: du kan få �mmar från �dbanken utbetalda i pengar.
# har vi avtal med gym?
# Bot: decerno har avtal med et ﬂertal gym, bl.a.
# hej då
# Bot: Goodbye!
